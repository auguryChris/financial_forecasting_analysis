# %% [markdown]
# # Backtesting with backtrader library
# Notes:
# Timestamp must be in the exact format specified for datafeed   **Timestamp needs to be first column index**
# Params for datafeed need to be specified as tuple of tuples
# Within strategy data is accessed via self.datas[0] for ex: self.datas[0].high_delta[0] would get you the first timeperiod's high_delta
# The current data has already happened and cannot be used to execute an order (ex. you cannot look at the current close price and simultaneously buy the current close, the order will be executed at open instead), orders will be executed on the following day.

# %%
import backtrader as bt
import datetime
import pandas as pd

# %% [markdown]
# ## Define Strategies and Data utils

# %%
class BasicStrategy(bt.Strategy):
    def __init__(self):
        # To keep track of pending orders
        self.order = None
        print('***The limit sells for this strategy are valid for 1 day***')
        
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        elif order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)
            
            self.bar_executed = len(self)
        
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')
        
        # set no pending order
        self.order = None


    def next(self):
        # STRATEGY 
        data = self.datas[0]
        self.log(f'Current Portfolio Value : {self.broker.get_value()}')
        
        # cancel if there is an order pending, this strategy should have 1 working order per day
        if self.order:
            self.log('ORDER CANCELLED')
            self.cancel(self.order)
        
        # Check if we are in the market
        if not self.position:
            # BUY
            try:
                self.size = int(self.broker.get_cash() / self.datas[0].open[1])
            except:
                print('Size Exception. If at the end of data, ignore.')
            # invest if prediction looks good
            self.log(f'MARKET BUY CREATE {self.size} shares at next open, current close price: {data.close[0]}')
            self.buy(size=self.size) # market order buys at next open                      
                
        else:
            # place sell order at predicted high if predicted high is greater than current close price
            # TODO: Make prediction and close a filter in the class constructor (more optimal)
            if data.prediction[0] >= data.close[0]:
                self.log(f'LIMIT SELL CREATE {self.size} shares at {data.prediction[0]}')  
                self.sell(exectype=bt.Order.Limit,
                             price=data.prediction[0],
                             valid=data.datetime.date(0) + datetime.timedelta(days=2),
                             size=self.size)
        # if prediction is less than current value sell at open (ASAP)
            else:
                self.log('MARKET SELL CREATE. PREDICTION < CURRENT CLOSE')
                self.sell(size=self.size)

# %%
class BuyAndHold(bt.Strategy):
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)

            self.bar_executed = len(self)

      
    def start(self):
        self.val_start = self.broker.get_cash()  # keep the starting cash

    def nextstart(self):
        # Buy all the available cash
        size = int(self.broker.get_cash() / self.datas[0].open[1])
        self.buy(size=size)

    def stop(self):
        # calculate the actual returns
        self.roi = (self.broker.get_value() / self.val_start) - 1.0
        print(f'Stop price: {self.datas[0].close[0]}')
        print('ROI:        {:.2f}%'.format(100.0 * self.roi))

# %%
def prepare_data(data, fromdate, todate, filepath):
    """Prepare data for backtrader datafeed object
        Returns prepared data filepath and params for the GenericCSVData class, also returns columns used"""
    data['timestamp'] = pd.to_datetime(data['timestamp'])
    # start param setup for backtrader
    start = data['timestamp'].iloc[0]
    end = data['timestamp'].iloc[-1]
    from_to = [(start.year, start.month, start.day), (end.year, end.month, end.day)]
    # Backtrader string format
    data['timestamp'] = data['timestamp'].dt.strftime('%Y-%m-%d %H:%M:%S')
    # backtrader data feed class needs a file path, this could be a temp file that's constantly overwritten
    data.to_csv(filepath)
    
    starting_params = [
    ('fromdate', datetime.datetime(*from_to[0])),
    ('todate', datetime.datetime(*from_to[1])),
    ('nullvalue', 0.0),
    ('dtformat', ('%Y-%m-%d %H:%M:%S')),
    ('tmformat', ('%H:%M:%S')),
    ('datetime', 1)]
    # skip nonfeatures (timestamp)
    cols = data.columns[1:]
    # get column position for each indicator and add to starting params list
    i = 2 # starting index since others are reserved
    for indicator in cols:
        starting_params.append((indicator, i))
        i+=1
    final_params = tuple(starting_params)

    return filepath, final_params, cols

# %% [markdown]
# ## Import Data and Run Backtest

# %%
import os

# %%
absolutepath = os.path.abspath('')
fileDirectory = os.path.dirname(absolutepath)

#Path of parent directory (moves outside of repository)
parentDirectory = os.path.dirname(fileDirectory)

# %%
fileDirectory
# Out:
# '/Users/chris/Documents/GitHub/financial_forecasting_analysis'

# %%
def capstone_data_prep(pred_folder_name, pred_col_name, ticker_df_filepath, starting_cash=100000):
    """Main loop, preps data and executes backtrader on all stocks in the prediction folder"""
    ticker_backtesting_dict = {}
    for pred_file in os.listdir( fileDirectory + f'/data/ticker_predictions/{pred_folder_name}'):
        # collect data
        ticker_name = pred_file.split('_')[0]
        pred_df = pd.read_csv(fileDirectory + f'/data/ticker_predictions/{pred_folder_name}/{pred_file}')
        ticker_df = pd.read_csv(ticker_df_filepath + f'/{ticker_name}_full_data.csv')
        
        # make timestamp in column position 0, SPECIFIC TO FULL DATA IN FILE 
        ticker_df = ticker_df.rename({'reportperiod':'timestamp'}, axis=1)
        ticker_cols = list(ticker_df.columns)
        ticker_cols[5] = 'ts_cpy'
        ticker_cols[0] = 'timestamp'
        ticker_df.columns = ticker_cols
        ticker_df['timestamp'] = ticker_df['ts_cpy']
        # merge prediction data with full data, on key = timestamp
        ticker_df = ticker_df.merge(pred_df.loc[:, ['timestamp', pred_col_name]], on='timestamp')
        # new prediction column name = "prediction", important because backtester strategy looks for this column name
        ticker_df = ticker_df.rename({pred_col_name:'prediction'}, axis=1)
        # remove all non-prediction rows in prediction field
        ticker_df = ticker_df[ticker_df.prediction > 0]
        # skip nonfeatures, keep timestamp, SPECIFIC TO FULL DATA IN FILE 
        nonfeatures = ticker_df.columns[1:7]
        features = [col for col in ticker_df.columns if col not in nonfeatures]
        # get index of start and end dates for trading
        ticker_df = ticker_df[features]
        ticker_df.columns = [c.lower() for c in ticker_df.columns]
        idx1 = ticker_df.prediction[ticker_df.prediction > 0].index[0]
        idx2 = ticker_df.prediction[ticker_df.prediction > 0].index[-1]
        start_date = pred_df.timestamp[idx1]
        end_date  = pred_df.timestamp[idx2]
        
        # Prepare data for backtrader
        prep_data = prepare_data(ticker_df.copy(), start_date, end_date, 'temp/prep_data.csv')
        class DataFeed(bt.feeds.GenericCSVData):
            lines = tuple(prep_data[2])
            params = prep_data[1]
        
        print(f"--------Ticker Name-------: {ticker_name}")
        ##### BUY AND HOLD #######
        print('BUY AND HOLD')
        # initialize everything and run strategy
        cerebro = bt.Cerebro(cheat_on_open=True)
        cerebro.broker.setcash(starting_cash)
        #cerebro.addsizer(bt.sizers.FixedSize, stake=10)
        print(f'Starting Portfolio Value: {cerebro.broker.getvalue()}')
        data = DataFeed(dataname=prep_data[0])
        cerebro.adddata(data)
        cerebro.addstrategy(BuyAndHold)
        cerebro.addanalyzer(bt.analyzers.SharpeRatio, timeframe=bt.TimeFrame.Months, _name = 'sharpe')
        cerebro.addanalyzer(bt.analyzers.DrawDown, _name = 'dd')
        cerebro.addanalyzer(bt.analyzers.Returns, _name = 'returns')
        buy_hold = cerebro.run()
        buy_hold_ret = cerebro.broker.getvalue() / starting_cash - 1
        print(f'Final Portfolio Value: {cerebro.broker.getvalue()}\n')
        print('STRATEGY INFO:')
        print(buy_hold[0].analyzers.sharpe.get_analysis())
        print(buy_hold[0].analyzers.dd.get_analysis())
        # rtot is total log returns over the strategy time period
        print(buy_hold[0].analyzers.returns.get_analysis())

        #### MAIN STRATEGY #####
        cerebro = bt.Cerebro(cheat_on_open=True)
        cerebro.broker.setcash(starting_cash)
        print(f'Starting Portfolio Value: {cerebro.broker.getvalue()}')
        data = DataFeed(dataname=prep_data[0])
        cerebro.adddata(data)
        cerebro.addstrategy(BasicStrategy)
        cerebro.addanalyzer(bt.analyzers.SharpeRatio, timeframe=bt.TimeFrame.Months, _name = 'sharpe')
        cerebro.addanalyzer(bt.analyzers.DrawDown, _name = 'dd')
        cerebro.addanalyzer(bt.analyzers.Returns, _name = 'returns')
        back = cerebro.run()
        strat_ret = cerebro.broker.getvalue() / starting_cash - 1
        print(f'Final Portfolio Value: {cerebro.broker.getvalue()}\n')
        print('STRATEGY INFO:')
        print(back[0].analyzers.sharpe.get_analysis())
        print(back[0].analyzers.dd.get_analysis())
        # rtot is total log returns over the strategy time period
        print(back[0].analyzers.returns.get_analysis())
        print(f"For {ticker_name}, return was {buy_hold_ret*100}% for buy and hold vs {strat_ret*100}%  for strategy")
        print('\n'*5)

        ticker_backtesting_dict[ticker_name] = cerebro
        
    return ticker_backtesting_dict

# %%
# pred_folder_name, pred_col_name, ticker_df_filepath, starting_cash=100000
# /Users/chris/Documents/GitHub/financial_forecasting_analysis/data/ticker_predictions/LSTM_preds

cerebro_dict = capstone_data_prep('LSTM_preds', 'prediction', f'{fileDirectory}/data/ticker_data/')
cerebro_dict
# Out:
# --------Ticker Name-------: MSFT
# BUY AND HOLD
# Starting Portfolio Value: 100000
# 2019-09-27, BUY EXECUTED, 140.15
# Stop price: 335.95001220703125
# ROI:        139.61%
# Final Portfolio Value: 239605.41305541992
#
# STRATEGY INFO:
# OrderedDict([('sharperatio', 0.5797021770069253)])
# AutoOrderedDict([('len', 1), ('drawdown', 0.3085141850586886), ('moneydown', 741.5043334960938), ('max', AutoOrderedDict([('len', 98), ('drawdown', 28.219971018038613), ('moneydown', 37988.63912963867)]))])
# OrderedDict([('rtot', 0.8738232720490078), ('ravg', 0.001630267298598895), ('rnorm', 0.5080649806090113), ('rnorm100', 50.80649806090113)])
# Starting Portfolio Value: 100000
# ***The limit sells for this strategy are valid for 1 day***
# 2019-09-26, Current Portfolio Value : 100000.0
# 2019-09-26, MARKET BUY CREATE 713 shares at next open, current close price: 139.5399932861328
# 2019-09-27, BUY EXECUTED, 140.15
# 2019-09-27, Current Portfolio Value : 98274.54130554199
# 2019-09-27, LIMIT SELL CREATE 713 shares at 139.09264229896607
# 2019-09-30, Current Portfolio Value : 99201.44348144531
# 2019-09-30, LIMIT SELL CREATE 713 shares at 140.40499712542604
# 2019-10-01, Current Portfolio Value : 97803.96957397461
# 2019-10-01, LIMIT SELL CREATE 713 shares at 138.42633124524505
# 2019-10-02, Current Portfolio Value : 96078.5
# 2019-10-02, LIMIT SELL CREATE 713 shares at 135.98448495983524
# 2019-10-03, SELL EXECUTED, 135.98
# 2019-10-03, Current Portfolio Value : 97029.99212816916
# 2019-10-03, MARKET BUY CREATE 709 shares at next open, current close price: 136.27999877929688
# 2019-10-04, BUY EXECUTED, 136.75
# 2019-10-04, Current Portfolio Value : 98001.3186662551
# 2019-10-04, LIMIT SELL CREATE 709 shares at 139.49712478451414
# 2019-10-07, Current Portfolio Value : 97292.3186662551
# 2019-10-07, LIMIT SELL CREATE 709 shares at 138.4894975079416
# 2019-10-08, Current Portfolio Value : 96264.27082995139
# 2019-10-08, LIMIT SELL CREATE 709 shares at 137.02340405535256
# 2019-10-09, SELL EXECUTED, 137.46
# 2019-10-09, Current Portfolio Value : 97533.386888301
# 2019-10-09, MARKET BUY CREATE 704 shares at next open, current close price: 138.24000549316406
# 2019-10-10, BUY EXECUTED, 138.49
# 2019-10-10, Current Portfolio Value : 97962.8273179885
# 2019-10-10, LIMIT SELL CREATE 704 shares at 140.48057033934202
# 2019-10-11, SELL EXECUTED, 140.48
# 2019-10-11, Current Portfolio Value : 98934.74454001029
# 2019-10-11, MARKET BUY CREATE 708 shares at next open, current close price: 139.67999267578125
# 2019-10-14, BUY EXECUTED, 139.69
# 2019-10-14, Current Portfolio Value : 98835.6249721392
# 2019-10-14, LIMIT SELL CREATE 708 shares at 140.93063481544758
# 2019-10-15, SELL EXECUTED, 140.93
# 2019-10-15, Current Portfolio Value : 99813.11226083155
# 2019-10-15, MARKET BUY CREATE 708 shares at next open, current close price: 141.57000732421875
# 2019-10-16, BUY EXECUTED, 140.79
# 2019-10-16, Current Portfolio Value : 99544.07960702296
# 2019-10-16, LIMIT SELL CREATE 708 shares at 141.79805110610334
# 2019-10-17, Current Portfolio Value : 99034.31874276514
# 2019-10-17, LIMIT SELL CREATE 708 shares at 141.07579162756622
# 2019-10-18, Current Portfolio Value : 97420.07960702296
# 2019-10-18, LIMIT SELL CREATE 708 shares at 138.77587480381337
# 2019-10-21, Current Portfolio Value : 98142.23182870264
# 2019-10-21, LIMIT SELL CREATE 708 shares at 139.8078249309048
# 2019-10-22, SELL EXECUTED, 139.81
# 2019-10-22, Current Portfolio Value : 99117.7370653301
# 2019-10-22, MARKET BUY CREATE 724 shares at next open, current close price: 136.3699951171875
# 2019-10-23, BUY EXECUTED, 136.88
# 2019-10-23, Current Portfolio Value : 99378.37750722464
# 2019-10-23, LIMIT SELL CREATE 724 shares at 138.61476394168017
# 2019-10-24, SELL EXECUTED, 139.39
# 2019-10-24, Current Portfolio Value : 100934.97308827932
# 2019-10-24, MARKET BUY CREATE 724 shares at next open, current close price: 139.94000244140625
# 2019-10-25, BUY EXECUTED, 139.34
# 2019-10-25, Current Portfolio Value : 101941.33264638479
# 2019-10-25, LIMIT SELL CREATE 724 shares at 142.14005390454147
# 2019-10-28, Current Portfolio Value : 104446.37750722464
# 2019-10-28, LIMIT SELL CREATE 724 shares at 145.62279746066545
# 2019-10-29, Current Portfolio Value : 103461.7370653301
# 2019-10-29, LIMIT SELL CREATE 724 shares at 144.23594356949906
# 2019-10-30, SELL EXECUTED, 144.24
# 2019-10-30, Current Portfolio Value : 104479.63888396382
# 2019-10-30, MARKET BUY CREATE 721 shares at next open, current close price: 144.61000061035156
# 2019-10-31, BUY EXECUTED, 144.90
# 2019-10-31, Current Portfolio Value : 103376.50976409078
# 2019-10-31, LIMIT SELL CREATE 721 shares at 144.79041767447632
# 2019-11-01, Current Portfolio Value : 103628.86416472554
# 2019-11-01, LIMIT SELL CREATE 721 shares at 145.14874989461612
# 2019-11-04, Current Portfolio Value : 104227.29548491597
# 2019-11-04, LIMIT SELL CREATE 721 shares at 145.98781393097354
# 2019-11-05, Current Portfolio Value : 104162.40812529683
# 2019-11-05, LIMIT SELL CREATE 721 shares at 145.89532811938693
# 2019-11-06, Current Portfolio Value : 103874.00152434468
# 2019-11-06, LIMIT SELL CREATE 721 shares at 145.48851749840878
# 2019-11-07, Current Portfolio Value : 104018.1993240273
# 2019-11-07, LIMIT SELL CREATE 721 shares at 145.6904634613436
# 2019-11-08, SELL EXECUTED, 145.69
# 2019-11-08, Current Portfolio Value : 105049.56744022733
# 2019-11-08, MARKET BUY CREATE 722 shares at next open, current close price: 145.9600067138672
# 2019-11-11, BUY EXECUTED, 145.34
# 2019-11-11, Current Portfolio Value : 105605.51052494413
# 2019-11-11, LIMIT SELL CREATE 722 shares at 147.5619345739984
# 2019-11-12, SELL EXECUTED, 147.56
# 2019-11-12, Current Portfolio Value : 106653.80684669715
# 2019-11-12, MARKET BUY CREATE 726 shares at next open, current close price: 147.07000732421875
# 2019-11-13, BUY EXECUTED, 146.74
# 2019-11-13, Current Portfolio Value : 107067.6210861991
# 2019-11-13, LIMIT SELL CREATE 726 shares at 148.77265379281812
# 2019-11-14, Current Portfolio Value : 107612.1210861991
# 2019-11-14, LIMIT SELL CREATE 726 shares at 149.5293771891633
# 2019-11-15, SELL EXECUTED, 149.53
# 2019-11-15, Current Portfolio Value : 108678.8906979926
# 2019-11-15, MARKET BUY CREATE 724 shares at next open, current close price: 149.97000122070312
# 2019-11-18, BUY EXECUTED, 150.07
# 2019-11-18, Current Portfolio Value : 108874.36274389103
# 2019-11-18, LIMIT SELL CREATE 724 shares at 151.8301430258208
# 2019-11-19, Current Portfolio Value : 108910.56495336369
# 2019-11-19, LIMIT SELL CREATE 724 shares at 151.8806468811317
# 2019-11-20, Current Portfolio Value : 108353.08186010197
# 2019-11-20, LIMIT SELL CREATE 724 shares at 151.10363900777415
# 2019-11-21, Current Portfolio Value : 108251.7223019965
# 2019-11-21, LIMIT SELL CREATE 724 shares at 150.96311450624486
# 2019-11-22, Current Portfolio Value : 108331.36274389103
# 2019-11-22, LIMIT SELL CREATE 724 shares at 151.07425866279056
# 2019-11-25, Current Portfolio Value : 109518.7223019965
# 2019-11-25, LIMIT SELL CREATE 724 shares at 152.7301404454624
# 2019-11-26, Current Portfolio Value : 110097.92451146916
# 2019-11-26, LIMIT SELL CREATE 724 shares at 153.5372755632591
# 2019-11-27, Current Portfolio Value : 110307.8906979926
# 2019-11-27, LIMIT SELL CREATE 724 shares at 153.82983845945824
# 2019-11-29, Current Portfolio Value : 109627.32893041447
# 2019-11-29, LIMIT SELL CREATE 724 shares at 152.8803393170938
# 2019-12-02, Current Portfolio Value : 108302.40760473088
# 2019-12-02, LIMIT SELL CREATE 724 shares at 151.03231871529422
# 2019-12-03, Current Portfolio Value : 108128.6436276801
# 2019-12-03, LIMIT SELL CREATE 724 shares at 150.79046061664644
# 2019-12-04, Current Portfolio Value : 108519.60981420353
# 2019-12-04, LIMIT SELL CREATE 724 shares at 151.33635552294135
# 2019-12-05, Current Portfolio Value : 108577.52009252385
# 2019-12-05, LIMIT SELL CREATE 724 shares at 151.4178055904466
# 2019-12-06, SELL EXECUTED, 151.42
# 2019-12-06, Current Portfolio Value : 109654.69664274155
# 2019-12-06, MARKET BUY CREATE 725 shares at next open, current close price: 151.75
# 2019-12-09, BUY EXECUTED, 151.07
# 2019-12-09, Current Portfolio Value : 109864.94177518784
# 2019-12-09, LIMIT SELL CREATE 725 shares at 152.86378900023527
# 2019-12-10, Current Portfolio Value : 109698.19487272202
# 2019-12-10, LIMIT SELL CREATE 725 shares at 152.6323993770834
# 2019-12-11, Current Portfolio Value : 110111.43912015854
# 2019-12-11, LIMIT SELL CREATE 725 shares at 153.20861390514543
# 2019-12-12, SELL EXECUTED, 153.21
# 2019-12-12, Current Portfolio Value : 111205.18641391338
# 2019-12-12, MARKET BUY CREATE 726 shares at next open, current close price: 153.24000549316406
# 2019-12-13, BUY EXECUTED, 153.00
# 2019-12-13, Current Portfolio Value : 112315.96552768291
# 2019-12-13, LIMIT SELL CREATE 726 shares at 156.06681831032796
# 2019-12-16, Current Portfolio Value : 113041.96552768291
# 2019-12-16, LIMIT SELL CREATE 726 shares at 157.07608273259157
# 2019-12-17, Current Portfolio Value : 112432.12818637432
# 2019-12-17, LIMIT SELL CREATE 726 shares at 156.22657020444038
# 2019-12-18, Current Portfolio Value : 112199.80286899151
# 2019-12-18, LIMIT SELL CREATE 726 shares at 155.90278755596822
# 2019-12-19, Current Portfolio Value : 113172.65128818096
# 2019-12-19, LIMIT SELL CREATE 726 shares at 157.25588614961245
# 2019-12-20, SELL EXECUTED, 157.35
# 2019-12-20, Current Portfolio Value : 114363.29084506573
# 2019-12-20, MARKET BUY CREATE 723 shares at next open, current close price: 157.41000366210938
# 2019-12-23, BUY EXECUTED, 158.12
# 2019-12-23, Current Portfolio Value : 113849.96702304424
# 2019-12-23, LIMIT SELL CREATE 723 shares at 158.97347180985378
# 2019-12-24, Current Portfolio Value : 113828.2779056126
# 2019-12-24, LIMIT SELL CREATE 723 shares at 158.9429218583319
# 2019-12-26, Current Portfolio Value : 114760.94305148663
# 2019-12-26, LIMIT SELL CREATE 723 shares at 160.24489357448903
# 2019-12-27, Current Portfolio Value : 114970.61922946514
# 2019-12-27, LIMIT SELL CREATE 723 shares at 160.53680976571428
# 2019-12-30, Current Portfolio Value : 113980.10172763409
# 2019-12-30, LIMIT SELL CREATE 723 shares at 159.15265344577097
# 2019-12-31, Current Portfolio Value : 114059.63216891827
# 2019-12-31, LIMIT SELL CREATE 723 shares at 159.26352747255604
# 2020-01-02, Current Portfolio Value : 116170.79084506573
# 2020-01-02, LIMIT SELL CREATE 723 shares at 162.21233561015333
# 2020-01-03, Current Portfolio Value : 114724.79084506573
# 2020-01-03, LIMIT SELL CREATE 723 shares at 160.1932176556055
# 2020-01-06, Current Portfolio Value : 115021.2234927708
# 2020-01-06, LIMIT SELL CREATE 723 shares at 160.61123933940513
# 2020-01-07, Current Portfolio Value : 113972.8756991917
# 2020-01-07, LIMIT SELL CREATE 723 shares at 159.1527357957911
# 2020-01-08, SELL EXECUTED, 159.15
# 2020-01-08, Current Portfolio Value : 115109.96235569613
# 2020-01-08, MARKET BUY CREATE 711 shares at next open, current close price: 160.08999633789062
# 2020-01-09, BUY EXECUTED, 161.84
# 2020-01-09, Current Portfolio Value : 115287.71235569613
# 2020-01-09, LIMIT SELL CREATE 711 shares at 163.71223349447132
# 2020-01-10, Current Portfolio Value : 114754.46235569613
# 2020-01-10, LIMIT SELL CREATE 711 shares at 162.953008336465
# 2020-01-13, Current Portfolio Value : 116133.80409153597
# 2020-01-13, LIMIT SELL CREATE 711 shares at 164.90700915054222
# 2020-01-14, Current Portfolio Value : 115316.15843113558
# 2020-01-14, LIMIT SELL CREATE 711 shares at 163.73769377408246
# 2020-01-15, SELL EXECUTED, 163.74
# 2020-01-15, Current Portfolio Value : 116459.22523282852
# 2020-01-15, MARKET BUY CREATE 708 shares at next open, current close price: 163.17999267578125
# 2020-01-16, BUY EXECUTED, 164.35
# 2020-01-16, Current Portfolio Value : 117747.77961515274
# 2020-01-16, LIMIT SELL CREATE 708 shares at 167.8109877174616
# 2020-01-17, Current Portfolio Value : 118406.22523282852
# 2020-01-17, LIMIT SELL CREATE 708 shares at 168.75145808704224
# 2020-01-21, Current Portfolio Value : 117981.42091153946
# 2020-01-21, LIMIT SELL CREATE 708 shares at 168.14976656763446
# 2020-01-22, Current Portfolio Value : 117415.01875089493
# 2020-01-22, LIMIT SELL CREATE 708 shares at 167.3464449033892
# 2020-01-23, Current Portfolio Value : 118137.18177579727
# 2020-01-23, LIMIT SELL CREATE 708 shares at 168.38099507258636
# 2020-01-24, Current Portfolio Value : 116947.7361581215
# 2020-01-24, LIMIT SELL CREATE 708 shares at 166.6891401410995
# 2020-01-27, Current Portfolio Value : 114993.66004728165
# 2020-01-27, LIMIT SELL CREATE 708 shares at 163.90674740301205
# 2020-01-28, SELL EXECUTED, 163.91
# 2020-01-28, Current Portfolio Value : 116145.39807287199
# 2020-01-28, MARKET BUY CREATE 692 shares at next open, current close price: 165.4600067138672
# 2020-01-29, BUY EXECUTED, 167.84
# 2020-01-29, Current Portfolio Value : 116283.79596105558
# 2020-01-29, LIMIT SELL CREATE 692 shares at 169.72563466379322
# 2020-01-30, SELL EXECUTED, 174.05
# 2020-01-30, Current Portfolio Value : 120442.72271886808
# 2020-01-30, MARKET BUY CREATE 699 shares at next open, current close price: 172.77999877929688
# 2020-01-31, BUY EXECUTED, 172.21
# 2020-01-31, Current Portfolio Value : 119058.69503942473
# 2020-01-31, LIMIT SELL CREATE 699 shares at 171.93029219273444
# 2020-02-03, Current Portfolio Value : 121959.55143896086
# 2020-02-03, LIMIT SELL CREATE 699 shares at 176.1248896796975
# 2020-02-04, SELL EXECUTED, 177.14
# 2020-02-04, Current Portfolio Value : 123888.78759923918
# 2020-02-04, MARKET BUY CREATE 673 shares at next open, current close price: 180.1199951171875
# 2020-02-05, BUY EXECUTED, 184.03
# 2020-02-05, Current Portfolio Value : 121109.29431310637
# 2020-02-05, LIMIT SELL CREATE 673 shares at 181.70771062833475
# 2020-02-06, SELL EXECUTED, 181.71
# 2020-02-06, Current Portfolio Value : 122325.88767364167
# 2020-02-06, MARKET BUY CREATE 668 shares at next open, current close price: 183.6300048828125
# 2020-02-07, BUY EXECUTED, 182.85
# 2020-02-07, Current Portfolio Value : 123020.6031887784
# 2020-02-07, LIMIT SELL CREATE 668 shares at 185.72863197670355
# 2020-02-10, Current Portfolio Value : 126233.68155791903
# 2020-02-10, LIMIT SELL CREATE 668 shares at 190.5762890052177
# 2020-02-11, SELL EXECUTED, 190.65
# 2020-02-11, Current Portfolio Value : 127536.27951934484
# 2020-02-11, MARKET BUY CREATE 687 shares at next open, current close price: 184.44000244140625
# 2020-02-12, BUY EXECUTED, 185.58
# 2020-02-12, Current Portfolio Value : 126938.59287383703
# 2020-02-12, LIMIT SELL CREATE 687 shares at 186.5387411508831
# 2020-02-13, Current Portfolio Value : 126251.59287383703
# 2020-02-13, LIMIT SELL CREATE 687 shares at 185.52540477362
# 2020-02-14, Current Portfolio Value : 127378.27245452549
# 2020-02-14, LIMIT SELL CREATE 687 shares at 187.1785381950965
# 2020-02-18, Current Portfolio Value : 128669.82532622959
# 2020-02-18, LIMIT SELL CREATE 687 shares at 189.07547036381527
# 2020-02-19, Current Portfolio Value : 128704.17742278722
# 2020-02-19, LIMIT SELL CREATE 687 shares at 189.12622168942187
# 2020-02-20, Current Portfolio Value : 126739.3570034757
# 2020-02-20, LIMIT SELL CREATE 687 shares at 186.24058240971536
# 2020-02-21, Current Portfolio Value : 122734.14574554113
# 2020-02-21, LIMIT SELL CREATE 687 shares at 180.35822906094847
# 2020-02-24, Current Portfolio Value : 117444.24784209875
# 2020-02-24, LIMIT SELL CREATE 687 shares at 172.58983586166562
# 2020-02-25, SELL EXECUTED, 174.20
# 2020-02-25, Current Portfolio Value : 119718.21616485265
# 2020-02-25, MARKET BUY CREATE 705 shares at next open, current close price: 168.07000732421875
# 2020-02-26, BUY EXECUTED, 169.71
# 2020-02-26, Current Portfolio Value : 120042.51014068273
# 2020-02-26, LIMIT SELL CREATE 705 shares at 171.88574379663655
# 2020-02-27, Current Portfolio Value : 111589.55626800207
# 2020-02-27, LIMIT SELL CREATE 705 shares at 159.78740137141017
# 2020-02-28, SELL EXECUTED, 159.79
# 2020-02-28, Current Portfolio Value : 112722.77939842046
# 2020-02-28, MARKET BUY CREATE 681 shares at next open, current close price: 162.00999450683594
# 2020-03-02, BUY EXECUTED, 165.31
# 2020-03-02, Current Portfolio Value : 117816.65648887456
# 2020-03-02, LIMIT SELL CREATE 681 shares at 174.53934708795668
# 2020-03-03, SELL EXECUTED, 174.54
# 2020-03-03, Current Portfolio Value : 119007.96642791662
# 2020-03-03, MARKET BUY CREATE 706 shares at next open, current close price: 164.50999450683594
# 2020-03-04, BUY EXECUTED, 168.49
# 2020-03-04, Current Portfolio Value : 120462.3247042838
# 2020-03-04, LIMIT SELL CREATE 706 shares at 172.22639017765582
# 2020-03-05, Current Portfolio Value : 117440.64556610021
# 2020-03-05, LIMIT SELL CREATE 706 shares at 167.89640345081494
# 2020-03-06, Current Portfolio Value : 114122.44772064123
# 2020-03-06, LIMIT SELL CREATE 706 shares at 163.18091329287554
# 2020-03-09, Current Portfolio Value : 106391.73910247716
# 2020-03-09, LIMIT SELL CREATE 706 shares at 152.17182274780114
# 2020-03-10, SELL EXECUTED, 158.16
# 2020-03-10, Current Portfolio Value : 111714.98513519201
# 2020-03-10, MARKET BUY CREATE 710 shares at next open, current close price: 160.9199981689453
# 2020-03-11, BUY EXECUTED, 157.13
# 2020-03-11, Current Portfolio Value : 109229.98513519201
# 2020-03-11, LIMIT SELL CREATE 710 shares at 155.23030843995846
# 2020-03-12, Current Portfolio Value : 98885.2799349967
# 2020-03-12, LIMIT SELL CREATE 710 shares at 140.48723946298688
# 2020-03-13, SELL EXECUTED, 147.50
# 2020-03-13, Current Portfolio Value : 104877.68166839513
# 2020-03-13, MARKET BUY CREATE 749 shares at next open, current close price: 158.8300018310547
# 2020-03-16, BUY EXECUTED, 140.00
# 2020-03-16, Current Portfolio Value : 101447.26029693517
# 2020-03-16, LIMIT SELL CREATE 749 shares at 136.75192192180882
# 2020-03-17, SELL EXECUTED, 140.00
# 2020-03-17, Current Portfolio Value : 104877.68166839513
# 2020-03-17, MARKET BUY CREATE 759 shares at next open, current close price: 146.57000732421875
# 2020-03-18, BUY EXECUTED, 138.00
# 2020-03-18, Current Portfolio Value : 106699.27703582677
# 2020-03-18, LIMIT SELL CREATE 759 shares at 141.8248234016591
# 2020-03-19, SELL EXECUTED, 142.77
# 2020-03-19, Current Portfolio Value : 108498.11491119298
# 2020-03-19, MARKET BUY CREATE 743 shares at next open, current close price: 142.7100067138672
# 2020-03-20, BUY EXECUTED, 146.00
# 2020-03-20, Current Portfolio Value : 102071.1694461051
# 2020-03-20, LIMIT SELL CREATE 743 shares at 138.7773247475359
# 2020-03-23, Current Portfolio Value : 101053.25173675451
# 2020-03-23, LIMIT SELL CREATE 743 shares at 137.38019806742852
# 2020-03-24, SELL EXECUTED, 143.75
# 2020-03-24, Current Portfolio Value : 106826.36491119298
# 2020-03-24, MARKET BUY CREATE 717 shares at next open, current close price: 148.33999633789062
# 2020-03-25, BUY EXECUTED, 148.91
# 2020-03-25, Current Portfolio Value : 105399.53097259435
# 2020-03-25, LIMIT SELL CREATE 717 shares at 148.4067710361198
# 2020-03-26, SELL EXECUTED, 148.41
# 2020-03-26, Current Portfolio Value : 106465.54711835846
# 2020-03-26, MARKET BUY CREATE 701 shares at next open, current close price: 156.11000061035156
# 2020-03-27, BUY EXECUTED, 151.75
# 2020-03-27, Current Portfolio Value : 105028.49497907623
# 2020-03-27, LIMIT SELL CREATE 701 shares at 151.19461004936394
# 2020-03-30, Current Portfolio Value : 112410.02412336334
# 2020-03-30, LIMIT SELL CREATE 701 shares at 161.82448222485036
# 2020-03-31, SELL EXECUTED, 161.82
# 2020-03-31, Current Portfolio Value : 113527.75915797857
# 2020-03-31, MARKET BUY CREATE 742 shares at next open, current close price: 157.7100067138672
# 2020-04-01, BUY EXECUTED, 153.00
# 2020-04-01, Current Portfolio Value : 112867.37961085943
# 2020-04-01, LIMIT SELL CREATE 742 shares at 153.65288303607008
# 2020-04-02, SELL EXECUTED, 153.65
# 2020-04-02, Current Portfolio Value : 114012.19837074257
# 2020-04-02, MARKET BUY CREATE 735 shares at next open, current close price: 155.25999450683594
# 2020-04-03, BUY EXECUTED, 155.10
# 2020-04-03, Current Portfolio Value : 113078.74523048378
# 2020-04-03, LIMIT SELL CREATE 735 shares at 155.4050432217326
# 2020-04-06, Current Portfolio Value : 121487.14702491737
# 2020-04-06, LIMIT SELL CREATE 735 shares at 166.94733540122857
# 2020-04-07, SELL EXECUTED, 169.59
# 2020-04-07, Current Portfolio Value : 124662.3411930082
# 2020-04-07, MARKET BUY CREATE 752 shares at next open, current close price: 163.49000549316406
# 2020-04-08, BUY EXECUTED, 165.67
# 2020-04-08, Current Portfolio Value : 124256.26624183632
# 2020-04-08, LIMIT SELL CREATE 752 shares at 166.7683391357176
# 2020-04-09, SELL EXECUTED, 166.77
# 2020-04-09, Current Portfolio Value : 125488.29360002096
# 2020-04-09, MARKET BUY CREATE 763 shares at next open, current close price: 165.13999938964844
# 2020-04-13, BUY EXECUTED, 164.35
# 2020-04-13, Current Portfolio Value : 126373.36475175436
# 2020-04-13, LIMIT SELL CREATE 763 shares at 167.1530504389063
# 2020-04-14, SELL EXECUTED, 169.00
# 2020-04-14, Current Portfolio Value : 129036.23894303854
# 2020-04-14, MARKET BUY CREATE 753 shares at next open, current close price: 173.6999969482422
# 2020-04-15, BUY EXECUTED, 171.20
# 2020-04-15, Current Portfolio Value : 129548.28491776998
# 2020-04-15, LIMIT SELL CREATE 753 shares at 173.60147502221406
# 2020-04-16, SELL EXECUTED, 174.30
# 2020-04-16, Current Portfolio Value : 131370.5435389858
# 2020-04-16, MARKET BUY CREATE 731 shares at next open, current close price: 177.0399932861328
# 2020-04-17, BUY EXECUTED, 179.50
# 2020-04-17, Current Portfolio Value : 130712.64800065572
# 2020-04-17, LIMIT SELL CREATE 731 shares at 180.3906485629328
# 2020-04-20, Current Portfolio Value : 128124.90175431783
# 2020-04-20, LIMIT SELL CREATE 731 shares at 176.80965627818438
# 2020-04-21, Current Portfolio Value : 122832.46889298971
# 2020-04-21, LIMIT SELL CREATE 731 shares at 169.48979134885272
# 2020-04-22, SELL EXECUTED, 171.39
# 2020-04-22, Current Portfolio Value : 125442.13309281881
# 2020-04-22, MARKET BUY CREATE 720 shares at next open, current close price: 173.52000427246094
# 2020-04-23, BUY EXECUTED, 174.11
# 2020-04-23, Current Portfolio Value : 123505.33133500631
# 2020-04-23, LIMIT SELL CREATE 720 shares at 173.13434330984097
# 2020-04-24, SELL EXECUTED, 173.13
# 2020-04-24, Current Portfolio Value : 124739.65983645119
# 2020-04-24, MARKET BUY CREATE 706 shares at next open, current close price: 174.5500030517578
# 2020-04-27, BUY EXECUTED, 176.59
# 2020-04-27, Current Portfolio Value : 122946.42457644142
# 2020-04-27, LIMIT SELL CREATE 706 shares at 175.80318873468286
# 2020-04-28, Current Portfolio Value : 119952.9806982676
# 2020-04-28, LIMIT SELL CREATE 706 shares at 171.5226254428373
# 2020-04-29, SELL EXECUTED, 173.22
# 2020-04-29, Current Portfolio Value : 122360.44328371681
# 2020-04-29, MARKET BUY CREATE 679 shares at next open, current close price: 177.42999267578125
# 2020-04-30, BUY EXECUTED, 180.00
# 2020-04-30, Current Portfolio Value : 121824.03784243263
# 2020-04-30, LIMIT SELL CREATE 679 shares at 181.00485313701452
# 2020-05-01, Current Portfolio Value : 118673.47825686134
# 2020-05-01, LIMIT SELL CREATE 679 shares at 176.3112631359489
# 2020-05-04, Current Portfolio Value : 121572.80079714455
# 2020-05-04, LIMIT SELL CREATE 679 shares at 180.61672145261667
# 2020-05-05, SELL EXECUTED, 180.62
# 2020-05-05, Current Portfolio Value : 122781.41996828713
# 2020-05-05, MARKET BUY CREATE 674 shares at next open, current close price: 180.75999450683597
# 2020-05-06, BUY EXECUTED, 182.08
# 2020-05-06, Current Portfolio Value : 123091.45420900978
# 2020-05-06, LIMIT SELL CREATE 674 shares at 184.34847376474875
# 2020-05-07, SELL EXECUTED, 184.35
# 2020-05-07, Current Portfolio Value : 124310.37005159692
# 2020-05-07, MARKET BUY CREATE 672 shares at next open, current close price: 183.6000061035156
# 2020-05-08, BUY EXECUTED, 184.98
# 2020-05-08, Current Portfolio Value : 124108.76800081569
# 2020-05-08, LIMIT SELL CREATE 672 shares at 186.52261975075896
# 2020-05-11, Current Portfolio Value : 125493.09661409695
# 2020-05-11, LIMIT SELL CREATE 672 shares at 188.6086383592047
# 2020-05-12, Current Portfolio Value : 122650.52923128445
# 2020-05-12, LIMIT SELL CREATE 672 shares at 184.34055619569705
# 2020-05-13, Current Portfolio Value : 120795.81292269069
# 2020-05-13, LIMIT SELL CREATE 672 shares at 181.5560979228609
# 2020-05-14, Current Portfolio Value : 121319.97210237819
# 2020-05-14, LIMIT SELL CREATE 672 shares at 182.34455856415715
# 2020-05-15, SELL EXECUTED, 182.34
# 2020-05-15, Current Portfolio Value : 122539.3562778043
# 2020-05-15, MARKET BUY CREATE 659 shares at next open, current close price: 183.16000366210935
# 2020-05-18, BUY EXECUTED, 185.75
# 2020-05-18, Current Portfolio Value : 121985.79869113436
# 2020-05-18, LIMIT SELL CREATE 659 shares at 186.7497781614964
# 2020-05-19, Current Portfolio Value : 121142.27949557774
# 2020-05-19, LIMIT SELL CREATE 659 shares at 185.45291088660903
# 2020-05-20, SELL EXECUTED, 185.45
# 2020-05-20, Current Portfolio Value : 122343.57455207965
# 2020-05-20, MARKET BUY CREATE 659 shares at next open, current close price: 185.66000366210935
# 2020-05-21, BUY EXECUTED, 185.40
# 2020-05-21, Current Portfolio Value : 121045.34374763627
# 2020-05-21, LIMIT SELL CREATE 659 shares at 185.25596295193037
# 2020-05-22, Current Portfolio Value : 121098.06495430133
# 2020-05-22, LIMIT SELL CREATE 659 shares at 185.34177458620127
# 2020-05-26, Current Portfolio Value : 119819.61340095659
# 2020-05-26, LIMIT SELL CREATE 659 shares at 183.3873721762958
# 2020-05-27, Current Portfolio Value : 119977.7669654097
# 2020-05-27, LIMIT SELL CREATE 659 shares at 183.62654042097145
# 2020-05-28, SELL EXECUTED, 183.63
# 2020-05-28, Current Portfolio Value : 121174.86871171661
# 2020-05-28, MARKET BUY CREATE 663 shares at next open, current close price: 181.3999938964844
# 2020-05-29, BUY EXECUTED, 182.73
# 2020-05-29, Current Portfolio Value : 121519.63154435823
# 2020-05-29, LIMIT SELL CREATE 663 shares at 185.0688911399672
# 2020-06-01, Current Portfolio Value : 121241.17275834749
# 2020-06-01, LIMIT SELL CREATE 663 shares at 184.64313568314043
# 2020-06-02, SELL EXECUTED, 184.64
# 2020-06-02, Current Portfolio Value : 122443.28050228034
# 2020-06-02, MARKET BUY CREATE 662 shares at next open, current close price: 184.91000366210935
# 2020-06-03, BUY EXECUTED, 184.82
# 2020-06-03, Current Portfolio Value : 122800.75605770027
# 2020-06-03, LIMIT SELL CREATE 662 shares at 187.21787964769945
# 2020-06-04, Current Portfolio Value : 121185.47444148932
# 2020-06-04, LIMIT SELL CREATE 662 shares at 184.76575051757123
# 2020-06-05, SELL EXECUTED, 184.77
# 2020-06-05, Current Portfolio Value : 122407.36249627967
# 2020-06-05, MARKET BUY CREATE 658 shares at next open, current close price: 187.1999969482422
# 2020-06-08, BUY EXECUTED, 185.94
# 2020-06-08, Current Portfolio Value : 123999.7212914457
# 2020-06-08, LIMIT SELL CREATE 658 shares at 190.25757815520703
# 2020-06-09, SELL EXECUTED, 190.26
# 2020-06-09, Current Portfolio Value : 125248.32731596059
# 2020-06-09, MARKET BUY CREATE 655 shares at next open, current close price: 189.8000030517578
# 2020-06-10, BUY EXECUTED, 191.13
# 2020-06-10, Current Portfolio Value : 128988.37171903678
# 2020-06-10, LIMIT SELL CREATE 655 shares at 198.80152752189036
# 2020-06-11, Current Portfolio Value : 122065.0269161803
# 2020-06-11, LIMIT SELL CREATE 655 shares at 188.13083068417825
# 2020-06-12, SELL EXECUTED, 190.54
# 2020-06-12, Current Portfolio Value : 124861.8697201354
# 2020-06-12, MARKET BUY CREATE 676 shares at next open, current close price: 187.7400054931641
# 2020-06-15, BUY EXECUTED, 184.58
# 2020-06-15, Current Portfolio Value : 127809.23013273305
# 2020-06-15, LIMIT SELL CREATE 676 shares at 190.8455444658412
# 2020-06-16, SELL EXECUTED, 192.89
# 2020-06-16, Current Portfolio Value : 130479.42806974477
# 2020-06-16, MARKET BUY CREATE 669 shares at next open, current close price: 193.57000732421875
# 2020-06-17, BUY EXECUTED, 195.03
# 2020-06-17, Current Portfolio Value : 129950.92256132193
# 2020-06-17, LIMIT SELL CREATE 669 shares at 196.197771763209
# 2020-06-18, SELL EXECUTED, 196.20
# 2020-06-18, Current Portfolio Value : 131260.668195982
# 2020-06-18, MARKET BUY CREATE 660 shares at next open, current close price: 196.32000732421875
# 2020-06-19, BUY EXECUTED, 198.59
# 2020-06-19, Current Portfolio Value : 128990.26658465387
# 2020-06-19, LIMIT SELL CREATE 660 shares at 197.09808354892837
# 2020-06-22, Current Portfolio Value : 132567.47544695856
# 2020-06-22, LIMIT SELL CREATE 660 shares at 202.56707495269228
# 2020-06-23, SELL EXECUTED, 202.57
# 2020-06-23, Current Portfolio Value : 133885.54008175107
# 2020-06-23, MARKET BUY CREATE 664 shares at next open, current close price: 201.91000366210935
# 2020-06-24, BUY EXECUTED, 201.60
# 2020-06-24, Current Portfolio Value : 131388.89359737613
# 2020-06-24, LIMIT SELL CREATE 664 shares at 199.81207500919788
# 2020-06-25, SELL EXECUTED, 199.81
# 2020-06-25, Current Portfolio Value : 132698.35383512411
# 2020-06-25, MARKET BUY CREATE 664 shares at next open, current close price: 200.33999633789065
# 2020-06-26, BUY EXECUTED, 199.73
# 2020-06-26, Current Portfolio Value : 130440.7578878585
# 2020-06-26, LIMIT SELL CREATE 664 shares at 198.29893422466964
# 2020-06-29, Current Portfolio Value : 131841.79829313196
# 2020-06-29, LIMIT SELL CREATE 664 shares at 200.4388747731891
# 2020-06-30, SELL EXECUTED, 200.44
# 2020-06-30, Current Portfolio Value : 133169.04952143575
# 2020-06-30, MARKET BUY CREATE 655 shares at next open, current close price: 203.50999450683597
# 2020-07-01, BUY EXECUTED, 203.14
# 2020-07-01, Current Portfolio Value : 134190.84792231466
# 2020-07-01, LIMIT SELL CREATE 655 shares at 206.76293480783156
# 2020-07-02, SELL EXECUTED, 206.76
# 2020-07-02, Current Portfolio Value : 135542.0722203457
# 2020-07-02, MARKET BUY CREATE 649 shares at next open, current close price: 206.25999450683597
# 2020-07-06, BUY EXECUTED, 208.83
# 2020-07-06, Current Portfolio Value : 136755.69905140038
# 2020-07-06, LIMIT SELL CREATE 649 shares at 212.8093858665565
# 2020-07-07, SELL EXECUTED, 212.81
# 2020-07-07, Current Portfolio Value : 138124.6924593864
# 2020-07-07, MARKET BUY CREATE 657 shares at next open, current close price: 208.25
# 2020-07-08, BUY EXECUTED, 210.07
# 2020-07-08, Current Portfolio Value : 139938.0088503776
# 2020-07-08, LIMIT SELL CREATE 657 shares at 214.94972513237065
# 2020-07-09, SELL EXECUTED, 216.33
# 2020-07-09, Current Portfolio Value : 142237.5088503776
# 2020-07-09, MARKET BUY CREATE 665 shares at next open, current close price: 214.32000732421875
# 2020-07-10, BUY EXECUTED, 213.62
# 2020-07-10, Current Portfolio Value : 142270.76087979655
# 2020-07-10, LIMIT SELL CREATE 665 shares at 215.793918473582
# 2020-07-13, Current Portfolio Value : 137881.7669680534
# 2020-07-13, LIMIT SELL CREATE 665 shares at 209.12697039604177
# 2020-07-14, Current Portfolio Value : 138732.96615628578
# 2020-07-14, LIMIT SELL CREATE 665 shares at 210.42690508132463
# 2020-07-15, SELL EXECUTED, 210.43
# 2020-07-15, Current Portfolio Value : 140114.1039765288
# 2020-07-15, MARKET BUY CREATE 682 shares at next open, current close price: 208.0399932861328
# 2020-07-16, BUY EXECUTED, 205.40
# 2020-07-16, Current Portfolio Value : 139104.74689034713
# 2020-07-16, LIMIT SELL CREATE 682 shares at 205.97773839909289
# 2020-07-17, Current Portfolio Value : 138395.47146920455
# 2020-07-17, LIMIT SELL CREATE 682 shares at 204.9357547593697
# 2020-07-20, Current Portfolio Value : 144342.51230172405
# 2020-07-20, LIMIT SELL CREATE 682 shares at 213.73390246423853
# 2020-07-21, SELL EXECUTED, 213.73
# 2020-07-21, Current Portfolio Value : 145797.8296197371
# 2020-07-21, MARKET BUY CREATE 696 shares at next open, current close price: 208.75
# 2020-07-22, BUY EXECUTED, 209.20
# 2020-07-22, Current Portfolio Value : 147572.63174376055
# 2020-07-22, LIMIT SELL CREATE 696 shares at 213.84691490182163
# 2020-07-23, Current Portfolio Value : 141162.46707090898
# 2020-07-23, LIMIT SELL CREATE 696 shares at 204.53444095759968
# 2020-07-24, Current Portfolio Value : 140299.43386778398
# 2020-07-24, LIMIT SELL CREATE 696 shares at 203.28291864287357
# 2020-07-27, Current Portfolio Value : 142074.2359918074
# 2020-07-27, LIMIT SELL CREATE 696 shares at 205.87399455204172
# 2020-07-28, Current Portfolio Value : 140800.55471739333
# 2020-07-28, LIMIT SELL CREATE 696 shares at 204.0537339429107
# 2020-07-29, SELL EXECUTED, 204.05
# 2020-07-29, Current Portfolio Value : 142216.03056802638
# 2020-07-29, MARKET BUY CREATE 707 shares at next open, current close price: 204.05999755859372
# 2020-07-30, BUY EXECUTED, 201.00
# 2020-07-30, Current Portfolio Value : 144266.32625284087
# 2020-07-30, LIMIT SELL CREATE 707 shares at 205.97979195820108
# 2020-07-31, Current Portfolio Value : 145051.09668435942
# 2020-07-31, LIMIT SELL CREATE 707 shares at 207.0912452346944
# 2020-08-03, Current Portfolio Value : 153202.80582132228
# 2020-08-03, LIMIT SELL CREATE 707 shares at 218.7036934046113
# 2020-08-04, Current Portfolio Value : 150905.05582132228
# 2020-08-04, LIMIT SELL CREATE 707 shares at 215.374020297076
# 2020-08-05, Current Portfolio Value : 150657.6122941006
# 2020-08-05, LIMIT SELL CREATE 707 shares at 215.0126181669005
# 2020-08-06, SELL EXECUTED, 215.01
# 2020-08-06, Current Portfolio Value : 152122.95161202503
# 2020-08-06, MARKET BUY CREATE 708 shares at next open, current close price: 216.3500061035156
# 2020-08-07, BUY EXECUTED, 214.85
# 2020-08-07, Current Portfolio Value : 150444.98426583363
# 2020-08-07, LIMIT SELL CREATE 708 shares at 214.60164783707336
# 2020-08-10, Current Portfolio Value : 147450.147290736
# 2020-08-10, LIMIT SELL CREATE 708 shares at 210.37138720490583
# 2020-08-11, Current Portfolio Value : 144002.19074776725
# 2020-08-11, LIMIT SELL CREATE 708 shares at 205.4461908711443
# 2020-08-12, SELL EXECUTED, 205.45
# 2020-08-12, Current Portfolio Value : 145465.05042750615
# 2020-08-12, MARKET BUY CREATE 694 shares at next open, current close price: 209.19000244140625
# 2020-08-13, BUY EXECUTED, 209.44
# 2020-08-13, Current Portfolio Value : 144951.4866152503
# 2020-08-13, LIMIT SELL CREATE 694 shares at 210.77193747254532
# 2020-08-14, Current Portfolio Value : 145090.2844973304
# 2020-08-14, LIMIT SELL CREATE 694 shares at 210.96576592335063
# 2020-08-17, Current Portfolio Value : 146048.00788600225
# 2020-08-17, LIMIT SELL CREATE 694 shares at 212.363853675648
# 2020-08-18, Current Portfolio Value : 146887.7525454261
# 2020-08-18, LIMIT SELL CREATE 694 shares at 213.59758047731168
# 2020-08-19, Current Portfolio Value : 145645.4866152503
# 2020-08-19, LIMIT SELL CREATE 694 shares at 211.79681564671156
# 2020-08-20, SELL EXECUTED, 211.80
# 2020-08-20, Current Portfolio Value : 147100.67879198803
# 2020-08-20, MARKET BUY CREATE 687 shares at next open, current close price: 214.5800018310547
# 2020-08-21, BUY EXECUTED, 213.86
# 2020-08-21, Current Portfolio Value : 146523.6013078571
# 2020-08-21, LIMIT SELL CREATE 687 shares at 215.16714780754816
# 2020-08-24, Current Portfolio Value : 146983.89004992257
# 2020-08-24, LIMIT SELL CREATE 687 shares at 215.8516369804535
# 2020-08-25, SELL EXECUTED, 215.85
# 2020-08-25, Current Portfolio Value : 148468.93297824805
# 2020-08-25, MARKET BUY CREATE 681 shares at next open, current close price: 216.47000122070312
# 2020-08-26, BUY EXECUTED, 217.88
# 2020-08-26, Current Portfolio Value : 150695.79549655863
# 2020-08-26, LIMIT SELL CREATE 681 shares at 223.3884114405269
# 2020-08-27, SELL EXECUTED, 223.39
# 2020-08-27, Current Portfolio Value : 152220.15784405157
# 2020-08-27, MARKET BUY CREATE 667 shares at next open, current close price: 226.5800018310547
# 2020-08-28, BUY EXECUTED, 228.18
# 2020-08-28, Current Portfolio Value : 152707.0751719324
# 2020-08-28, LIMIT SELL CREATE 667 shares at 231.19239803347853
# 2020-08-31, Current Portfolio Value : 150452.6119150965
# 2020-08-31, LIMIT SELL CREATE 667 shares at 227.75894531210628
# 2020-09-01, Current Portfolio Value : 151613.1955790369
# 2020-09-01, LIMIT SELL CREATE 667 shares at 229.500317205968
# 2020-09-02, SELL EXECUTED, 229.50
# 2020-09-02, Current Portfolio Value : 153100.81430568613
# 2020-09-02, MARKET BUY CREATE 667 shares at next open, current close price: 231.6499938964844
# 2020-09-03, BUY EXECUTED, 229.27
# 2020-09-03, Current Portfolio Value : 145116.82349147717
# 2020-09-03, LIMIT SELL CREATE 667 shares at 219.4712726768453
# 2020-09-04, Current Portfolio Value : 143082.4714559547
# 2020-09-04, LIMIT SELL CREATE 667 shares at 216.41210913566587
# 2020-09-08, Current Portfolio Value : 135351.94389858164
# 2020-09-08, LIMIT SELL CREATE 667 shares at 204.721119315731
# 2020-09-09, SELL EXECUTED, 207.60
# 2020-09-09, Current Portfolio Value : 138646.9255269996
# 2020-09-09, MARKET BUY CREATE 649 shares at next open, current close price: 211.2899932861328
# 2020-09-10, BUY EXECUTED, 213.40
# 2020-09-10, Current Portfolio Value : 133435.4563192359
# 2020-09-10, LIMIT SELL CREATE 649 shares at 207.44344174103784
# 2020-09-11, SELL EXECUTED, 207.44
# 2020-09-11, Current Portfolio Value : 134781.1231781148
# 2020-09-11, MARKET BUY CREATE 659 shares at next open, current close price: 204.02999877929688
# 2020-09-14, BUY EXECUTED, 204.24
# 2020-09-14, Current Portfolio Value : 135552.1519714497
# 2020-09-14, LIMIT SELL CREATE 659 shares at 207.44915169706047
# 2020-09-15, SELL EXECUTED, 208.42
# 2020-09-15, Current Portfolio Value : 137535.7383514546
# 2020-09-15, MARKET BUY CREATE 653 shares at next open, current close price: 208.77999877929688
# 2020-09-16, BUY EXECUTED, 210.62
# 2020-09-16, Current Portfolio Value : 133898.53353272902
# 2020-09-16, LIMIT SELL CREATE 653 shares at 207.08980970215435
# 2020-09-17, Current Portfolio Value : 132501.11393128856
# 2020-09-17, LIMIT SELL CREATE 653 shares at 204.93345236199363
# 2020-09-18, Current Portfolio Value : 130855.5511413716
# 2020-09-18, LIMIT SELL CREATE 653 shares at 202.3968502726369
# 2020-09-21, Current Portfolio Value : 132259.4971557759
# 2020-09-21, LIMIT SELL CREATE 653 shares at 204.5799859011645
# 2020-09-22, SELL EXECUTED, 205.06
# 2020-09-22, Current Portfolio Value : 133905.05994569286
# 2020-09-22, MARKET BUY CREATE 644 shares at next open, current close price: 207.4199981689453
# 2020-09-23, BUY EXECUTED, 207.90
# 2020-09-23, Current Portfolio Value : 129197.42151795846
# 2020-09-23, LIMIT SELL CREATE 644 shares at 202.6126555186196
# 2020-09-24, SELL EXECUTED, 202.61
# 2020-09-24, Current Portfolio Value : 130500.01403034793
# 2020-09-24, MARKET BUY CREATE 641 shares at next open, current close price: 203.19000244140625
# 2020-09-25, BUY EXECUTED, 203.55
# 2020-09-25, Current Portfolio Value : 133237.0867689954
# 2020-09-25, LIMIT SELL CREATE 641 shares at 209.8987443528249
# 2020-09-28, Current Portfolio Value : 134275.50363911258
# 2020-09-28, LIMIT SELL CREATE 641 shares at 211.52800393120245
# 2020-09-29, Current Portfolio Value : 132878.11855305303
# 2020-09-29, LIMIT SELL CREATE 641 shares at 209.3214781673265
# 2020-09-30, SELL EXECUTED, 209.32
# 2020-09-30, Current Portfolio Value : 134199.52957942744
# 2020-09-30, MARKET BUY CREATE 628 shares at next open, current close price: 210.3300018310547
# 2020-10-01, BUY EXECUTED, 213.49
# 2020-10-01, Current Portfolio Value : 133552.69034602898
# 2020-10-01, LIMIT SELL CREATE 628 shares at 214.57550032227988
# 2020-10-02, Current Portfolio Value : 129615.12766292352
# 2020-10-02, LIMIT SELL CREATE 628 shares at 208.24563065204052
# 2020-10-05, Current Portfolio Value : 132246.44919612663
# 2020-10-05, LIMIT SELL CREATE 628 shares at 212.48655427622205
# 2020-10-06, Current Portfolio Value : 129439.28842952507
# 2020-10-06, LIMIT SELL CREATE 628 shares at 207.9831328086653
# 2020-10-07, SELL EXECUTED, 207.98
# 2020-10-07, Current Portfolio Value : 130741.2135335622
# 2020-10-07, MARKET BUY CREATE 621 shares at next open, current close price: 209.8300018310547
# 2020-10-08, BUY EXECUTED, 210.51
# 2020-10-08, Current Portfolio Value : 130784.68808190203
# 2020-10-08, LIMIT SELL CREATE 621 shares at 212.7135821341569
# 2020-10-09, SELL EXECUTED, 212.71
# 2020-10-09, Current Portfolio Value : 132109.64145012852
# 2020-10-09, MARKET BUY CREATE 603 shares at next open, current close price: 215.80999755859372
# 2020-10-12, BUY EXECUTED, 218.79
# 2020-10-12, Current Portfolio Value : 133683.47181817054
# 2020-10-12, LIMIT SELL CREATE 603 shares at 223.62112807911407
# 2020-10-13, SELL EXECUTED, 223.62
# 2020-10-13, Current Portfolio Value : 135022.81573029622
# 2020-10-13, MARKET BUY CREATE 605 shares at next open, current close price: 222.8600006103516
# 2020-10-14, BUY EXECUTED, 223.00
# 2020-10-14, Current Portfolio Value : 133728.11609955895
# 2020-10-14, LIMIT SELL CREATE 605 shares at 223.04567961953333
# 2020-10-15, Current Portfolio Value : 133002.11794587236
# 2020-10-15, LIMIT SELL CREATE 605 shares at 221.83736105561115
# 2020-10-16, SELL EXECUTED, 221.84
# 2020-10-16, Current Portfolio Value : 134319.41916894098
# 2020-10-16, MARKET BUY CREATE 609 shares at next open, current close price: 219.66000366210935
# 2020-10-19, BUY EXECUTED, 220.42
# 2020-10-19, Current Portfolio Value : 130543.62102746149
# 2020-10-19, LIMIT SELL CREATE 609 shares at 216.36399001779304
# 2020-10-20, SELL EXECUTED, 216.36
# 2020-10-20, Current Portfolio Value : 131849.31020488925
# 2020-10-20, MARKET BUY CREATE 618 shares at next open, current close price: 214.6499938964844
# 2020-10-21, BUY EXECUTED, 213.12
# 2020-10-21, Current Portfolio Value : 132887.5551084537
# 2020-10-21, LIMIT SELL CREATE 618 shares at 216.96017550239264
# 2020-10-22, Current Portfolio Value : 132943.1728452701
# 2020-10-22, LIMIT SELL CREATE 618 shares at 217.03801854832503
# 2020-10-23, Current Portfolio Value : 133771.29058208648
# 2020-10-23, LIMIT SELL CREATE 618 shares at 218.379572447413
# 2020-10-26, Current Portfolio Value : 129970.59435405917
# 2020-10-26, LIMIT SELL CREATE 618 shares at 212.16708366934645
# 2020-10-27, SELL EXECUTED, 212.17
# 2020-10-27, Current Portfolio Value : 131260.41093012347
# 2020-10-27, MARKET BUY CREATE 632 shares at next open, current close price: 213.25
# 2020-10-28, BUY EXECUTED, 207.67
# 2020-10-28, Current Portfolio Value : 128106.72745844378
# 2020-10-28, LIMIT SELL CREATE 632 shares at 204.7090274263604
# 2020-10-29, SELL EXECUTED, 204.71
# 2020-10-29, Current Portfolio Value : 129389.0774208098
# 2020-10-29, MARKET BUY CREATE 635 shares at next open, current close price: 204.72000122070312
# 2020-10-30, BUY EXECUTED, 203.50
# 2020-10-30, Current Portfolio Value : 128735.02819595629
# 2020-10-30, LIMIT SELL CREATE 635 shares at 204.51811337457428
# 2020-11-02, Current Portfolio Value : 128646.12858352953
# 2020-11-02, LIMIT SELL CREATE 635 shares at 204.37904578798376
# 2020-11-03, SELL EXECUTED, 204.38
# 2020-11-03, Current Portfolio Value : 129947.27149617948
# 2020-11-03, MARKET BUY CREATE 607 shares at next open, current close price: 206.42999267578125
# 2020-11-04, BUY EXECUTED, 214.02
# 2020-11-04, Current Portfolio Value : 131385.85853231233
# 2020-11-04, LIMIT SELL CREATE 607 shares at 218.57141439275708
# 2020-11-05, SELL EXECUTED, 222.04
# 2020-11-05, Current Portfolio Value : 134815.40482747834
# 2020-11-05, MARKET BUY CREATE 606 shares at next open, current close price: 223.2899932861328
# 2020-11-06, BUY EXECUTED, 222.26
# 2020-11-06, Current Portfolio Value : 135700.16889608183
# 2020-11-06, LIMIT SELL CREATE 606 shares at 225.9617305423673
# 2020-11-09, Current Portfolio Value : 132470.1877864627
# 2020-11-09, LIMIT SELL CREATE 606 shares at 220.5742131966264
# 2020-11-10, Current Portfolio Value : 127997.90482747831
# 2020-11-10, LIMIT SELL CREATE 606 shares at 213.11788823952136
# 2020-11-11, SELL EXECUTED, 213.12
# 2020-11-11, Current Portfolio Value : 129275.28842948569
# 2020-11-11, MARKET BUY CREATE 595 shares at next open, current close price: 216.5500030517578
# 2020-11-12, BUY EXECUTED, 217.21
# 2020-11-12, Current Portfolio Value : 128222.13588737143
# 2020-11-12, LIMIT SELL CREATE 595 shares at 217.59131793007688
# 2020-11-13, Current Portfolio Value : 128858.78116630211
# 2020-11-13, LIMIT SELL CREATE 595 shares at 218.67451225259745
# 2020-11-16, Current Portfolio Value : 129287.18189262044
# 2020-11-16, LIMIT SELL CREATE 595 shares at 219.4031297883048
# 2020-11-17, Current Portfolio Value : 127639.03842948569
# 2020-11-17, LIMIT SELL CREATE 595 shares at 216.60657228570963
# 2020-11-18, Current Portfolio Value : 125627.93552421225
# 2020-11-18, LIMIT SELL CREATE 595 shares at 213.19393146409303
# 2020-11-19, Current Portfolio Value : 126425.23334525718
# 2020-11-19, LIMIT SELL CREATE 595 shares at 214.54768814528992
# 2020-11-20, Current Portfolio Value : 125217.38407157554
# 2020-11-20, LIMIT SELL CREATE 595 shares at 212.4968567214776
# 2020-11-23, Current Portfolio Value : 125050.78479789391
# 2020-11-23, LIMIT SELL CREATE 595 shares at 212.21262929622057
# 2020-11-24, SELL EXECUTED, 212.21
# 2020-11-24, Current Portfolio Value : 126301.84886598596
# 2020-11-24, MARKET BUY CREATE 587 shares at next open, current close price: 213.8600006103516
# 2020-11-25, BUY EXECUTED, 215.11
# 2020-11-25, Current Portfolio Value : 125573.96564149864
# 2020-11-25, LIMIT SELL CREATE 587 shares at 216.00367131832968
# 2020-11-27, Current Portfolio Value : 126372.28599977499
# 2020-11-27, LIMIT SELL CREATE 587 shares at 217.3738855764909
# 2020-11-30, Current Portfolio Value : 125691.37280702598
# 2020-11-30, LIMIT SELL CREATE 587 shares at 216.2001019475492
# 2020-12-01, SELL EXECUTED, 216.20
# 2020-12-01, Current Portfolio Value : 126941.73835092096
# 2020-12-01, MARKET BUY CREATE 590 shares at next open, current close price: 216.2100067138672
# 2020-12-02, BUY EXECUTED, 214.88
# 2020-12-02, Current Portfolio Value : 127230.83258920221
# 2020-12-02, LIMIT SELL CREATE 590 shares at 217.51952368213196
# 2020-12-03, Current Portfolio Value : 126564.1387110284
# 2020-12-03, LIMIT SELL CREATE 590 shares at 216.3787794427661
# 2020-12-04, Current Portfolio Value : 126634.93583016902
# 2020-12-04, LIMIT SELL CREATE 590 shares at 216.498248021606
# 2020-12-07, Current Portfolio Value : 126593.63150887995
# 2020-12-07, LIMIT SELL CREATE 590 shares at 216.42529962220905
# 2020-12-08, SELL EXECUTED, 216.43
# 2020-12-08, Current Portfolio Value : 127853.46224716493
# 2020-12-08, MARKET BUY CREATE 594 shares at next open, current close price: 216.00999450683597
# 2020-12-09, BUY EXECUTED, 215.16
# 2020-12-09, Current Portfolio Value : 125857.62188461612
# 2020-12-09, LIMIT SELL CREATE 594 shares at 213.91174769087144
# 2020-12-10, Current Portfolio Value : 125097.30260971376
# 2020-12-10, LIMIT SELL CREATE 594 shares at 212.62623115117665
# 2020-12-11, SELL EXECUTED, 212.63
# 2020-12-11, Current Portfolio Value : 126348.40137567092
# 2020-12-11, MARKET BUY CREATE 592 shares at next open, current close price: 213.25999450683597
# 2020-12-14, BUY EXECUTED, 213.10
# 2020-12-14, Current Portfolio Value : 126999.59595574906
# 2020-12-14, LIMIT SELL CREATE 592 shares at 216.3561667786615
# 2020-12-15, Current Portfolio Value : 126958.16065301468
# 2020-12-15, LIMIT SELL CREATE 592 shares at 216.28402658334716
# 2020-12-16, SELL EXECUTED, 216.28
# 2020-12-16, Current Portfolio Value : 128233.3414997312
# 2020-12-16, MARKET BUY CREATE 583 shares at next open, current close price: 219.27999877929688
# 2020-12-17, BUY EXECUTED, 219.87
# 2020-12-17, Current Portfolio Value : 127970.99327890601
# 2020-12-17, LIMIT SELL CREATE 583 shares at 221.61607449483057
# 2020-12-18, Current Portfolio Value : 127487.10221140114
# 2020-12-18, LIMIT SELL CREATE 583 shares at 220.77301435918775
# 2020-12-21, Current Portfolio Value : 129819.10221140114
# 2020-12-21, LIMIT SELL CREATE 583 shares at 224.81111386524188
# 2020-12-22, SELL EXECUTED, 224.81
# 2020-12-22, Current Portfolio Value : 131114.01372984692
# 2020-12-22, MARKET BUY CREATE 587 shares at next open, current close price: 223.94000244140625
# 2020-12-23, BUY EXECUTED, 223.11
# 2020-12-23, Current Portfolio Value : 129887.1858795051
# 2020-12-23, LIMIT SELL CREATE 587 shares at 223.2321052639743
# 2020-12-24, SELL EXECUTED, 223.23
# 2020-12-24, Current Portfolio Value : 131185.68916152345
# 2020-12-24, MARKET BUY CREATE 584 shares at next open, current close price: 222.75
# 2020-12-28, BUY EXECUTED, 224.45
# 2020-12-28, Current Portfolio Value : 131483.53486464845
# 2020-12-28, LIMIT SELL CREATE 584 shares at 227.20793635580767
# 2020-12-29, Current Portfolio Value : 131010.4873792969
# 2020-12-29, LIMIT SELL CREATE 584 shares at 226.38700396957972
# 2020-12-30, Current Portfolio Value : 129568.00666640626
# 2020-12-30, LIMIT SELL CREATE 584 shares at 223.88929571426013
# 2020-12-31, Current Portfolio Value : 130000.16987441407
# 2020-12-31, LIMIT SELL CREATE 584 shares at 224.63636626069143
# 2021-01-04, Current Portfolio Value : 127237.85236953126
# 2021-01-04, LIMIT SELL CREATE 584 shares at 219.86088289445877
# 2021-01-05, Current Portfolio Value : 127360.4873792969
# 2021-01-05, LIMIT SELL CREATE 584 shares at 220.07588490414813
# 2021-01-06, Current Portfolio Value : 124060.89094375001
# 2021-01-06, LIMIT SELL CREATE 584 shares at 214.3708169998096
# 2021-01-07, SELL EXECUTED, 214.37
# 2021-01-07, Current Portfolio Value : 125299.4480716388
# ...
# 2021-06-23, LIMIT SELL CREATE 1522 shares at 64.53621865010481
# 2021-06-24, SELL EXECUTED, 64.54
# 2021-06-24, Current Portfolio Value : 98228.34857138067
# 2021-06-24, MARKET BUY CREATE 1520 shares at next open, current close price: 64.5199966430664
# 2021-06-25, BUY EXECUTED, 64.61
# 2021-06-25, Current Portfolio Value : 98304.35321005255
# 2021-06-25, LIMIT SELL CREATE 1520 shares at 64.93538002356571
# 2021-06-28, Current Portfolio Value : 95796.34509237677
# 2021-06-28, LIMIT SELL CREATE 1520 shares at 63.277433817445335
# 2021-06-29, SELL EXECUTED, 63.28
# 2021-06-29, Current Portfolio Value : 96202.84704616321
# 2021-06-29, MARKET BUY CREATE 1534 shares at next open, current close price: 62.619998931884766
# 2021-06-30, BUY EXECUTED, 62.70
# 2021-06-30, Current Portfolio Value : 96785.76868465198
# 2021-06-30, LIMIT SELL CREATE 1534 shares at 63.34604066307825
# 2021-07-01, SELL EXECUTED, 64.33
# 2021-07-01, Current Portfolio Value : 98703.26868465198
# 2021-07-01, MARKET BUY CREATE 1566 shares at next open, current close price: 63.2599983215332
# 2021-07-02, BUY EXECUTED, 63.01
# 2021-07-02, Current Portfolio Value : 98953.82844569934
# 2021-07-02, LIMIT SELL CREATE 1566 shares at 63.43605943268584
# 2021-07-06, Current Portfolio Value : 96135.02964046253
# 2021-07-06, LIMIT SELL CREATE 1566 shares at 61.6294934846754
# 2021-07-07, SELL EXECUTED, 61.63
# 2021-07-07, Current Portfolio Value : 96541.39811013266
# 2021-07-07, MARKET BUY CREATE 1623 shares at next open, current close price: 60.40999984741211
# 2021-07-08, BUY EXECUTED, 59.45
# 2021-07-08, Current Portfolio Value : 97661.26588128135
# 2021-07-08, LIMIT SELL CREATE 1623 shares at 60.39725901531945
# 2021-07-09, SELL EXECUTED, 60.70
# 2021-07-09, Current Portfolio Value : 98570.14811013266
# 2021-07-09, MARKET BUY CREATE 1631 shares at next open, current close price: 61.22999954223633
# 2021-07-12, BUY EXECUTED, 60.42
# 2021-07-12, Current Portfolio Value : 99793.39811013266
# 2021-07-12, LIMIT SELL CREATE 1631 shares at 61.42927230613462
# 2021-07-13, SELL EXECUTED, 61.43
# 2021-07-13, Current Portfolio Value : 100216.27422788843
# 2021-07-13, MARKET BUY CREATE 1638 shares at next open, current close price: 60.880001068115234
# 2021-07-14, BUY EXECUTED, 61.17
# 2021-07-14, Current Portfolio Value : 97529.9552276443
# 2021-07-14, LIMIT SELL CREATE 1638 shares at 59.77458807400292
# 2021-07-15, Current Portfolio Value : 96579.91847685083
# 2021-07-15, LIMIT SELL CREATE 1638 shares at 59.19311837243422
# 2021-07-16, SELL EXECUTED, 59.19
# 2021-07-16, Current Portfolio Value : 96978.14512120326
# 2021-07-16, MARKET BUY CREATE 1742 shares at next open, current close price: 57.31999969482422
# 2021-07-19, BUY EXECUTED, 55.64
# 2021-07-19, Current Portfolio Value : 96472.96352635461
# 2021-07-19, LIMIT SELL CREATE 1742 shares at 55.58390476568708
# 2021-07-20, SELL EXECUTED, 55.58
# 2021-07-20, Current Portfolio Value : 96880.42828626257
# 2021-07-20, MARKET BUY CREATE 1703 shares at next open, current close price: 55.959999084472656
# 2021-07-21, BUY EXECUTED, 56.86
# 2021-07-21, Current Portfolio Value : 98413.1243884049
# 2021-07-21, LIMIT SELL CREATE 1703 shares at 58.00795917815717
# 2021-07-22, Current Portfolio Value : 97306.17828626257
# 2021-07-22, LIMIT SELL CREATE 1703 shares at 57.352631287421495
# 2021-07-23, Current Portfolio Value : 97186.96880597693
# 2021-07-23, LIMIT SELL CREATE 1703 shares at 57.28116147288103
# 2021-07-26, Current Portfolio Value : 99639.28646726233
# 2021-07-26, LIMIT SELL CREATE 1703 shares at 58.72620628410375
# 2021-07-27, Current Portfolio Value : 98532.34036511999
# 2021-07-27, LIMIT SELL CREATE 1703 shares at 58.07204984619971
# 2021-07-28, SELL EXECUTED, 58.07
# 2021-07-28, Current Portfolio Value : 98944.54813491197
# 2021-07-28, MARKET BUY CREATE 1677 shares at next open, current close price: 58.220001220703125
# 2021-07-29, BUY EXECUTED, 59.00
# 2021-07-29, Current Portfolio Value : 98827.15864669175
# 2021-07-29, LIMIT SELL CREATE 1677 shares at 59.173500493462136
# 2021-07-30, Current Portfolio Value : 96546.43762313218
# 2021-07-30, LIMIT SELL CREATE 1677 shares at 57.80745098445105
# 2021-08-02, Current Portfolio Value : 96563.21120559068
# 2021-08-02, LIMIT SELL CREATE 1677 shares at 57.81802535424638
# 2021-08-03, SELL EXECUTED, 57.82
# 2021-08-03, Current Portfolio Value : 96962.37665398314
# 2021-08-03, MARKET BUY CREATE 1695 shares at next open, current close price: 58.20000076293945
# 2021-08-04, BUY EXECUTED, 57.19
# 2021-08-04, Current Portfolio Value : 96369.1292403479
# 2021-08-04, LIMIT SELL CREATE 1695 shares at 57.07656407883953
# 2021-08-05, SELL EXECUTED, 57.13
# 2021-08-05, Current Portfolio Value : 96860.68079216675
# 2021-08-05, MARKET BUY CREATE 1679 shares at next open, current close price: 57.20000076293945
# 2021-08-06, BUY EXECUTED, 57.66
# 2021-08-06, Current Portfolio Value : 97196.48207314209
# 2021-08-06, LIMIT SELL CREATE 1679 shares at 58.099666007451056
# 2021-08-09, Current Portfolio Value : 96088.34232933716
# 2021-08-09, LIMIT SELL CREATE 1679 shares at 57.43567026770884
# 2021-08-10, SELL EXECUTED, 57.44
# 2021-08-10, Current Portfolio Value : 96484.03142784497
# 2021-08-10, MARKET BUY CREATE 1658 shares at next open, current close price: 58.18000030517578
# 2021-08-11, BUY EXECUTED, 58.19
# 2021-08-11, Current Portfolio Value : 96749.31117485424
# 2021-08-11, LIMIT SELL CREATE 1658 shares at 58.5850434242823
# 2021-08-12, Current Portfolio Value : 95091.31117485424
# 2021-08-12, LIMIT SELL CREATE 1658 shares at 57.579810135791966
# 2021-08-13, Current Portfolio Value : 94129.67446373365
# 2021-08-13, LIMIT SELL CREATE 1658 shares at 56.997609075166366
# 2021-08-16, Current Portfolio Value : 92753.53142784497
# 2021-08-16, LIMIT SELL CREATE 1658 shares at 56.1658342798667
# 2021-08-17, SELL EXECUTED, 56.17
# 2021-08-17, Current Portfolio Value : 93127.96694078048
# 2021-08-17, MARKET BUY CREATE 1680 shares at next open, current close price: 55.560001373291016
# 2021-08-18, BUY EXECUTED, 55.42
# 2021-08-18, Current Portfolio Value : 91397.56899156173
# 2021-08-18, LIMIT SELL CREATE 1680 shares at 54.61770085773462
# 2021-08-19, Current Portfolio Value : 88608.76924790938
# 2021-08-19, LIMIT SELL CREATE 1680 shares at 52.95265498282709
# 2021-08-20, SELL EXECUTED, 52.95
# 2021-08-20, Current Portfolio Value : 88982.83038810187
# 2021-08-20, MARKET BUY CREATE 1649 shares at next open, current close price: 52.7400016784668
# 2021-08-23, BUY EXECUTED, 53.95
# 2021-08-23, Current Portfolio Value : 90565.86887839728
# 2021-08-23, LIMIT SELL CREATE 1649 shares at 55.14142773961793
# 2021-08-24, SELL EXECUTED, 55.29
# 2021-08-24, Current Portfolio Value : 91192.4906397193
# 2021-08-24, MARKET BUY CREATE 1650 shares at next open, current close price: 55.36000061035156
# 2021-08-25, BUY EXECUTED, 55.24
# 2021-08-25, Current Portfolio Value : 91555.48635962897
# 2021-08-25, LIMIT SELL CREATE 1650 shares at 55.68726128632285
# 2021-08-26, Current Portfolio Value : 90317.98635962897
# 2021-08-26, LIMIT SELL CREATE 1650 shares at 54.93281310506429
# 2021-08-27, SELL EXECUTED, 55.40
# 2021-08-27, Current Portfolio Value : 91456.49038794928
# 2021-08-27, MARKET BUY CREATE 1626 shares at next open, current close price: 55.77000045776367
# 2021-08-30, BUY EXECUTED, 56.24
# 2021-08-30, Current Portfolio Value : 89700.40741065436
# 2021-08-30, LIMIT SELL CREATE 1626 shares at 55.38623927210739
# 2021-08-31, Current Portfolio Value : 88659.768403086
# 2021-08-31, LIMIT SELL CREATE 1626 shares at 54.74474855566653
# 2021-09-01, SELL EXECUTED, 54.74
# 2021-09-01, Current Portfolio Value : 89025.20881027605
# 2021-09-01, MARKET BUY CREATE 1639 shares at next open, current close price: 53.77000045776367
# 2021-09-02, BUY EXECUTED, 54.29
# 2021-09-02, Current Portfolio Value : 90320.02031082536
# 2021-09-02, LIMIT SELL CREATE 1639 shares at 55.309833990784256
# 2021-09-03, SELL EXECUTED, 55.31
# 2021-09-03, Current Portfolio Value : 90696.71522062212
# 2021-09-03, MARKET BUY CREATE 1658 shares at next open, current close price: 54.869998931884766
# 2021-09-07, BUY EXECUTED, 54.67
# 2021-09-07, Current Portfolio Value : 90497.75699155718
# 2021-09-07, LIMIT SELL CREATE 1658 shares at 54.77755861960704
# 2021-09-08, SELL EXECUTED, 54.79
# 2021-09-08, Current Portfolio Value : 90895.67977445513
# 2021-09-08, MARKET BUY CREATE 1695 shares at next open, current close price: 54.04999923706055
# 2021-09-09, BUY EXECUTED, 53.62
# 2021-09-09, Current Portfolio Value : 91692.33184354693
# 2021-09-09, LIMIT SELL CREATE 1695 shares at 54.31140803773604
# 2021-09-10, SELL EXECUTED, 55.19
# 2021-09-10, Current Portfolio Value : 93556.82925718217
# 2021-09-10, MARKET BUY CREATE 1711 shares at next open, current close price: 53.97999954223633
# 2021-09-13, BUY EXECUTED, 54.65
# 2021-09-13, Current Portfolio Value : 94788.74481885819
# 2021-09-13, LIMIT SELL CREATE 1711 shares at 55.594183694759856
# 2021-09-14, SELL EXECUTED, 55.69
# 2021-09-14, Current Portfolio Value : 95336.26429670241
# 2021-09-14, MARKET BUY CREATE 1721 shares at next open, current close price: 54.58000183105469
# 2021-09-15, BUY EXECUTED, 55.37
# 2021-09-15, Current Portfolio Value : 97143.31298368362
# 2021-09-15, LIMIT SELL CREATE 1721 shares at 56.64766102937445
# 2021-09-16, Current Portfolio Value : 96110.71560972121
# 2021-09-16, LIMIT SELL CREATE 1721 shares at 56.04572421454384
# 2021-09-17, SELL EXECUTED, 56.05
# 2021-09-17, Current Portfolio Value : 96499.18750815868
# 2021-09-17, MARKET BUY CREATE 1794 shares at next open, current close price: 55.15999984741211
# 2021-09-20, BUY EXECUTED, 53.78
# 2021-09-20, Current Portfolio Value : 96337.72723441597
# 2021-09-20, LIMIT SELL CREATE 1794 shares at 53.90857441397755
# 2021-09-21, SELL EXECUTED, 54.37
# 2021-09-21, Current Portfolio Value : 97557.64778190134
# 2021-09-21, MARKET BUY CREATE 1792 shares at next open, current close price: 53.63999938964844
# 2021-09-22, BUY EXECUTED, 54.43
# 2021-09-22, Current Portfolio Value : 98955.40559440134
# 2021-09-22, LIMIT SELL CREATE 1792 shares at 55.436373041580055
# 2021-09-23, SELL EXECUTED, 55.44
# 2021-09-23, Current Portfolio Value : 99361.0677255378
# 2021-09-23, MARKET BUY CREATE 1752 shares at next open, current close price: 57.08000183105469
# 2021-09-24, BUY EXECUTED, 56.70
# 2021-09-24, Current Portfolio Value : 100920.34665620186
# 2021-09-24, LIMIT SELL CREATE 1752 shares at 57.82537541335378
# 2021-09-27, Current Portfolio Value : 103916.26505219795
# 2021-09-27, LIMIT SELL CREATE 1752 shares at 59.54218617239961
# 2021-09-28, SELL EXECUTED, 59.90
# 2021-09-28, Current Portfolio Value : 104967.46906220772
# 2021-09-28, MARKET BUY CREATE 1754 shares at next open, current close price: 59.91999816894531
# 2021-09-29, BUY EXECUTED, 59.84
# 2021-09-29, Current Portfolio Value : 105037.63066804268
# 2021-09-29, LIMIT SELL CREATE 1754 shares at 60.1244540614068
# 2021-09-30, SELL EXECUTED, 60.12
# 2021-09-30, Current Portfolio Value : 105466.40121827609
# 2021-09-30, MARKET BUY CREATE 1775 shares at next open, current close price: 58.81999969482422
# 2021-10-01, BUY EXECUTED, 59.41
# 2021-10-01, Current Portfolio Value : 108164.40203080661
# 2021-10-01, LIMIT SELL CREATE 1775 shares at 61.175769774709
# 2021-10-04, Current Portfolio Value : 109566.65365586765
# 2021-10-04, LIMIT SELL CREATE 1775 shares at 61.964330966363946
# 2021-10-05, SELL EXECUTED, 62.52
# 2021-10-05, Current Portfolio Value : 110986.65230165012
# 2021-10-05, MARKET BUY CREATE 1835 shares at next open, current close price: 61.619998931884766
# 2021-10-06, BUY EXECUTED, 60.47
# 2021-10-06, Current Portfolio Value : 111023.35314164645
# 2021-10-06, LIMIT SELL CREATE 1835 shares at 60.72715418304514
# 2021-10-07, SELL EXECUTED, 60.73
# 2021-10-07, Current Portfolio Value : 111458.52798754771
# 2021-10-07, MARKET BUY CREATE 1819 shares at next open, current close price: 60.65999984741211
# 2021-10-08, BUY EXECUTED, 61.25
# 2021-10-08, Current Portfolio Value : 113150.19854266246
# 2021-10-08, LIMIT SELL CREATE 1819 shares at 62.43849532759052
# 2021-10-11, Current Portfolio Value : 112022.42048556407
# 2021-10-11, LIMIT SELL CREATE 1819 shares at 61.822162933496095
# 2021-10-12, SELL EXECUTED, 61.82
# 2021-10-12, Current Portfolio Value : 112499.29236357711
# 2021-10-12, MARKET BUY CREATE 1850 shares at next open, current close price: 61.2400016784668
# 2021-10-13, BUY EXECUTED, 60.78
# 2021-10-13, Current Portfolio Value : 113035.79405730269
# 2021-10-13, LIMIT SELL CREATE 1850 shares at 61.3181974362117
# 2021-10-14, SELL EXECUTED, 61.71
# 2021-10-14, Current Portfolio Value : 114219.7929281523
# 2021-10-14, MARKET BUY CREATE 1820 shares at next open, current close price: 62.0
# 2021-10-15, BUY EXECUTED, 62.73
# 2021-10-15, Current Portfolio Value : 113964.99403899214
# 2021-10-15, LIMIT SELL CREATE 1820 shares at 62.81639353862267
# 2021-10-18, Current Portfolio Value : 113910.39626067183
# 2021-10-18, LIMIT SELL CREATE 1820 shares at 62.77308088330712
# 2021-10-19, SELL EXECUTED, 62.87
# 2021-10-19, Current Portfolio Value : 114474.59181731245
# 2021-10-19, MARKET BUY CREATE 1820 shares at next open, current close price: 63.5
# 2021-10-20, BUY EXECUTED, 62.89
# 2021-10-20, Current Portfolio Value : 116221.79015105267
# 2021-10-20, LIMIT SELL CREATE 1820 shares at 64.04349433001533
# 2021-10-21, Current Portfolio Value : 114110.59042876263
# 2021-10-21, LIMIT SELL CREATE 1820 shares at 62.87786707407176
# 2021-10-22, SELL EXECUTED, 62.88
# 2021-10-22, Current Portfolio Value : 114452.5110029629
# 2021-10-22, MARKET BUY CREATE 1796 shares at next open, current close price: 63.119998931884766
# 2021-10-25, BUY EXECUTED, 63.72
# 2021-10-25, Current Portfolio Value : 115583.98607010157
# 2021-10-25, LIMIT SELL CREATE 1796 shares at 64.5679336305315
# 2021-10-26, SELL EXECUTED, 64.57
# 2021-10-26, Current Portfolio Value : 115975.39761101466
# 2021-10-26, MARKET BUY CREATE 1779 shares at next open, current close price: 65.83999633789062
# 2021-10-27, BUY EXECUTED, 65.16
# 2021-10-27, Current Portfolio Value : 114143.01620995265
# 2021-10-27, LIMIT SELL CREATE 1779 shares at 64.39503303014544
# 2021-10-28, SELL EXECUTED, 64.40
# 2021-10-28, Current Portfolio Value : 114614.51485675083
# 2021-10-28, MARKET BUY CREATE 1761 shares at next open, current close price: 64.30999755859375
# 2021-10-29, BUY EXECUTED, 65.05
# 2021-10-29, Current Portfolio Value : 113593.13163226352
# 2021-10-29, LIMIT SELL CREATE 1761 shares at 64.76607644964132
# 2021-11-01, Current Portfolio Value : 115635.88464587436
# 2021-11-01, LIMIT SELL CREATE 1761 shares at 65.9372803157876
# 2021-11-02, Current Portfolio Value : 114209.47894519077
# 2021-11-02, LIMIT SELL CREATE 1761 shares at 65.11985336273305
# 2021-11-03, Current Portfolio Value : 112642.19002001987
# 2021-11-03, LIMIT SELL CREATE 1761 shares at 64.21023107501871
# 2021-11-04, SELL EXECUTED, 64.68
# 2021-11-04, Current Portfolio Value : 113962.94002001987
# 2021-11-04, MARKET BUY CREATE 1751 shares at next open, current close price: 64.41000366210938
# 2021-11-05, BUY EXECUTED, 65.05
# 2021-11-05, Current Portfolio Value : 113910.39879840122
# 2021-11-05, LIMIT SELL CREATE 1751 shares at 65.24722698009603
# 2021-11-08, Current Portfolio Value : 115136.10681384311
# 2021-11-08, LIMIT SELL CREATE 1751 shares at 65.9131286600984
# 2021-11-09, SELL EXECUTED, 65.91
# 2021-11-09, Current Portfolio Value : 115474.27296022423
# Size Exception. If at the end of data, ignore.
# 2021-11-09, MARKET BUY CREATE 1751 shares at next open, current close price: 66.36000061035156
# Final Portfolio Value: 115474.27296022423
#
# STRATEGY INFO:
# OrderedDict([('sharperatio', 0.09508327750143204)])
# AutoOrderedDict([('len', 14), ('drawdown', 0.6431816184012449), ('moneydown', 747.5171908284392), ('max', AutoOrderedDict([('len', 434), ('drawdown', 41.514141419372535), ('moneydown', 42038.112245072494)]))])
# OrderedDict([('rtot', 0.14387757422929626), ('ravg', 0.00026842831012928404), ('rnorm', 0.06998425579211126), ('rnorm100', 6.998425579211126)])
# For XOM, return was -6.136754821777346% for buy and hold vs 15.474272960224233%  for strategy
# {'MSFT': <backtrader.cerebro.Cerebro at 0x140ffdc70>,
#  'HD': <backtrader.cerebro.Cerebro at 0x127678910>,
#  'WAT': <backtrader.cerebro.Cerebro at 0x12752caf0>,
#  'ADSK': <backtrader.cerebro.Cerebro at 0x140729190>,
#  'UNH': <backtrader.cerebro.Cerebro at 0x140af2ac0>,
#  'XOM': <backtrader.cerebro.Cerebro at 0x17710fa30>}

# %%
cerebro_dict
# Out:
# {'MSFT': <backtrader.cerebro.Cerebro at 0x140ffdc70>,
#  'HD': <backtrader.cerebro.Cerebro at 0x127678910>,
#  'WAT': <backtrader.cerebro.Cerebro at 0x12752caf0>,
#  'ADSK': <backtrader.cerebro.Cerebro at 0x140729190>,
#  'UNH': <backtrader.cerebro.Cerebro at 0x140af2ac0>,
#  'XOM': <backtrader.cerebro.Cerebro at 0x17710fa30>}

# %% [markdown]
# ### Library additionally has plotting
# Not sure how to reformat this, it's pretty ugly

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 8]
plt.rcParams.update({'font.size': 12}) 
cerebro_dict['UNH'].plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/32/x61r3nkd55dd30vm0g0c6wp00000gn/T/ipykernel_6876/3540091736.py in <module>
#       3 plt.rcParams['figure.figsize'] = [10, 8]
#       4 plt.rcParams.update({'font.size': 12})
# ----> 5 cerebro_dict['UNH'].plot()
#
# /opt/homebrew/Caskroom/miniforge/base/envs/other/lib/python3.8/site-packages/backtrader/cerebro.py in plot(self, plotter, numfigs, iplot, start, end, width, height, dpi, tight, use, **kwargs)
#     972
#     973         if not plotter:
# --> 974             from . import plot
#     975             if self.p.oldsync:
#     976                 plotter = plot.Plot_OldSync(**kwargs)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/other/lib/python3.8/site-packages/backtrader/plot/__init__.py in <module>
#      40
#      41
# ---> 42 from .plot import Plot, Plot_OldSync
#      43 from .scheme import PlotScheme
#
# /opt/homebrew/Caskroom/miniforge/base/envs/other/lib/python3.8/site-packages/backtrader/plot/plot.py in <module>
#      42 from .finance import plot_candlestick, plot_ohlc, plot_volume, plot_lineonclose
#      43 from .formatters import (MyVolFormatter, MyDateFormatter, getlocator)
# ---> 44 from . import locator as loc
#      45 from .multicursor import MultiCursor
#      46 from .scheme import PlotScheme
#
# /opt/homebrew/Caskroom/miniforge/base/envs/other/lib/python3.8/site-packages/backtrader/plot/locator.py in <module>
#      33 from matplotlib.dates import AutoDateFormatter as ADFormatter
#      34
# ---> 35 from matplotlib.dates import (HOURS_PER_DAY, MIN_PER_HOUR, SEC_PER_MIN,
#      36                               MONTHS_PER_YEAR, DAYS_PER_WEEK,
#      37                               SEC_PER_HOUR, SEC_PER_DAY,
#
# ImportError: cannot import name 'warnings' from 'matplotlib.dates' (/opt/homebrew/Caskroom/miniforge/base/envs/other/lib/python3.8/site-packages/matplotlib/dates.py)

# %% [markdown]
# ### Ways to Improve:

# %% [markdown]
# Increase strategy trading volume. There are certain periods where sell orders are not going through for multiple days in a row, meaning that the price is lower than anticipated by model for that period. For example, if the last sell order didn't go through, we can find a way to use that information to inform our next sell order and make the prediction lower or try a market sell. Maybe train a "bear" model, one that only knows pain and suffering of bear markets, and only produces pessimistic high price predictions.
#
# Smarter entry points. Currently, buy orders are being executed at market price at the open. Returns may increase if entry constraints are increased.
#
# Resizing orders. Orders for this strategy baseline are currently 100% in or 100% out of position. This has beneifits if you want less exposure to the long term movement of the stocks. Depending on the situation and strategy, we might want to reserve a cash position to expose ourselves less to short term movements.
