# %% [markdown]
# # Backtesting with backtrader library
# Notes:
# Timestamp must be in the exact format specified for datafeed   **Timestamp needs to be first column index**
# Params for datafeed need to be specified as tuple of tuples
# Within strategy data is accessed via self.datas[0] for ex: self.datas[0].high_delta[0] would get you the first timeperiod's high_delta
# The current data has already happened and cannot be used to execute an order (ex. you cannot look at the current close price and simultaneously buy the current close, the order will be executed at open instead), orders will be executed on the following day.

# %%
import backtrader as bt
import datetime
import pandas as pd

# %% [markdown]
# ## Define Strategies and Data utils

# %%
class BasicStrategy(bt.Strategy):
    def __init__(self):
        # To keep track of pending orders
        self.order = None
        print('***The limit sells for this strategy are valid for 1 day***')
        
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)

            self.bar_executed = len(self)

            # Note: This logic does not properly work
#         elif order.status in [order.Expired]:
#             if order.isbuy():
#                 self.log('BUY ORDER EXPIRED')
#             elif order.issell():
#                 self.log('SELL ORDER EXPIRED')
        
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')
        
        self.order = None



    def next(self):
        # STRATEGY 
        data = self.datas[0]
        self.log(f'Current Portfolio Value : {self.broker.get_value()}')
        
        # Check if we are in the market
        if not self.position:
            # BUY
            try:
                self.size = int(self.broker.get_cash() / self.datas[0].open[1])
            except:
                print('Size Exception. If at the end of data, ignore.')
            # invest if prediction looks good
            # TODO: Make this a filter in the class constructor
            if (data.prediction[0] >= data.close[0]):
                self.log(f'MARKET BUY CREATE {self.size} shares at next open, current close price: {data.close[0]}')
                # Keep track of the created order to avoid a 2nd order
                self.order = self.buy(size=self.size) # market order buys at next open
                
        else:
            # place sell order at predicted high if predicted high is greater than current close price
            if data.prediction[0] > data.close[0]:
                self.log(f'LIMIT SELL CREATE {self.size} shares at {data.prediction[0]}')
                # Keep track of the created order to avoid a 2nd order, order valid for 1 day
                self.order = self.sell(exectype=bt.Order.Limit,
                             price=data.prediction[0],
                             valid=data.datetime.date(0) + datetime.timedelta(days=2),
                             size=self.size)
            # if prediction is less than current value sell at open
            else:
                self.log('MARKET SELL CREATE. PREDICTION < CURRENT CLOSE')
                self.order = self.sell(size=self.size)

# %%
class BuyAndHold(bt.Strategy):
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)

            self.bar_executed = len(self)

      
    def start(self):
        self.val_start = self.broker.get_cash()  # keep the starting cash

    def nextstart(self):
        # Buy all the available cash
        size = int(self.broker.get_cash() / self.datas[0].open[1])
        self.buy(size=size)

    def stop(self):
        # calculate the actual returns
        self.roi = (self.broker.get_value() / self.val_start) - 1.0
        print(f'Stop price: {self.datas[0].close[0]}')
        print('ROI:        {:.2f}%'.format(100.0 * self.roi))

# %%
def prepare_data(data, fromdate, todate, filepath):
    """Prepare data for backtrader datafeed object
        Returns prepared data filepath and params for the GenericCSVData class, also returns columns used"""
    data['timestamp'] = pd.to_datetime(data['timestamp'])
    # start param setup for backtrader
    start = data['timestamp'].iloc[0]
    end = data['timestamp'].iloc[-1]
    from_to = [(start.year, start.month, start.day), (end.year, end.month, end.day)]
    # Backtrader string format
    data['timestamp'] = data['timestamp'].dt.strftime('%Y-%m-%d %H:%M:%S')
    # backtrader data feed class needs a file path, this could be a temp file that's constantly overwritten
    data.to_csv(filepath)
    
    starting_params = [
    ('fromdate', datetime.datetime(*from_to[0])),
    ('todate', datetime.datetime(*from_to[1])),
    ('nullvalue', 0.0),
    ('dtformat', ('%Y-%m-%d %H:%M:%S')),
    ('tmformat', ('%H:%M:%S')),
    ('datetime', 1)]
    # skip nonfeatures (timestamp)
    cols = data.columns[1:]
    # get column position for each indicator and add to starting params list
    i = 2 # starting index since others are reserved
    for indicator in cols:
        starting_params.append((indicator, i))
        i+=1
    final_params = tuple(starting_params)

    return filepath, final_params, cols

# %% [markdown]
# ## Import Data and Run Backtest

# %%
import os

# %%
def capstone_data_prep(pred_folder_name, pred_col_name, ticker_df_filepath, starting_cash=100000):
    """Main loop, preps data and executes backtrader on all stocks in the prediction folder"""
    ticker_backtesting_dict = {}
    for pred_file in os.listdir(f'../data/ticker_predictions/{pred_folder_name}'):
        ticker_name = pred_file.split('_')[0]
        pred_df = pd.read_csv(f'../data/ticker_predictions/{pred_folder_name}/{pred_file}')
        ticker_df = pd.read_csv(ticker_df_filepath + f'/{ticker_name}_full_data.csv')
        # new prediction column name = "prediction", important because backtester strategy looks for this column name
        ticker_df['prediction'] = pred_df[pred_col_name]
        # remove all non-prediction rows, use "timestamp" as the common datetime name
        ticker_df = ticker_df[ticker_df.prediction > 0]
        ticker_df = ticker_df.rename({'reportperiod':'timestamp'}, axis=1)

        # make timestamp in column position 0 
        ticker_cols = list(ticker_df.columns)
        ticker_cols[5] = 'ts_cpy'
        ticker_cols[0] = 'timestamp'
        ticker_df.columns = ticker_cols
        ticker_df['timestamp'] = ticker_df['ts_cpy']

        # skip nonfeatures, keep timestamp
        nonfeatures = ticker_df.columns[1:7]
        features = [col for col in ticker_df.columns if col not in nonfeatures]
        # get index of start and end dates for trading
        ticker_df = ticker_df[features]
        ticker_df.columns = [c.lower() for c in ticker_df.columns]
        idx1 = ticker_df.prediction[ticker_df.prediction > 0].index[0]
        idx2 = ticker_df.prediction[ticker_df.prediction > 0].index[-1]
        start_date = pred_df.timestamp[idx1]
        end_date  = pred_df.timestamp[idx2]

        # Prepare data for backtrader
        prep_data = prepare_data(ticker_df.copy(), start_date, end_date, 'temp/prep_data.csv')
        class DataFeed(bt.feeds.GenericCSVData):
            lines = tuple(prep_data[2])
            params = prep_data[1]
        
        print(f"--------Ticker Name-------: {ticker_name}")
        ##### BUY AND HOLD #######
        print('BUY AND HOLD')
        # initialize everything and run strategy
        cerebro = bt.Cerebro(cheat_on_open=True)
        cerebro.broker.setcash(starting_cash)
        #cerebro.addsizer(bt.sizers.FixedSize, stake=10)
        print(f'Starting Portfolio Value: {cerebro.broker.getvalue()}')
        data = DataFeed(dataname=prep_data[0])
        cerebro.adddata(data)
        cerebro.addstrategy(BuyAndHold)
        cerebro.addanalyzer(bt.analyzers.SharpeRatio, timeframe=bt.TimeFrame.Months, _name = 'sharpe')
        cerebro.addanalyzer(bt.analyzers.DrawDown, _name = 'dd')
        cerebro.addanalyzer(bt.analyzers.Returns, _name = 'returns')
        buy_hold = cerebro.run()
        buy_hold_ret = cerebro.broker.getvalue() / starting_cash - 1
        print(f'Final Portfolio Value: {cerebro.broker.getvalue()}\n')
        print('STRATEGY INFO:')
        print(buy_hold[0].analyzers.sharpe.get_analysis())
        print(buy_hold[0].analyzers.dd.get_analysis())
        # rtot is total log returns over the strategy time period
        print(buy_hold[0].analyzers.returns.get_analysis())

        #### MAIN STRATEGY #####
        cerebro = bt.Cerebro(cheat_on_open=True)
        cerebro.broker.setcash(starting_cash)
        print(f'Starting Portfolio Value: {cerebro.broker.getvalue()}')
        data = DataFeed(dataname=prep_data[0])
        cerebro.adddata(data)
        cerebro.addstrategy(BasicStrategy)
        cerebro.addanalyzer(bt.analyzers.SharpeRatio, timeframe=bt.TimeFrame.Months, _name = 'sharpe')
        cerebro.addanalyzer(bt.analyzers.DrawDown, _name = 'dd')
        cerebro.addanalyzer(bt.analyzers.Returns, _name = 'returns')
        back = cerebro.run()
        strat_ret = cerebro.broker.getvalue() / starting_cash - 1
        print(f'Final Portfolio Value: {cerebro.broker.getvalue()}\n')
        print('STRATEGY INFO:')
        print(back[0].analyzers.sharpe.get_analysis())
        print(back[0].analyzers.dd.get_analysis())
        # rtot is total log returns over the strategy time period
        print(back[0].analyzers.returns.get_analysis())
        print(f"For {ticker_name}, return was {buy_hold_ret*100}% for buy and hold vs {strat_ret*100}%  for strategy")
        print('\n'*5)

        ticker_backtesting_dict[ticker_name] = cerebro
        
    return ticker_backtesting_dict
#     return ticker_df

# %%
# pred_folder_name, pred_col_name, ticker_df_filepath, starting_cash=100000

cerebro_dict = capstone_data_prep('ar_preds', 'prediction', '../data/ticker_data')
cerebro_dict
# Out:
# --------Ticker Name-------: MSFT
# BUY AND HOLD
# Starting Portfolio Value: 100000
# 2000-04-03, BUY EXECUTED, 47.22
# Stop price: 25.45499992370605
# ROI:        -46.07%
# Final Portfolio Value: 53926.14108848571
#
# STRATEGY INFO:
# OrderedDict([('sharperatio', -0.08149073316471005)])
# AutoOrderedDict([('len', 541), ('drawdown', 46.07385891151429), ('moneydown', 46073.85891151429), ('max', AutoOrderedDict([('len', 541), ('drawdown', 56.03434375), ('moneydown', 56034.34375)]))])
# OrderedDict([('rtot', -0.6175548332786981), ('ravg', -0.001139400061399812), ('rnorm', -0.24958494245957547), ('rnorm100', -24.958494245957546)])
# Starting Portfolio Value: 100000
# ***The limit sells for this strategy are valid for 1 day***
# 2000-03-31, Current Portfolio Value : 100000.0
# 2000-03-31, MARKET BUY CREATE 2117 shares at next open, current close price: 53.125
# 2000-04-03, BUY EXECUTED, 47.22
# 2000-04-03, Current Portfolio Value : 96229.09375
# 2000-04-03, LIMIT SELL CREATE 2117 shares at 139.52539573803514
# 2000-04-04, Current Portfolio Value : 93781.3125
# 2000-04-04, LIMIT SELL CREATE 2117 shares at 142.09345851411553
# 2000-04-05, Current Portfolio Value : 91465.84375
# 2000-04-05, LIMIT SELL CREATE 2117 shares at 140.4516129833714
# 2000-04-06, Current Portfolio Value : 91068.90625
# 2000-04-06, LIMIT SELL CREATE 2117 shares at 140.1494329537251
# 2000-04-07, Current Portfolio Value : 94310.5625
# 2000-04-07, LIMIT SELL CREATE 2117 shares at 138.37667001267386
# 2000-04-10, Current Portfolio Value : 91135.0625
# 2000-04-10, LIMIT SELL CREATE 2117 shares at 140.3710302222835
# 2000-04-11, Current Portfolio Value : 88819.59375
# 2000-04-11, LIMIT SELL CREATE 2117 shares at 140.55232870978634
# 2000-04-12, Current Portfolio Value : 84056.34375
# 2000-04-12, LIMIT SELL CREATE 2117 shares at 138.7291999720787
# 2000-04-13, Current Portfolio Value : 83924.03125
# 2000-04-13, LIMIT SELL CREATE 2117 shares at 140.03863429231487
# 2000-04-14, Current Portfolio Value : 78499.21875
# 2000-04-14, LIMIT SELL CREATE 2117 shares at 138.06442348167204
# 2000-04-17, Current Portfolio Value : 80351.59375
# 2000-04-17, LIMIT SELL CREATE 2117 shares at 135.6268533287228
# 2000-04-18, Current Portfolio Value : 85313.3125
# 2000-04-18, LIMIT SELL CREATE 2117 shares at 137.2686835789066
# 2000-04-19, Current Portfolio Value : 83328.625
# 2000-04-19, LIMIT SELL CREATE 2117 shares at 139.1220287312007
# 2000-04-20, Current Portfolio Value : 83593.25
# 2000-04-20, LIMIT SELL CREATE 2117 shares at 138.11477392632494
# 2000-04-24, Current Portfolio Value : 70560.46875
# 2000-04-24, LIMIT SELL CREATE 2117 shares at 136.65425753315284
# 2000-04-25, Current Portfolio Value : 73471.34375
# 2000-04-25, LIMIT SELL CREATE 2117 shares at 139.24290975903804
# 2000-04-26, Current Portfolio Value : 72015.90625
# 2000-04-26, LIMIT SELL CREATE 2117 shares at 140.1091495060107
# 2000-04-27, Current Portfolio Value : 73934.4375
# 2000-04-27, LIMIT SELL CREATE 2117 shares at 140.69334376768867
# 2000-04-28, Current Portfolio Value : 73868.28125
# 2000-04-28, LIMIT SELL CREATE 2117 shares at 140.56241109430707
# 2000-05-01, Current Portfolio Value : 77771.5
# 2000-05-01, LIMIT SELL CREATE 2117 shares at 142.59707010361288
# 2000-05-02, Current Portfolio Value : 74000.59375
# 2000-05-02, LIMIT SELL CREATE 2117 shares at 141.42865084127976
# 2000-05-03, Current Portfolio Value : 74728.3125
# 2000-05-03, LIMIT SELL CREATE 2117 shares at 140.70342615221014
# 2000-05-04, Current Portfolio Value : 74596.0
# 2000-05-04, LIMIT SELL CREATE 2117 shares at 138.40688642665253
# 2000-05-05, Current Portfolio Value : 75323.71875
# 2000-05-05, LIMIT SELL CREATE 2117 shares at 139.434275261594
# 2000-05-08, Current Portfolio Value : 73934.4375
# 2000-05-08, LIMIT SELL CREATE 2117 shares at 137.35933282266816
# 2000-05-09, Current Portfolio Value : 71817.4375
# 2000-05-09, LIMIT SELL CREATE 2117 shares at 138.2356549541623
# 2000-05-10, Current Portfolio Value : 70097.375
# 2000-05-10, LIMIT SELL CREATE 2117 shares at 140.95523985342908
# 2000-05-11, Current Portfolio Value : 71883.59375
# 2000-05-11, LIMIT SELL CREATE 2117 shares at 141.7509643867059
# 2000-05-12, Current Portfolio Value : 72875.9375
# 2000-05-12, LIMIT SELL CREATE 2117 shares at 145.23607277415095
# 2000-05-15, Current Portfolio Value : 73471.34375
# 2000-05-15, LIMIT SELL CREATE 2117 shares at 143.86620562474042
# 2000-05-16, Current Portfolio Value : 73603.65625
# 2000-05-16, LIMIT SELL CREATE 2117 shares at 145.65911794786012
# 2000-05-17, Current Portfolio Value : 71685.125
# 2000-05-17, LIMIT SELL CREATE 2117 shares at 144.4101164567983
# 2000-05-18, Current Portfolio Value : 70097.375
# 2000-05-18, LIMIT SELL CREATE 2117 shares at 144.76266178630027
# 2000-05-19, Current Portfolio Value : 68906.5625
# 2000-05-19, LIMIT SELL CREATE 2117 shares at 145.59868511868578
# 2000-05-22, Current Portfolio Value : 67980.375
# 2000-05-22, LIMIT SELL CREATE 2117 shares at 145.50803587492422
# 2000-05-23, Current Portfolio Value : 66921.875
# 2000-05-23, LIMIT SELL CREATE 2117 shares at 145.10512473128077
# 2000-05-24, Current Portfolio Value : 69435.8125
# 2000-05-24, LIMIT SELL CREATE 2117 shares at 145.3065726183582
# 2000-05-25, Current Portfolio Value : 65135.65625
# 2000-05-25, LIMIT SELL CREATE 2117 shares at 147.01891808223783
# 2000-05-26, Current Portfolio Value : 65069.5
# 2000-05-26, LIMIT SELL CREATE 2117 shares at 147.17000015517374
# 2000-05-30, Current Portfolio Value : 67120.34375
# 2000-05-30, LIMIT SELL CREATE 2117 shares at 148.13697153042943
# 2000-05-31, Current Portfolio Value : 66260.3125
# 2000-05-31, LIMIT SELL CREATE 2117 shares at 148.3787028471269
# 2000-06-01, Current Portfolio Value : 68377.3125
# 2000-06-01, LIMIT SELL CREATE 2117 shares at 149.1341439507837
# 2000-06-02, Current Portfolio Value : 70229.6875
# 2000-06-02, LIMIT SELL CREATE 2117 shares at 151.05800431677363
# 2000-06-05, Current Portfolio Value : 70825.09375
# 2000-06-05, LIMIT SELL CREATE 2117 shares at 151.43068367634132
# 2000-06-06, Current Portfolio Value : 73735.96875
# 2000-06-06, LIMIT SELL CREATE 2117 shares at 151.4810494904828
# 2000-06-07, Current Portfolio Value : 74662.15625
# 2000-06-07, LIMIT SELL CREATE 2117 shares at 150.7054589872717
# 2000-06-08, Current Portfolio Value : 72875.9375
# 2000-06-08, LIMIT SELL CREATE 2117 shares at 150.56444392936862
# 2000-06-09, Current Portfolio Value : 72875.9375
# 2000-06-09, LIMIT SELL CREATE 2117 shares at 150.6752425726845
# 2000-06-12, Current Portfolio Value : 70825.09375
# 2000-06-12, LIMIT SELL CREATE 2117 shares at 152.32713983790117
# 2000-06-13, Current Portfolio Value : 71883.59375
# 2000-06-13, LIMIT SELL CREATE 2117 shares at 153.1329467556995
# 2000-06-14, Current Portfolio Value : 74662.15625
# 2000-06-14, LIMIT SELL CREATE 2117 shares at 153.42505925602703
# 2000-06-15, Current Portfolio Value : 76646.84375
# 2000-06-15, LIMIT SELL CREATE 2117 shares at 152.4782372803257
# 2000-06-16, Current Portfolio Value : 76845.3125
# 2000-06-16, LIMIT SELL CREATE 2117 shares at 150.63495914306446
# 2000-06-19, Current Portfolio Value : 78036.125
# 2000-06-19, LIMIT SELL CREATE 2117 shares at 150.3932124568784
# 2000-06-20, Current Portfolio Value : 79359.25
# 2000-06-20, LIMIT SELL CREATE 2117 shares at 150.9371386584249
# 2000-06-21, Current Portfolio Value : 85445.625
# 2000-06-21, LIMIT SELL CREATE 2117 shares at 151.017705517665
# 2000-06-22, Current Portfolio Value : 84585.59375
# 2000-06-22, LIMIT SELL CREATE 2117 shares at 152.85091663989337
# 2000-06-23, Current Portfolio Value : 82270.125
# 2000-06-23, LIMIT SELL CREATE 2117 shares at 152.45808788077136
# 2000-06-26, Current Portfolio Value : 84188.65625
# 2000-06-26, LIMIT SELL CREATE 2117 shares at 152.22642357910675
# 2000-06-27, Current Portfolio Value : 83460.9375
# 2000-06-27, LIMIT SELL CREATE 2117 shares at 152.80055082575186
# 2000-06-28, Current Portfolio Value : 83593.25
# 2000-06-28, LIMIT SELL CREATE 2117 shares at 154.35173183217412
# 2000-06-29, Current Portfolio Value : 81740.875
# 2000-06-29, LIMIT SELL CREATE 2117 shares at 155.65108376788882
# 2000-06-30, Current Portfolio Value : 84717.90625
# 2000-06-30, LIMIT SELL CREATE 2117 shares at 156.65833857276456
# 2000-07-03, Current Portfolio Value : 84717.90625
# 2000-07-03, LIMIT SELL CREATE 2117 shares at 155.81224822534622
# 2000-07-05, Current Portfolio Value : 83130.15625
# 2000-07-05, LIMIT SELL CREATE 2117 shares at 155.48991931043145
# 2000-07-06, Current Portfolio Value : 85710.25
# 2000-07-06, LIMIT SELL CREATE 2117 shares at 156.8396524297763
# 2000-07-07, Current Portfolio Value : 86834.90625
# 2000-07-07, LIMIT SELL CREATE 2117 shares at 158.5519825241673
# 2000-07-10, Current Portfolio Value : 84122.5
# 2000-07-10, LIMIT SELL CREATE 2117 shares at 158.5519825241673
# 2000-07-11, Current Portfolio Value : 83791.71875
# 2000-07-11, LIMIT SELL CREATE 2117 shares at 158.5217661095801
# 2000-07-12, Current Portfolio Value : 85048.6875
# 2000-07-12, LIMIT SELL CREATE 2117 shares at 159.82111804529484
# 2000-07-13, Current Portfolio Value : 84651.75
# 2000-07-13, LIMIT SELL CREATE 2117 shares at 160.11323054562243
# 2000-07-14, Current Portfolio Value : 83593.25
# 2000-07-14, LIMIT SELL CREATE 2117 shares at 158.73328101169042
# 2000-07-17, Current Portfolio Value : 82799.375
# 2000-07-17, LIMIT SELL CREATE 2117 shares at 158.84407965500628
# 2000-07-18, Current Portfolio Value : 83130.15625
# 2000-07-18, LIMIT SELL CREATE 2117 shares at 161.7852618409048
# 2000-07-19, Current Portfolio Value : 77440.71875
# 2000-07-19, LIMIT SELL CREATE 2117 shares at 159.77075223115335
# 2000-07-20, Current Portfolio Value : 79226.9375
# 2000-07-20, LIMIT SELL CREATE 2117 shares at 160.18373038982966
# 2000-07-21, Current Portfolio Value : 76580.6875
# 2000-07-21, LIMIT SELL CREATE 2117 shares at 158.72321399665756
# 2000-07-24, Current Portfolio Value : 74728.3125
# 2000-07-24, LIMIT SELL CREATE 2117 shares at 161.25141802387975
# 2000-07-25, Current Portfolio Value : 73074.40625
# 2000-07-25, LIMIT SELL CREATE 2117 shares at 163.26592763363124
# 2000-07-26, Current Portfolio Value : 71817.4375
# 2000-07-26, LIMIT SELL CREATE 2117 shares at 162.51048652997443
# 2000-07-27, Current Portfolio Value : 73471.34375
# 2000-07-27, LIMIT SELL CREATE 2117 shares at 164.46456331055154
# 2000-07-28, Current Portfolio Value : 73802.125
# 2000-07-28, LIMIT SELL CREATE 2117 shares at 163.3062264327399
# 2000-07-31, Current Portfolio Value : 73934.4375
# 2000-07-31, LIMIT SELL CREATE 2117 shares at 164.36383168226854
# 2000-08-01, Current Portfolio Value : 72743.625
# 2000-08-01, LIMIT SELL CREATE 2117 shares at 167.37552908186288
# 2000-08-02, Current Portfolio Value : 73471.34375
# 2000-08-02, LIMIT SELL CREATE 2117 shares at 168.3122840425314
# 2000-08-03, Current Portfolio Value : 74397.53125
# 2000-08-03, LIMIT SELL CREATE 2117 shares at 167.70792501181052
# 2000-08-04, Current Portfolio Value : 73206.71875
# 2000-08-04, LIMIT SELL CREATE 2117 shares at 166.9021180940122
# 2000-08-07, Current Portfolio Value : 74132.90625
# 2000-08-07, LIMIT SELL CREATE 2117 shares at 167.9295222984423
# 2000-08-08, Current Portfolio Value : 78499.21875
# 2000-08-08, LIMIT SELL CREATE 2117 shares at 166.23732623411695
# 2000-08-09, Current Portfolio Value : 78631.53125
# 2000-08-09, LIMIT SELL CREATE 2117 shares at 163.4573085056758
# 2000-08-10, Current Portfolio Value : 76911.46875
# 2000-08-10, LIMIT SELL CREATE 2117 shares at 166.66038677731473
# 2000-08-11, Current Portfolio Value : 76713.0
# 2000-08-11, LIMIT SELL CREATE 2117 shares at 169.25909064874418
# 2000-08-14, Current Portfolio Value : 76448.375
# 2000-08-14, LIMIT SELL CREATE 2117 shares at 174.03348395687107
# 2000-08-15, Current Portfolio Value : 75852.96875
# 2000-08-15, LIMIT SELL CREATE 2117 shares at 171.46498113054022
# 2000-08-16, Current Portfolio Value : 75191.40625
# 2000-08-16, LIMIT SELL CREATE 2117 shares at 175.64509779246768
# 2000-08-17, Current Portfolio Value : 75786.8125
# 2000-08-17, LIMIT SELL CREATE 2117 shares at 181.42673053598173
# 2000-08-18, Current Portfolio Value : 75191.40625
# 2000-08-18, LIMIT SELL CREATE 2117 shares at 181.20513324935
# 2000-08-21, Current Portfolio Value : 74794.46875
# 2000-08-21, LIMIT SELL CREATE 2117 shares at 184.96220473756827
# 2000-08-22, Current Portfolio Value : 75456.03125
# 2000-08-22, LIMIT SELL CREATE 2117 shares at 185.22408545382007
# 2000-08-23, Current Portfolio Value : 74926.78125
# 2000-08-23, LIMIT SELL CREATE 2117 shares at 190.0689786061542
# 2000-08-24, Current Portfolio Value : 75323.71875
# 2000-08-24, LIMIT SELL CREATE 2117 shares at 185.77807867039945
# 2000-08-25, Current Portfolio Value : 74794.46875
# 2000-08-25, LIMIT SELL CREATE 2117 shares at 186.05004177117272
# 2000-08-28, Current Portfolio Value : 75522.1875
# 2000-08-28, LIMIT SELL CREATE 2117 shares at 185.04278696629697
# 2000-08-29, Current Portfolio Value : 75125.25
# 2000-08-29, LIMIT SELL CREATE 2117 shares at 186.6946842315136
# 2000-08-30, Current Portfolio Value : 74132.90625
# 2000-08-30, LIMIT SELL CREATE 2117 shares at 188.5883128134277
# 2000-08-31, Current Portfolio Value : 73934.4375
# 2000-08-31, LIMIT SELL CREATE 2117 shares at 188.63867862756928
# 2000-09-01, Current Portfolio Value : 74331.375
# 2000-09-01, LIMIT SELL CREATE 2117 shares at 185.75792927084512
# 2000-09-05, Current Portfolio Value : 74265.21875
# 2000-09-05, LIMIT SELL CREATE 2117 shares at 179.88563191408093
# 2000-09-06, Current Portfolio Value : 73537.5
# 2000-09-06, LIMIT SELL CREATE 2117 shares at 172.12977299043547
# 2000-09-07, Current Portfolio Value : 74199.0625
# 2000-09-07, LIMIT SELL CREATE 2117 shares at 169.28932243281994
# 2000-09-08, Current Portfolio Value : 73405.1875
# 2000-09-08, LIMIT SELL CREATE 2117 shares at 171.40454830136585
# 2000-09-11, Current Portfolio Value : 72875.9375
# 2000-09-11, LIMIT SELL CREATE 2117 shares at 159.32755765788983
# 2000-09-12, Current Portfolio Value : 72148.21875
# 2000-09-12, LIMIT SELL CREATE 2117 shares at 163.18534540490256
# 2000-09-13, Current Portfolio Value : 72280.53125
# 2000-09-13, LIMIT SELL CREATE 2117 shares at 174.04355097190393
# 2000-09-14, Current Portfolio Value : 69700.4375
# 2000-09-14, LIMIT SELL CREATE 2117 shares at 165.7034824170919
# 2000-09-15, Current Portfolio Value : 67980.375
# 2000-09-15, LIMIT SELL CREATE 2117 shares at 171.78731004545497
# 2000-09-18, Current Portfolio Value : 66723.40625
# 2000-09-18, LIMIT SELL CREATE 2117 shares at 167.4762607101459
# 2000-09-19, Current Portfolio Value : 68840.40625
# 2000-09-19, LIMIT SELL CREATE 2117 shares at 162.74216620112765
# 2000-09-20, Current Portfolio Value : 68046.53125
# 2000-09-20, LIMIT SELL CREATE 2117 shares at 151.71271379214744
# 2000-09-21, Current Portfolio Value : 67980.375
# 2000-09-21, LIMIT SELL CREATE 2117 shares at 162.08744135626526
# 2000-09-22, Current Portfolio Value : 66988.03125
# 2000-09-22, LIMIT SELL CREATE 2117 shares at 154.7445605912961
# 2000-09-25, Current Portfolio Value : 64871.03125
# 2000-09-25, LIMIT SELL CREATE 2117 shares at 140.06885070690203
# 2000-09-26, Current Portfolio Value : 66392.625
# 2000-09-26, LIMIT SELL CREATE 2117 shares at 159.98228250275224
# 2000-09-27, Current Portfolio Value : 64209.46875
# 2000-09-27, LIMIT SELL CREATE 2117 shares at 136.4024438319339
# 2000-09-28, Current Portfolio Value : 64937.1875
# 2000-09-28, LIMIT SELL CREATE 2117 shares at 147.63334412799156
# 2000-09-29, Current Portfolio Value : 63878.6875
# 2000-09-29, LIMIT SELL CREATE 2117 shares at 141.4185684567583
# 2000-10-02, Current Portfolio Value : 62621.71875
# 2000-10-02, LIMIT SELL CREATE 2117 shares at 143.74533996639167
# 2000-10-03, Current Portfolio Value : 59909.3125
# 2000-10-03, LIMIT SELL CREATE 2117 shares at 138.34645359747816
# 2000-10-04, Current Portfolio Value : 58718.5
# 2000-10-04, LIMIT SELL CREATE 2117 shares at 136.96650406354615
# 2000-10-05, Current Portfolio Value : 58652.34375
# 2000-10-05, LIMIT SELL CREATE 2117 shares at 149.41617406658983
# 2000-10-06, Current Portfolio Value : 58850.8125
# 2000-10-06, LIMIT SELL CREATE 2117 shares at 147.98587408800492
# 2000-10-09, Current Portfolio Value : 57395.375
# 2000-10-09, LIMIT SELL CREATE 2117 shares at 157.24254820393114
# 2000-10-10, Current Portfolio Value : 57792.3125
# 2000-10-10, LIMIT SELL CREATE 2117 shares at 150.78604121600037
# 2000-10-11, Current Portfolio Value : 59049.28125
# 2000-10-11, LIMIT SELL CREATE 2117 shares at 161.39243308178283
# 2000-10-12, Current Portfolio Value : 57593.84375
# 2000-10-12, LIMIT SELL CREATE 2117 shares at 158.85416203952775
# 2000-10-13, Current Portfolio Value : 56932.28125
# 2000-10-13, LIMIT SELL CREATE 2117 shares at 153.21352898442817
# 2000-10-16, Current Portfolio Value : 53359.84375
# 2000-10-16, LIMIT SELL CREATE 2117 shares at 156.3863754719913
# 2000-10-17, Current Portfolio Value : 53426.0
# 2000-10-17, LIMIT SELL CREATE 2117 shares at 154.94600847837353
# 2000-10-18, Current Portfolio Value : 54815.28125
# 2000-10-18, LIMIT SELL CREATE 2117 shares at 166.46900590527017
# 2000-10-19, Current Portfolio Value : 65532.59375
# 2000-10-19, LIMIT SELL CREATE 2117 shares at 164.67609358215043
# 2000-10-20, Current Portfolio Value : 69038.875
# 2000-10-20, LIMIT SELL CREATE 2117 shares at 166.3279908473671
# 2000-10-23, Current Portfolio Value : 65797.21875
# 2000-10-23, LIMIT SELL CREATE 2117 shares at 166.33805786239998
# 2000-10-24, Current Portfolio Value : 65135.65625
# 2000-10-24, LIMIT SELL CREATE 2117 shares at 166.71073722196763
# 2000-10-25, Current Portfolio Value : 64871.03125
# 2000-10-25, LIMIT SELL CREATE 2117 shares at 174.9601565330181
# 2000-10-26, Current Portfolio Value : 68245.0
# 2000-10-26, LIMIT SELL CREATE 2117 shares at 173.12696078027835
# 2000-10-27, Current Portfolio Value : 71685.125
# 2000-10-27, LIMIT SELL CREATE 2117 shares at 178.3243838926258
# 2000-10-30, Current Portfolio Value : 73140.5625
# 2000-10-30, LIMIT SELL CREATE 2117 shares at 179.8957142986024
# 2000-10-31, Current Portfolio Value : 72942.09375
# 2000-10-31, LIMIT SELL CREATE 2117 shares at 176.33002368242867
# 2000-11-01, Current Portfolio Value : 73735.96875
# 2000-11-01, LIMIT SELL CREATE 2117 shares at 169.037508731601
# 2000-11-02, Current Portfolio Value : 74463.6875
# 2000-11-02, LIMIT SELL CREATE 2117 shares at 174.778858045495
# 2000-11-03, Current Portfolio Value : 72280.53125
# 2000-11-03, LIMIT SELL CREATE 2117 shares at 172.66361680746053
# 2000-11-06, Current Portfolio Value : 73603.65625
# 2000-11-06, LIMIT SELL CREATE 2117 shares at 175.81632926495794
# 2000-11-07, Current Portfolio Value : 74662.15625
# 2000-11-07, LIMIT SELL CREATE 2117 shares at 175.31270186252007
# 2000-11-08, Current Portfolio Value : 73537.5
# 2000-11-08, LIMIT SELL CREATE 2117 shares at 171.04193595683105
# 2000-11-09, Current Portfolio Value : 75059.09375
# 2000-11-09, LIMIT SELL CREATE 2117 shares at 178.7172126517478
# 2000-11-10, Current Portfolio Value : 71354.34375
# 2000-11-10, LIMIT SELL CREATE 2117 shares at 180.51014034435613
# 2000-11-13, Current Portfolio Value : 70362.0
# 2000-11-13, LIMIT SELL CREATE 2117 shares at 175.83647866451224
# 2000-11-14, Current Portfolio Value : 72875.9375
# 2000-11-14, LIMIT SELL CREATE 2117 shares at 180.13744561529987
# 2000-11-15, Current Portfolio Value : 74199.0625
# 2000-11-15, LIMIT SELL CREATE 2117 shares at 182.07137299632268
# 2000-11-16, Current Portfolio Value : 73008.25
# 2000-11-16, LIMIT SELL CREATE 2117 shares at 183.8642853194424
# 2000-11-17, Current Portfolio Value : 73140.5625
# 2000-11-17, LIMIT SELL CREATE 2117 shares at 184.93198832298103
# 2000-11-20, Current Portfolio Value : 71155.875
# 2000-11-20, LIMIT SELL CREATE 2117 shares at 186.0198099870969
# 2000-11-21, Current Portfolio Value : 71751.28125
# 2000-11-21, LIMIT SELL CREATE 2117 shares at 188.0947677955114
# 2000-11-22, Current Portfolio Value : 72280.53125
# 2000-11-22, LIMIT SELL CREATE 2117 shares at 183.83406890485523
# 2000-11-24, Current Portfolio Value : 74066.75
# 2000-11-24, LIMIT SELL CREATE 2117 shares at 181.05405117641405
# 2000-11-27, Current Portfolio Value : 74860.625
# 2000-11-27, LIMIT SELL CREATE 2117 shares at 181.83970869465804
# 2000-11-28, Current Portfolio Value : 70957.40625
# 2000-11-28, LIMIT SELL CREATE 2117 shares at 184.4887937497176
# 2000-11-29, Current Portfolio Value : 68906.5625
# 2000-11-29, LIMIT SELL CREATE 2117 shares at 186.2514896582501
# 2000-11-30, Current Portfolio Value : 60769.34375
# 2000-11-30, LIMIT SELL CREATE 2117 shares at 184.96220473756827
# 2000-12-01, Current Portfolio Value : 59975.46875
# 2000-12-01, LIMIT SELL CREATE 2117 shares at 187.0069307619069
# 2000-12-04, Current Portfolio Value : 59777.0
# 2000-12-04, LIMIT SELL CREATE 2117 shares at 184.76074148100224
# 2000-12-05, Current Portfolio Value : 63415.59375
# 2000-12-05, LIMIT SELL CREATE 2117 shares at 184.84132370973097
# 2000-12-06, Current Portfolio Value : 60041.625
# 2000-12-06, LIMIT SELL CREATE 2117 shares at 182.8872622986424
# 2000-12-07, Current Portfolio Value : 56270.71875
# 2000-12-07, LIMIT SELL CREATE 2117 shares at 183.12899361533988
# 2000-12-08, Current Portfolio Value : 57660.0
# 2000-12-08, LIMIT SELL CREATE 2117 shares at 182.7160154566636
# 2000-12-11, Current Portfolio Value : 61497.0625
# 2000-12-11, LIMIT SELL CREATE 2117 shares at 184.57944299347915
# 2000-12-12, Current Portfolio Value : 61827.84375
# 2000-12-12, LIMIT SELL CREATE 2117 shares at 184.15639781976995
# 2000-12-13, Current Portfolio Value : 60637.03125
# 2000-12-13, LIMIT SELL CREATE 2117 shares at 186.2514896582501
# 2000-12-14, Current Portfolio Value : 58784.65625
# 2000-12-14, LIMIT SELL CREATE 2117 shares at 186.7047512465465
# 2000-12-15, Current Portfolio Value : 52102.875
# 2000-12-15, LIMIT SELL CREATE 2117 shares at 184.2470470635315
# 2000-12-18, Current Portfolio Value : 50647.4375
# 2000-12-18, LIMIT SELL CREATE 2117 shares at 188.55809639884055
# 2000-12-19, Current Portfolio Value : 47471.9375
# 2000-12-19, LIMIT SELL CREATE 2117 shares at 189.72651566117372
# 2000-12-20, Current Portfolio Value : 43965.65625
# 2000-12-20, LIMIT SELL CREATE 2117 shares at 191.17696503931296
# 2000-12-21, Current Portfolio Value : 46016.5
# 2000-12-21, LIMIT SELL CREATE 2117 shares at 198.2680321030632
# 2000-12-22, Current Portfolio Value : 49192.0
# 2000-12-22, LIMIT SELL CREATE 2117 shares at 187.62135680766065
# 2000-12-26, Current Portfolio Value : 49655.09375
# 2000-12-26, LIMIT SELL CREATE 2117 shares at 189.10202260038716
# 2000-12-27, Current Portfolio Value : 49192.0
# 2000-12-27, LIMIT SELL CREATE 2117 shares at 190.3107252923403
# 2000-12-28, Current Portfolio Value : 47207.3125
# 2000-12-28, LIMIT SELL CREATE 2117 shares at 194.9743199571513
# 2000-12-29, Current Portfolio Value : 45950.34375
# 2000-12-29, LIMIT SELL CREATE 2117 shares at 195.64917883207943
# 2001-01-02, Current Portfolio Value : 45950.34375
# 2001-01-02, LIMIT SELL CREATE 2117 shares at 197.7442706705596
# 2001-01-03, Current Portfolio Value : 50779.75
# 2001-01-03, LIMIT SELL CREATE 2117 shares at 196.56576902370503
# 2001-01-04, Current Portfolio Value : 51309.0
# 2001-01-04, LIMIT SELL CREATE 2117 shares at 202.02510359128144
# 2001-01-05, Current Portfolio Value : 52036.71875
# 2001-01-05, LIMIT SELL CREATE 2117 shares at 203.37482134113765
# 2001-01-08, Current Portfolio Value : 51838.25
# 2001-01-08, LIMIT SELL CREATE 2117 shares at 199.2752869079389
# 2001-01-09, Current Portfolio Value : 54881.4375
# 2001-01-09, LIMIT SELL CREATE 2117 shares at 201.79342392012828
# 2001-01-10, Current Portfolio Value : 56006.09375
# 2001-01-10, LIMIT SELL CREATE 2117 shares at 197.75433768559245
# 2001-01-11, Current Portfolio Value : 58255.40625
# 2001-01-11, LIMIT SELL CREATE 2117 shares at 199.8796459386598
# 2001-01-12, Current Portfolio Value : 56667.65625
# 2001-01-12, LIMIT SELL CREATE 2117 shares at 204.9864198072457
# 2001-01-16, Current Portfolio Value : 55675.3125
# 2001-01-16, LIMIT SELL CREATE 2117 shares at 206.185055484166
# 2001-01-17, Current Portfolio Value : 56072.25
# 2001-01-17, LIMIT SELL CREATE 2117 shares at 207.75637052065403
# 2001-01-18, Current Portfolio Value : 58784.65625
# 2001-01-18, LIMIT SELL CREATE 2117 shares at 212.22858431342044
# 2001-01-19, Current Portfolio Value : 64606.40625
# 2001-01-19, LIMIT SELL CREATE 2117 shares at 209.7608131153726
# 2001-01-22, Current Portfolio Value : 63680.21875
# 2001-01-22, LIMIT SELL CREATE 2117 shares at 214.3740419660421
# 2001-01-23, Current Portfolio Value : 64143.3125
# 2001-01-23, LIMIT SELL CREATE 2117 shares at 215.87485715832287
# 2001-01-24, Current Portfolio Value : 66657.25
# 2001-01-24, LIMIT SELL CREATE 2117 shares at 215.22013231346048
# 2001-01-25, Current Portfolio Value : 65466.4375
# 2001-01-25, LIMIT SELL CREATE 2117 shares at 208.57225982297376
# 2001-01-26, Current Portfolio Value : 67781.90625
# 2001-01-26, LIMIT SELL CREATE 2117 shares at 209.8615447436556
# 2001-01-29, Current Portfolio Value : 68311.15625
# 2001-01-29, LIMIT SELL CREATE 2117 shares at 209.5492828437737
# 2001-01-30, Current Portfolio Value : 67120.34375
# 2001-01-30, LIMIT SELL CREATE 2117 shares at 205.399397965922
# 2001-01-31, Current Portfolio Value : 64672.5625
# 2001-01-31, LIMIT SELL CREATE 2117 shares at 204.35185973142623
# 2001-02-01, Current Portfolio Value : 66061.84375
# 2001-02-01, LIMIT SELL CREATE 2117 shares at 213.1351228595017
# 2001-02-02, Current Portfolio Value : 64407.9375
# 2001-02-02, LIMIT SELL CREATE 2117 shares at 210.26444051781047
# 2001-02-05, Current Portfolio Value : 65598.75
# 2001-02-05, LIMIT SELL CREATE 2117 shares at 213.2862049324377
# 2001-02-06, Current Portfolio Value : 66260.3125
# 2001-02-06, LIMIT SELL CREATE 2117 shares at 204.00938141695715
# 2001-02-07, Current Portfolio Value : 68509.625
# 2001-02-07, LIMIT SELL CREATE 2117 shares at 202.76039529538397
# 2001-02-08, Current Portfolio Value : 65929.53125
# 2001-02-08, LIMIT SELL CREATE 2117 shares at 205.3288981217148
# 2001-02-09, Current Portfolio Value : 62621.71875
# 2001-02-09, LIMIT SELL CREATE 2117 shares at 203.48561998445356
# 2001-02-12, Current Portfolio Value : 62224.78125
# 2001-02-12, LIMIT SELL CREATE 2117 shares at 205.54041302382507
# 2001-02-13, Current Portfolio Value : 61629.375
# 2001-02-13, LIMIT SELL CREATE 2117 shares at 205.3792485663677
# 2001-02-14, Current Portfolio Value : 61827.84375
# 2001-02-14, LIMIT SELL CREATE 2117 shares at 206.49730201455932
# 2001-02-15, Current Portfolio Value : 62290.9375
# 2001-02-15, LIMIT SELL CREATE 2117 shares at 218.1109486852175
# 2001-02-16, Current Portfolio Value : 60703.1875
# 2001-02-16, LIMIT SELL CREATE 2117 shares at 214.83737056937136
# 2001-02-20, Current Portfolio Value : 59181.59375
# 2001-02-20, LIMIT SELL CREATE 2117 shares at 214.484840609358
# 2001-02-21, Current Portfolio Value : 59578.53125
# 2001-02-21, LIMIT SELL CREATE 2117 shares at 217.9195831826615
# 2001-02-22, Current Portfolio Value : 58453.875
# 2001-02-22, LIMIT SELL CREATE 2117 shares at 214.02149663654012
# 2001-02-23, Current Portfolio Value : 60107.78125
# 2001-02-23, LIMIT SELL CREATE 2117 shares at 209.7608131153726
# 2001-02-26, Current Portfolio Value : 63084.8125
# 2001-02-26, LIMIT SELL CREATE 2117 shares at 204.8554871338641
# 2001-02-27, Current Portfolio Value : 62886.34375
# 2001-02-27, LIMIT SELL CREATE 2117 shares at 210.707635091074
# 2001-02-28, Current Portfolio Value : 62489.40625
# 2001-02-28, LIMIT SELL CREATE 2117 shares at 210.21407470366896
# 2001-03-01, Current Portfolio Value : 62869.8046875
# 2001-03-01, LIMIT SELL CREATE 2117 shares at 210.41552259074643
# 2001-03-02, Current Portfolio Value : 60041.625
# 2001-03-02, LIMIT SELL CREATE 2117 shares at 211.80553913971127
# 2001-03-05, Current Portfolio Value : 60835.5
# 2001-03-05, LIMIT SELL CREATE 2117 shares at 213.02432421618596
# 2001-03-06, Current Portfolio Value : 62952.5
# 2001-03-06, LIMIT SELL CREATE 2117 shares at 211.2213295085447
# 2001-03-07, Current Portfolio Value : 64275.625
# 2001-03-07, LIMIT SELL CREATE 2117 shares at 216.13673787457464
# 2001-03-08, Current Portfolio Value : 62754.03125
# 2001-03-08, LIMIT SELL CREATE 2117 shares at 214.56542283808668
# 2001-03-09, Current Portfolio Value : 60041.625
# 2001-03-09, LIMIT SELL CREATE 2117 shares at 215.2402817130148
# 2001-03-12, Current Portfolio Value : 55013.75
# 2001-03-12, LIMIT SELL CREATE 2117 shares at 218.04044884101023
# 2001-03-13, Current Portfolio Value : 57395.375
# 2001-03-13, LIMIT SELL CREATE 2117 shares at 222.75439395047425
# 2001-03-14, Current Portfolio Value : 57196.90625
# 2001-03-14, LIMIT SELL CREATE 2117 shares at 228.22379553308355
# 2001-03-15, Current Portfolio Value : 56866.125
# 2001-03-15, LIMIT SELL CREATE 2117 shares at 230.5707010727826
# 2001-03-16, Current Portfolio Value : 57792.3125
# 2001-03-16, LIMIT SELL CREATE 2117 shares at 227.1661749140663
# 2001-03-19, Current Portfolio Value : 57527.6875
# 2001-03-19, LIMIT SELL CREATE 2117 shares at 228.91880380756595
# 2001-03-20, Current Portfolio Value : 55807.625
# 2001-03-20, LIMIT SELL CREATE 2117 shares at 233.3305694016695
# 2001-03-21, Current Portfolio Value : 53029.0625
# 2001-03-21, LIMIT SELL CREATE 2117 shares at 218.87647217339577
# 2001-03-22, Current Portfolio Value : 57196.90625
# 2001-03-22, LIMIT SELL CREATE 2117 shares at 215.80434194462703
# 2001-03-23, Current Portfolio Value : 59909.3125
# 2001-03-23, LIMIT SELL CREATE 2117 shares at 204.13026244479445
# 2001-03-26, Current Portfolio Value : 59380.0625
# 2001-03-26, LIMIT SELL CREATE 2117 shares at 212.82286095961987
# 2001-03-27, Current Portfolio Value : 61695.53125
# 2001-03-27, LIMIT SELL CREATE 2117 shares at 206.8599143590941
# 2001-03-28, Current Portfolio Value : 58850.8125
# 2001-03-28, LIMIT SELL CREATE 2117 shares at 205.5101966092379
# 2001-03-29, Current Portfolio Value : 58652.34375
# 2001-03-29, LIMIT SELL CREATE 2117 shares at 206.90021315820275
# 2001-03-30, Current Portfolio Value : 57924.625
# 2001-03-30, LIMIT SELL CREATE 2117 shares at 210.2946569323977
# 2001-04-02, Current Portfolio Value : 59115.4375
# 2001-04-02, LIMIT SELL CREATE 2117 shares at 206.537600813668
# 2001-04-03, Current Portfolio Value : 56535.34375
# 2001-04-03, LIMIT SELL CREATE 2117 shares at 204.3820761460134
# 2001-04-04, Current Portfolio Value : 55013.75
# 2001-04-04, LIMIT SELL CREATE 2117 shares at 201.84378973426976
# 2001-04-05, Current Portfolio Value : 60107.78125
# 2001-04-05, LIMIT SELL CREATE 2117 shares at 204.00938141695715
# 2001-04-06, Current Portfolio Value : 59512.375
# 2001-04-06, LIMIT SELL CREATE 2117 shares at 208.92478978298712
# 2001-04-09, Current Portfolio Value : 60531.18286514282
# 2001-04-09, LIMIT SELL CREATE 2117 shares at 202.0452376213472
# 2001-04-10, Current Portfolio Value : 63209.186573028564
# 2001-04-10, LIMIT SELL CREATE 2117 shares at 204.66410626181957
# 2001-04-11, Current Portfolio Value : 63590.24721908569
# 2001-04-11, LIMIT SELL CREATE 2117 shares at 209.32770092663057
# 2001-04-12, Current Portfolio Value : 65855.43657302856
# 2001-04-12, LIMIT SELL CREATE 2117 shares at 210.9594487922929
# 2001-04-16, Current Portfolio Value : 64384.12221908569
# 2001-04-16, LIMIT SELL CREATE 2117 shares at 208.76362532552977
# 2001-04-17, Current Portfolio Value : 65114.48576545715
# 2001-04-17, LIMIT SELL CREATE 2117 shares at 211.8559049538528
# 2001-04-18, Current Portfolio Value : 69295.56157302856
# 2001-04-18, LIMIT SELL CREATE 2117 shares at 214.0013626064745
# 2001-04-19, Current Portfolio Value : 72058.2472190857
# 2001-04-19, LIMIT SELL CREATE 2117 shares at 207.6858706764468
# 2001-04-20, Current Portfolio Value : 73074.40625
# 2001-04-20, LIMIT SELL CREATE 2117 shares at 211.90627076799427
# 2001-04-23, Current Portfolio Value : 72280.53125
# 2001-04-23, LIMIT SELL CREATE 2117 shares at 207.40384056064065
# 2001-04-24, Current Portfolio Value : 71539.58448028564
# 2001-04-24, LIMIT SELL CREATE 2117 shares at 211.3522775514149
# 2001-04-25, Current Portfolio Value : 73804.77383422852
# 2001-04-25, LIMIT SELL CREATE 2117 shares at 212.1077186550717
# 2001-04-26, Current Portfolio Value : 73212.00834274292
# 2001-04-26, LIMIT SELL CREATE 2117 shares at 217.375656981115
# 2001-04-27, Current Portfolio Value : 71084.42915725708
# 2001-04-27, LIMIT SELL CREATE 2117 shares at 223.0062076516932
# 2001-04-30, Current Portfolio Value : 71751.28125
# 2001-04-30, LIMIT SELL CREATE 2117 shares at 224.47680642938676
# 2001-05-01, Current Portfolio Value : 74312.84931182861
# 2001-05-01, LIMIT SELL CREATE 2117 shares at 222.46229681963524
# 2001-05-02, Current Portfolio Value : 73878.86851119995
# 2001-05-02, LIMIT SELL CREATE 2117 shares at 221.253594127682
# 2001-05-03, Current Portfolio Value : 72576.90995788574
# 2001-05-03, LIMIT SELL CREATE 2117 shares at 221.253594127682
# 2001-05-04, Current Portfolio Value : 74926.78125
# 2001-05-04, LIMIT SELL CREATE 2117 shares at 215.77412553003987
# 2001-05-07, Current Portfolio Value : 75593.63334274292
# 2001-05-07, LIMIT SELL CREATE 2117 shares at 216.20723771878195
# 2001-05-08, Current Portfolio Value : 76313.4136657715
# 2001-05-08, LIMIT SELL CREATE 2117 shares at 216.3583351612064
# 2001-05-09, Current Portfolio Value : 74556.30786514282
# 2001-05-09, LIMIT SELL CREATE 2117 shares at 216.448984404968
# 2001-05-10, Current Portfolio Value : 74132.90625
# 2001-05-10, LIMIT SELL CREATE 2117 shares at 217.79870215482416
# 2001-05-11, Current Portfolio Value : 73497.80786514282
# 2001-05-11, LIMIT SELL CREATE 2117 shares at 211.60409125263385
# 2001-05-14, Current Portfolio Value : 72778.02754211426
# 2001-05-14, LIMIT SELL CREATE 2117 shares at 214.7970871397513
# 2001-05-15, Current Portfolio Value : 72301.69769668579
# 2001-05-15, LIMIT SELL CREATE 2117 shares at 204.15039647486023
# 2001-05-16, Current Portfolio Value : 73243.77012634277
# 2001-05-16, LIMIT SELL CREATE 2117 shares at 206.20520488372037
# 2001-05-17, Current Portfolio Value : 72195.84931182861
# 2001-05-17, LIMIT SELL CREATE 2117 shares at 203.93888157274992
# 2001-05-18, Current Portfolio Value : 72111.16737365723
# 2001-05-18, LIMIT SELL CREATE 2117 shares at 203.79786651484687
# 2001-05-21, Current Portfolio Value : 72852.1222190857
# 2001-05-21, LIMIT SELL CREATE 2117 shares at 207.92760199314424
# 2001-05-22, Current Portfolio Value : 74461.03866577148
# 2001-05-22, LIMIT SELL CREATE 2117 shares at 217.9598666122816
# 2001-05-23, Current Portfolio Value : 73815.35301971436
# 2001-05-23, LIMIT SELL CREATE 2117 shares at 224.90991861812876
# 2001-05-24, Current Portfolio Value : 75953.52754211426
# 2001-05-24, LIMIT SELL CREATE 2117 shares at 225.34304617635937
# 2001-05-25, Current Portfolio Value : 75096.14512634277
# 2001-05-25, LIMIT SELL CREATE 2117 shares at 219.97437622203304
# 2001-05-29, Current Portfolio Value : 74492.79237365723
# 2001-05-29, LIMIT SELL CREATE 2117 shares at 212.54083084381375
# 2001-05-30, Current Portfolio Value : 73275.52383422852
# 2001-05-30, LIMIT SELL CREATE 2117 shares at 218.12103106973896
# 2001-05-31, Current Portfolio Value : 73264.93657302856
# 2001-05-31, LIMIT SELL CREATE 2117 shares at 217.00297762154736
# 2001-06-01, Current Portfolio Value : 74492.79237365723
# 2001-06-01, LIMIT SELL CREATE 2117 shares at 218.08073227063036
# 2001-06-04, Current Portfolio Value : 74958.53495788574
# 2001-06-04, LIMIT SELL CREATE 2117 shares at 218.8059569596999
# 2001-06-05, Current Portfolio Value : 76885.00463485718
# 2001-06-05, LIMIT SELL CREATE 2117 shares at 216.01587221622597
# 2001-06-06, Current Portfolio Value : 76630.96689605713
# 2001-06-06, LIMIT SELL CREATE 2117 shares at 212.6113460575096
# 2001-06-07, Current Portfolio Value : 78028.18657302856
# 2001-06-07, LIMIT SELL CREATE 2117 shares at 213.9610638073658
# 2001-06-08, Current Portfolio Value : 77509.52383422852
# 2001-06-08, LIMIT SELL CREATE 2117 shares at 211.9163377830272
# 2001-06-11, Current Portfolio Value : 76376.92915725708
# 2001-06-11, LIMIT SELL CREATE 2117 shares at 211.6343076672211
# 2001-06-12, Current Portfolio Value : 76334.58818817139
# 2001-06-12, LIMIT SELL CREATE 2117 shares at 215.41151318550507
# 2001-06-13, Current Portfolio Value : 74863.27383422852
# 2001-06-13, LIMIT SELL CREATE 2117 shares at 215.4215802005379
# 2001-06-14, Current Portfolio Value : 72968.55786514282
# 2001-06-14, LIMIT SELL CREATE 2117 shares at 216.79144734994844
# 2001-06-15, Current Portfolio Value : 72037.07269668579
# 2001-06-15, LIMIT SELL CREATE 2117 shares at 215.62304345710396
# 2001-06-18, Current Portfolio Value : 70830.38334274292
# 2001-06-18, LIMIT SELL CREATE 2117 shares at 217.7785681247585
# 2001-06-19, Current Portfolio Value : 71296.12592697144
# 2001-06-19, LIMIT SELL CREATE 2117 shares at 216.93246240785152
# 2001-06-20, Current Portfolio Value : 73508.39512634277
# 2001-06-20, LIMIT SELL CREATE 2117 shares at 215.7942749295942
# 2001-06-21, Current Portfolio Value : 73963.54237365723
# 2001-06-21, LIMIT SELL CREATE 2117 shares at 215.91514058794291
# 2001-06-22, Current Portfolio Value : 72894.46318817139
# 2001-06-22, LIMIT SELL CREATE 2117 shares at 215.8446253742471
# 2001-06-25, Current Portfolio Value : 72915.62963485718
# 2001-06-25, LIMIT SELL CREATE 2117 shares at 217.5771048681925
# 2001-06-26, Current Portfolio Value : 74281.09560394287
# 2001-06-26, LIMIT SELL CREATE 2117 shares at 213.3365707465792
# 2001-06-27, Current Portfolio Value : 75339.59560394287
# 2001-06-27, LIMIT SELL CREATE 2117 shares at 212.0472858258973
# 2001-06-28, Current Portfolio Value : 77033.19398880005
# 2001-06-28, LIMIT SELL CREATE 2117 shares at 214.8071541547842
# 2001-06-29, Current Portfolio Value : 77308.40625
# 2001-06-29, LIMIT SELL CREATE 2117 shares at 215.75397613048557
# 2001-07-02, Current Portfolio Value : 74768.00463485718
# 2001-07-02, LIMIT SELL CREATE 2117 shares at 215.6834762862783
# 2001-07-03, Current Portfolio Value : 74630.40254211426
# 2001-07-03, LIMIT SELL CREATE 2117 shares at 220.87083238359293
# 2001-07-05, Current Portfolio Value : 72555.74351119995
# 2001-07-05, LIMIT SELL CREATE 2117 shares at 221.011847441496
# 2001-07-06, Current Portfolio Value : 69962.41366577148
# 2001-07-06, LIMIT SELL CREATE 2117 shares at 220.1758241091105
# 2001-07-09, Current Portfolio Value : 69570.77383422852
# 2001-07-09, LIMIT SELL CREATE 2117 shares at 224.20484332861344
# 2001-07-10, Current Portfolio Value : 68289.98980331421
# 2001-07-10, LIMIT SELL CREATE 2117 shares at 225.5646434629911
# 2001-07-11, Current Portfolio Value : 70428.15625
# 2001-07-11, LIMIT SELL CREATE 2117 shares at 222.62346127709256
# 2001-07-12, Current Portfolio Value : 75826.50463485718
# 2001-07-12, LIMIT SELL CREATE 2117 shares at 224.3660077860708
# 2001-07-13, Current Portfolio Value : 75551.29237365723
# 2001-07-13, LIMIT SELL CREATE 2117 shares at 226.5920476674212
# 2001-07-16, Current Portfolio Value : 75381.93657302856
# 2001-07-16, LIMIT SELL CREATE 2117 shares at 225.77615836510145
# 2001-07-17, Current Portfolio Value : 76059.37592697144
# 2001-07-17, LIMIT SELL CREATE 2117 shares at 223.28823776749925
# 2001-07-18, Current Portfolio Value : 74736.25092697144
# 2001-07-18, LIMIT SELL CREATE 2117 shares at 224.0336118561232
# 2001-07-19, Current Portfolio Value : 76853.25092697144
# 2001-07-19, LIMIT SELL CREATE 2117 shares at 219.26930093251772
# 2001-07-20, Current Portfolio Value : 73264.93657302856
# 2001-07-20, LIMIT SELL CREATE 2117 shares at 219.4808158346281
# 2001-07-23, Current Portfolio Value : 71052.66737365723
# 2001-07-23, LIMIT SELL CREATE 2117 shares at 213.7898323348756
# 2001-07-24, Current Portfolio Value : 70237.62592697144
# 2001-07-24, LIMIT SELL CREATE 2117 shares at 219.87364459375004
# 2001-07-25, Current Portfolio Value : 71465.48980331421
# 2001-07-25, LIMIT SELL CREATE 2117 shares at 221.2132953285734
# 2001-07-26, Current Portfolio Value : 70523.41737365723
# 2001-07-26, LIMIT SELL CREATE 2117 shares at 219.0678530454404
# 2001-07-27, Current Portfolio Value : 69337.90254211426
# 2001-07-27, LIMIT SELL CREATE 2117 shares at 216.489267834588
# 2001-07-30, Current Portfolio Value : 69687.20948028564
# 2001-07-30, LIMIT SELL CREATE 2117 shares at 217.9095007981401
# 2001-07-31, Current Portfolio Value : 70100.02383422852
# 2001-07-31, LIMIT SELL CREATE 2117 shares at 214.56542283808668
# 2001-08-01, Current Portfolio Value : 70396.40254211426
# 2001-08-01, LIMIT SELL CREATE 2117 shares at 214.19272810903044
# 2001-08-02, Current Portfolio Value : 71433.72801971436
# 2001-08-02, LIMIT SELL CREATE 2117 shares at 218.01023242642307
# 2001-08-03, Current Portfolio Value : 70840.97060394287
# 2001-08-03, LIMIT SELL CREATE 2117 shares at 225.967539237146
# 2001-08-06, Current Portfolio Value : 70036.50834274292
# 2001-08-06, LIMIT SELL CREATE 2117 shares at 226.60211468245404
# 2001-08-07, Current Portfolio Value : 70269.37963485718
# 2001-08-07, LIMIT SELL CREATE 2117 shares at 227.58922008777543
# 2001-08-08, Current Portfolio Value : 68692.21689605713
# 2001-08-08, LIMIT SELL CREATE 2117 shares at 231.19519413356923
# 2001-08-09, Current Portfolio Value : 68850.99351119995
# 2001-08-09, LIMIT SELL CREATE 2117 shares at 234.01551066111904
# 2001-08-10, Current Portfolio Value : 69390.82269668579
# 2001-08-10, LIMIT SELL CREATE 2117 shares at 234.58963790776417
# 2001-08-13, Current Portfolio Value : 69718.96318817139
# 2001-08-13, LIMIT SELL CREATE 2117 shares at 240.66338315160576
# 2001-08-14, Current Portfolio Value : 68512.27383422852
# 2001-08-14, LIMIT SELL CREATE 2117 shares at 233.64283130155133
# 2001-08-15, Current Portfolio Value : 66935.10705757141
# 2001-08-15, LIMIT SELL CREATE 2117 shares at 241.3886078406754
# 2001-08-16, Current Portfolio Value : 68438.17915725708
# 2001-08-16, LIMIT SELL CREATE 2117 shares at 241.24759278277236
# 2001-08-17, Current Portfolio Value : 65537.88738059998
# 2001-08-17, LIMIT SELL CREATE 2117 shares at 244.7629175848045
# 2001-08-20, Current Portfolio Value : 66405.85705757141
# 2001-08-20, LIMIT SELL CREATE 2117 shares at 243.7657297949617
# 2001-08-21, Current Portfolio Value : 64373.53495788575
# 2001-08-21, LIMIT SELL CREATE 2117 shares at 243.95711066700625
# 2001-08-22, Current Portfolio Value : 64246.51608848571
# 2001-08-22, LIMIT SELL CREATE 2117 shares at 244.22907376777948
# 2001-08-23, Current Portfolio Value : 62616.425119400024
# 2001-08-23, LIMIT SELL CREATE 2117 shares at 245.5385080880156
# 2001-08-24, Current Portfolio Value : 65717.83044242859
# 2001-08-24, LIMIT SELL CREATE 2117 shares at 244.58161909728145
# 2001-08-27, Current Portfolio Value : 65993.04270362854
# 2001-08-27, LIMIT SELL CREATE 2117 shares at 246.2637327770853
# 2001-08-28, Current Portfolio Value : 64331.198026657104
# 2001-08-28, LIMIT SELL CREATE 2117 shares at 246.7673601795232
# 2001-08-29, Current Portfolio Value : 63812.53125
# 2001-08-29, LIMIT SELL CREATE 2117 shares at 245.46799287431983
# 2001-08-30, Current Portfolio Value : 60308.89479637145
# 2001-08-30, LIMIT SELL CREATE 2117 shares at 245.9716202767577
# 2001-08-31, Current Portfolio Value : 60425.330442428596
# 2001-08-31, LIMIT SELL CREATE 2117 shares at 245.5586421180814
# 2001-09-04, Current Portfolio Value : 59419.75463485718
# 2001-09-04, LIMIT SELL CREATE 2117 shares at 242.71819156046587
# 2001-09-05, Current Portfolio Value : 61155.698026657104
# 2001-09-05, LIMIT SELL CREATE 2117 shares at 236.21131875839365
# 2001-09-06, Current Portfolio Value : 59335.076734542854
# 2001-09-06, LIMIT SELL CREATE 2117 shares at 234.9623326368204
# 2001-09-07, Current Portfolio Value : 58678.80786514282
# 2001-09-07, LIMIT SELL CREATE 2117 shares at 236.25161755750227
# 2001-09-10, Current Portfolio Value : 60986.33818817139
# 2001-09-10, LIMIT SELL CREATE 2117 shares at 230.65128330151137
# 2001-09-17, Current Portfolio Value : 56043.14108848571
# 2001-09-17, LIMIT SELL CREATE 2117 shares at 234.06587647526052
# 2001-09-18, Current Portfolio Value : 57535.625926971436
# 2001-09-18, LIMIT SELL CREATE 2117 shares at 238.6589559263757
# 2001-09-19, Current Portfolio Value : 57059.300119400024
# 2001-09-19, LIMIT SELL CREATE 2117 shares at 235.5666762980527
# 2001-09-20, Current Portfolio Value : 53767.364473342896
# 2001-09-20, LIMIT SELL CREATE 2117 shares at 229.21090093840493
# 2001-09-21, Current Portfolio Value : 52655.94028091431
# 2001-09-21, LIMIT SELL CREATE 2117 shares at 228.37487760601945
# 2001-09-24, Current Portfolio Value : 55090.489473342896
# 2001-09-24, LIMIT SELL CREATE 2117 shares at 233.28021895701653
# 2001-09-25, Current Portfolio Value : 54338.955442428596
# 2001-09-25, LIMIT SELL CREATE 2117 shares at 229.0396694659147
# 2001-09-26, Current Portfolio Value : 53248.701734542854
# 2001-09-26, LIMIT SELL CREATE 2117 shares at 235.47602705429117
# 2001-09-27, Current Portfolio Value : 52920.56528091431
# 2001-09-27, LIMIT SELL CREATE 2117 shares at 234.10615990488057
# 2001-09-28, Current Portfolio Value : 54201.34931182861
# 2001-09-28, LIMIT SELL CREATE 2117 shares at 238.8503367984203
# 2001-10-01, Current Portfolio Value : 54857.62221908569
# 2001-10-01, LIMIT SELL CREATE 2117 shares at 237.46032024945544
# 2001-10-02, Current Portfolio Value : 56191.330442428596
# 2001-10-02, LIMIT SELL CREATE 2117 shares at 236.51349827375404
# 2001-10-03, Current Portfolio Value : 59557.36076545715
# 2001-10-03, LIMIT SELL CREATE 2117 shares at 239.43454642958685
# 2001-10-04, Current Portfolio Value : 59779.64479637145
# 2001-10-04, LIMIT SELL CREATE 2117 shares at 238.75967218517013
# 2001-10-05, Current Portfolio Value : 61134.52754211425
# 2001-10-05, LIMIT SELL CREATE 2117 shares at 232.39382981048956
# 2001-10-08, Current Portfolio Value : 61473.24721908569
# 2001-10-08, LIMIT SELL CREATE 2117 shares at 232.02115045092185
# 2001-10-09, Current Portfolio Value : 57789.66770362854
# 2001-10-09, LIMIT SELL CREATE 2117 shares at 237.70206693564157
# 2001-10-10, Current Portfolio Value : 58795.239473342896
# 2001-10-10, LIMIT SELL CREATE 2117 shares at 239.30359838671663
# 2001-10-11, Current Portfolio Value : 59652.625926971436
# 2001-10-11, LIMIT SELL CREATE 2117 shares at 237.16822311861645
# 2001-10-12, Current Portfolio Value : 59716.137380599976
# 2001-10-12, LIMIT SELL CREATE 2117 shares at 234.02557767615195
# 2001-10-15, Current Portfolio Value : 61494.41770362854
# 2001-10-15, LIMIT SELL CREATE 2117 shares at 238.1956119535579
# 2001-10-16, Current Portfolio Value : 61907.23205757141
# 2001-10-16, LIMIT SELL CREATE 2117 shares at 236.94662583198476
# 2001-10-17, Current Portfolio Value : 59345.65995788575
# 2001-10-17, LIMIT SELL CREATE 2117 shares at 233.5320326582355
# 2001-10-18, Current Portfolio Value : 60107.78125
# 2001-10-18, LIMIT SELL CREATE 2117 shares at 237.4804696490097
# 2001-10-19, Current Portfolio Value : 61325.05786514282
# 2001-10-19, LIMIT SELL CREATE 2117 shares at 244.1082081094307
# 2001-10-22, Current Portfolio Value : 63717.26608848571
# 2001-10-22, LIMIT SELL CREATE 2117 shares at 250.8769616277548
# 2001-10-23, Current Portfolio Value : 64003.061573028564
# 2001-10-23, LIMIT SELL CREATE 2117 shares at 249.6581765512802
# 2001-10-24, Current Portfolio Value : 64945.125926971436
# 2001-10-24, LIMIT SELL CREATE 2117 shares at 251.7129695906517
# 2001-10-25, Current Portfolio Value : 66257.66770362854
# 2001-10-25, LIMIT SELL CREATE 2117 shares at 255.08727933478085
# 2001-10-26, Current Portfolio Value : 65876.60705757141
# 2001-10-26, LIMIT SELL CREATE 2117 shares at 257.7061479752532
# 2001-10-29, Current Portfolio Value : 63166.84560394287
# 2001-10-29, LIMIT SELL CREATE 2117 shares at 257.7665808044276
# 2001-10-30, Current Portfolio Value : 62362.387380599976
# 2001-10-30, LIMIT SELL CREATE 2117 shares at 260.365284675857
# 2001-10-31, Current Portfolio Value : 61589.68286514282
# 2001-10-31, LIMIT SELL CREATE 2117 shares at 257.4442518895128
# 2001-11-01, Current Portfolio Value : 65495.54641151428
# 2001-11-01, LIMIT SELL CREATE 2117 shares at 261.38262186525424
# 2001-11-02, Current Portfolio Value : 65029.80786514282
# 2001-11-02, LIMIT SELL CREATE 2117 shares at 262.6316079868274
# 2001-11-05, Current Portfolio Value : 67009.20173454285
# 2001-11-05, LIMIT SELL CREATE 2117 shares at 260.61709837707593
# 2001-11-06, Current Portfolio Value : 68607.53495788574
# 2001-11-06, LIMIT SELL CREATE 2117 shares at 260.133635743681
# 2001-11-07, Current Portfolio Value : 68046.53125
# 2001-11-07, LIMIT SELL CREATE 2117 shares at 262.4704435293701
# 2001-11-08, Current Portfolio Value : 68226.47431182861
# 2001-11-08, LIMIT SELL CREATE 2117 shares at 259.0357316950437
# 2001-11-09, Current Portfolio Value : 69062.6902809143
# 2001-11-09, LIMIT SELL CREATE 2117 shares at 263.04458614550373
# 2001-11-12, Current Portfolio Value : 69676.6222190857
# 2001-11-12, LIMIT SELL CREATE 2117 shares at 263.4474819196586
# 2001-11-13, Current Portfolio Value : 71910.05786514282
# 2001-11-13, LIMIT SELL CREATE 2117 shares at 263.8705424628564
# 2001-11-14, Current Portfolio Value : 69845.97801971436
# 2001-11-14, LIMIT SELL CREATE 2117 shares at 256.40678067004984
# 2001-11-15, Current Portfolio Value : 70025.92915725708
# 2001-11-15, LIMIT SELL CREATE 2117 shares at 254.34190524615693
# 2001-11-16, Current Portfolio Value : 69634.28125
# 2001-11-16, LIMIT SELL CREATE 2117 shares at 254.0095093162093
# 2001-11-19, Current Portfolio Value : 70470.4972190857
# 2001-11-19, LIMIT SELL CREATE 2117 shares at 253.68719577078315
# 2001-11-20, Current Portfolio Value : 69263.80786514282
# ...
# 2001-11-29, LIMIT SELL CREATE 13473 shares at 408.1908335219325
# 2001-11-30, Current Portfolio Value : 240666.53034591675
# 2001-11-30, LIMIT SELL CREATE 13473 shares at 411.4030341563632
# 2001-12-03, Current Portfolio Value : 240262.35679244995
# 2001-12-03, LIMIT SELL CREATE 13473 shares at 412.6516530808652
# 2001-12-04, Current Portfolio Value : 240127.62370872498
# 2001-12-04, LIMIT SELL CREATE 13473 shares at 411.47352863886
# 2001-12-05, Current Portfolio Value : 242384.34504127502
# 2001-12-05, LIMIT SELL CREATE 13473 shares at 413.2357063216381
# 2001-12-06, Current Portfolio Value : 243159.05384826654
# 2001-12-06, LIMIT SELL CREATE 13473 shares at 412.3495777700792
# 2001-12-07, Current Portfolio Value : 242990.63106918335
# 2001-12-07, LIMIT SELL CREATE 13473 shares at 411.4836080591995
# 2001-12-10, Current Portfolio Value : 240902.30681800842
# 2001-12-10, LIMIT SELL CREATE 13473 shares at 414.4944046664796
# 2001-12-11, Current Portfolio Value : 241643.32592964172
# 2001-12-11, LIMIT SELL CREATE 13473 shares at 413.8096801420715
# 2001-12-12, Current Portfolio Value : 234772.09284591675
# 2001-12-12, LIMIT SELL CREATE 13473 shares at 415.9242687774532
# 2001-12-13, Current Portfolio Value : 235782.578125
# 2001-12-13, LIMIT SELL CREATE 13473 shares at 416.0853858531856
# 2001-12-14, Current Portfolio Value : 239016.09504127502
# 2001-12-14, LIMIT SELL CREATE 13473 shares at 415.5718578248496
# 2001-12-17, Current Portfolio Value : 238982.40534591675
# 2001-12-17, LIMIT SELL CREATE 13473 shares at 414.7864312868661
# 2001-12-18, Current Portfolio Value : 239150.828125
# 2001-12-18, LIMIT SELL CREATE 13473 shares at 409.5502338803493
# 2001-12-19, Current Portfolio Value : 233828.98695755005
# 2001-12-19, LIMIT SELL CREATE 13473 shares at 408.67418474913006
# 2001-12-20, Current Portfolio Value : 233290.08032035828
# 2001-12-20, LIMIT SELL CREATE 13473 shares at 410.7988528048513
# 2001-12-21, Current Portfolio Value : 233694.25387382507
# 2001-12-21, LIMIT SELL CREATE 13473 shares at 408.4627320315799
# 2001-12-24, Current Portfolio Value : 236658.33032035828
# 2001-12-24, LIMIT SELL CREATE 13473 shares at 403.0352100182521
# 2001-12-26, Current Portfolio Value : 236590.95092964172
# 2001-12-26, LIMIT SELL CREATE 13473 shares at 404.5355686117224
# 2001-12-27, Current Portfolio Value : 237635.12590408325
# 2001-12-27, LIMIT SELL CREATE 13473 shares at 403.8911310387323
# 2001-12-28, Current Portfolio Value : 238477.18840408325
# 2001-12-28, LIMIT SELL CREATE 13473 shares at 404.2838289427541
# 2001-12-31, Current Portfolio Value : 238376.11931800842
# 2001-12-31, LIMIT SELL CREATE 13473 shares at 400.6588022935625
# 2002-01-02, Current Portfolio Value : 237197.23695755005
# 2002-01-02, LIMIT SELL CREATE 13473 shares at 401.9376287491431
# 2002-01-03, Current Portfolio Value : 234536.31637382507
# 2002-01-03, LIMIT SELL CREATE 13473 shares at 403.0654175493307
# 2002-01-04, Current Portfolio Value : 235782.578125
# 2002-01-04, LIMIT SELL CREATE 13473 shares at 400.0143339906325
# 2002-01-07, Current Portfolio Value : 234266.87590408325
# 2002-01-07, LIMIT SELL CREATE 13473 shares at 400.11503600420775
# 2002-01-08, Current Portfolio Value : 233626.90018081665
# 2002-01-08, LIMIT SELL CREATE 13473 shares at 392.0794947079612
# 2002-01-09, Current Portfolio Value : 234300.5399017334
# 2002-01-09, LIMIT SELL CREATE 13473 shares at 400.8400474800342
# 2002-01-10, Current Portfolio Value : 237803.52298545837
# 2002-01-10, LIMIT SELL CREATE 13473 shares at 401.4643569422851
# 2002-01-11, Current Portfolio Value : 241677.015625
# 2002-01-11, LIMIT SELL CREATE 13473 shares at 398.31257137001154
# 2002-01-14, Current Portfolio Value : 244203.203125
# 2002-01-14, LIMIT SELL CREATE 13473 shares at 401.6456021287567
# 2002-01-15, Current Portfolio Value : 244708.44576454163
# 2002-01-15, LIMIT SELL CREATE 13473 shares at 407.7679280868322
# 2002-01-16, Current Portfolio Value : 245887.328125
# 2002-01-16, LIMIT SELL CREATE 13473 shares at 404.25362141167545
# 2002-01-17, Current Portfolio Value : 243664.2707901001
# 2002-01-17, LIMIT SELL CREATE 13473 shares at 400.8702550111127
# 2002-01-18, Current Portfolio Value : 244472.66929244995
# 2002-01-18, LIMIT SELL CREATE 13473 shares at 403.22653462506327
# 2002-01-22, Current Portfolio Value : 244371.62590408325
# 2002-01-22, LIMIT SELL CREATE 13473 shares at 407.707513024675
# 2002-01-23, Current Portfolio Value : 243866.38326454163
# 2002-01-23, LIMIT SELL CREATE 13473 shares at 412.20858880508575
# 2002-01-24, Current Portfolio Value : 250367.10679244995
# 2002-01-24, LIMIT SELL CREATE 13473 shares at 413.1148761973237
# 2002-01-25, Current Portfolio Value : 249929.21784591675
# 2002-01-25, LIMIT SELL CREATE 13473 shares at 414.5246121975582
# 2002-01-28, Current Portfolio Value : 249255.578125
# 2002-01-28, LIMIT SELL CREATE 13473 shares at 412.8027214661983
# 2002-01-29, Current Portfolio Value : 245718.90534591675
# 2002-01-29, LIMIT SELL CREATE 13473 shares at 414.9777251637371
# 2002-01-30, Current Portfolio Value : 244203.203125
# 2002-01-30, LIMIT SELL CREATE 13473 shares at 418.9350961146733
# 2002-01-31, Current Portfolio Value : 250434.46048545843
# 2002-01-31, LIMIT SELL CREATE 13473 shares at 421.45249280435627
# 2002-02-01, Current Portfolio Value : 252522.7847366333
# 2002-02-01, LIMIT SELL CREATE 13473 shares at 417.6260313980741
# 2002-02-04, Current Portfolio Value : 248918.75826454163
# 2002-02-04, LIMIT SELL CREATE 13473 shares at 422.9729795085656
# 2002-02-05, Current Portfolio Value : 252623.828125
# 2002-02-05, LIMIT SELL CREATE 13473 shares at 422.62056855596205
# 2002-02-06, Current Portfolio Value : 251276.52298545843
# 2002-02-06, LIMIT SELL CREATE 13473 shares at 411.9065134942998
# 2002-02-07, Current Portfolio Value : 252960.64798545843
# 2002-02-07, LIMIT SELL CREATE 13473 shares at 415.8437256045569
# 2002-02-08, Current Portfolio Value : 250703.92665290833
# 2002-02-08, LIMIT SELL CREATE 13473 shares at 417.5253601144388
# 2002-02-11, Current Portfolio Value : 250602.88326454163
# 2002-02-11, LIMIT SELL CREATE 13473 shares at 418.66319760502586
# 2002-02-12, Current Portfolio Value : 254510.03990173346
# 2002-02-12, LIMIT SELL CREATE 13473 shares at 420.60665120421567
# 2002-02-13, Current Portfolio Value : 253297.46784591675
# 2002-02-13, LIMIT SELL CREATE 13473 shares at 416.4176994249903
# 2002-02-14, Current Portfolio Value : 251040.7465133667
# 2002-02-14, LIMIT SELL CREATE 13473 shares at 417.98855250095727
# 2002-02-15, Current Portfolio Value : 250299.72740173346
# 2002-02-15, LIMIT SELL CREATE 13473 shares at 412.0172949282147
# 2002-02-19, Current Portfolio Value : 248615.60240173346
# 2002-02-19, LIMIT SELL CREATE 13473 shares at 414.9475176326585
# 2002-02-20, Current Portfolio Value : 248851.37887382502
# 2002-02-20, LIMIT SELL CREATE 13473 shares at 415.088506597652
# 2002-02-21, Current Portfolio Value : 252354.36195755005
# 2002-02-21, LIMIT SELL CREATE 13473 shares at 418.4618243078153
# 2002-02-22, Current Portfolio Value : 251714.41193199158
# 2002-02-22, LIMIT SELL CREATE 13473 shares at 424.835859204919
# 2002-02-25, Current Portfolio Value : 250501.83987617493
# 2002-02-25, LIMIT SELL CREATE 13473 shares at 424.4733688319759
# 2002-02-26, Current Portfolio Value : 248245.09284591675
# 2002-02-26, LIMIT SELL CREATE 13473 shares at 414.05134039070026
# 2002-02-27, Current Portfolio Value : 245718.90534591675
# 2002-02-27, LIMIT SELL CREATE 13473 shares at 418.00868061169626
# 2002-02-28, Current Portfolio Value : 244169.51342964172
# 2002-02-28, LIMIT SELL CREATE 13473 shares at 413.7291062392352
# 2002-03-01, Current Portfolio Value : 239992.890625
# 2002-03-01, LIMIT SELL CREATE 13473 shares at 414.64544232187257
# 2002-03-04, Current Portfolio Value : 229483.94137382507
# 2002-03-04, LIMIT SELL CREATE 13473 shares at 410.5773206669616
# 2002-03-05, Current Portfolio Value : 231572.265625
# 2002-03-05, LIMIT SELL CREATE 13473 shares at 408.7849354531049
# 2002-03-06, Current Portfolio Value : 235883.6215133667
# 2002-03-06, LIMIT SELL CREATE 13473 shares at 412.5207742661513
# 2002-03-07, Current Portfolio Value : 237803.52298545837
# 2002-03-07, LIMIT SELL CREATE 13473 shares at 420.11322055667847
# 2002-03-08, Current Portfolio Value : 240733.9097366333
# 2002-03-08, LIMIT SELL CREATE 13473 shares at 424.7150290806047
# 2002-03-11, Current Portfolio Value : 246156.79429244995
# 2002-03-11, LIMIT SELL CREATE 13473 shares at 420.2240019905934
# 2002-03-12, Current Portfolio Value : 247032.5207901001
# 2002-03-12, LIMIT SELL CREATE 13473 shares at 430.8675625697588
# 2002-03-13, Current Portfolio Value : 248076.69576454163
# 2002-03-13, LIMIT SELL CREATE 13473 shares at 432.7002040050936
# 2002-03-14, Current Portfolio Value : 250602.88326454163
# 2002-03-14, LIMIT SELL CREATE 13473 shares at 428.3199276190571
# 2002-03-15, Current Portfolio Value : 251108.12590408325
# 2002-03-15, LIMIT SELL CREATE 13473 shares at 426.3563766390684
# 2002-03-18, Current Portfolio Value : 252388.05165290833
# 2002-03-18, LIMIT SELL CREATE 13473 shares at 422.6608247774401
# 2002-03-19, Current Portfolio Value : 253667.97740173346
# 2002-03-19, LIMIT SELL CREATE 13473 shares at 419.75073018373536
# 2002-03-20, Current Portfolio Value : 253634.31340408325
# 2002-03-20, LIMIT SELL CREATE 13473 shares at 421.674024942246
# 2002-03-21, Current Portfolio Value : 253769.0207901001
# 2002-03-21, LIMIT SELL CREATE 13473 shares at 421.21080182578754
# 2002-03-22, Current Portfolio Value : 251545.98915290833
# 2002-03-22, LIMIT SELL CREATE 13473 shares at 419.16667694296245
# 2002-03-25, Current Portfolio Value : 250434.46048545843
# 2002-03-25, LIMIT SELL CREATE 13473 shares at 420.254209521672
# 2002-03-26, Current Portfolio Value : 250535.50387382502
# 2002-03-26, LIMIT SELL CREATE 13473 shares at 426.6584519498544
# 2002-03-27, Current Portfolio Value : 253971.13326454163
# 2002-03-27, LIMIT SELL CREATE 13473 shares at 425.8025309293741
# 2002-03-28, Current Portfolio Value : 257406.73695755005
# 2002-03-28, LIMIT SELL CREATE 13473 shares at 424.17126279124994
# 2002-04-01, Current Portfolio Value : 255621.56856918335
# 2002-04-01, LIMIT SELL CREATE 13473 shares at 418.2805791213437
# 2002-04-02, Current Portfolio Value : 259427.68181800842
# 2002-04-02, LIMIT SELL CREATE 13473 shares at 417.434706791263
# 2002-04-03, Current Portfolio Value : 258181.44576454163
# 2002-04-03, LIMIT SELL CREATE 13473 shares at 406.7206824595408
# 2002-04-04, Current Portfolio Value : 258821.3957901001
# 2002-04-04, LIMIT SELL CREATE 13473 shares at 417.4044992601844
# 2002-04-05, Current Portfolio Value : 260842.36634826654
# 2002-04-05, LIMIT SELL CREATE 13473 shares at 415.41074074911705
# 2002-04-08, Current Portfolio Value : 259629.79429244995
# 2002-04-08, LIMIT SELL CREATE 13473 shares at 420.425375287804
# 2002-04-09, Current Portfolio Value : 260370.81340408325
# 2002-04-09, LIMIT SELL CREATE 13473 shares at 419.7406507633958
# 2002-04-10, Current Portfolio Value : 262560.15534591675
# 2002-04-10, LIMIT SELL CREATE 13473 shares at 423.08376094248047
# 2002-04-11, Current Portfolio Value : 263907.46048545843
# 2002-04-11, LIMIT SELL CREATE 13473 shares at 415.5718578248496
# 2002-04-12, Current Portfolio Value : 258686.68840408325
# 2002-04-12, LIMIT SELL CREATE 13473 shares at 415.2093367219664
# 2002-04-15, Current Portfolio Value : 257676.203125
# 2002-04-15, LIMIT SELL CREATE 13473 shares at 411.5440231213568
# 2002-04-16, Current Portfolio Value : 258855.08548545843
# 2002-04-16, LIMIT SELL CREATE 13473 shares at 410.869347287348
# 2002-04-17, Current Portfolio Value : 268016.7295970916
# 2002-04-17, LIMIT SELL CREATE 13473 shares at 409.9127242532925
# 2002-04-18, Current Portfolio Value : 283813.8303203583
# 2002-04-18, LIMIT SELL CREATE 13473 shares at 408.0901315083572
# 2002-04-19, Current Portfolio Value : 288933.5590133667
# 2002-04-19, LIMIT SELL CREATE 13473 shares at 401.3938624597884
# 2002-04-22, Current Portfolio Value : 289640.8884296417
# 2002-04-22, LIMIT SELL CREATE 13473 shares at 403.19632709398456
# 2002-04-23, Current Portfolio Value : 286811.5707645416
# 2002-04-23, LIMIT SELL CREATE 13473 shares at 393.45902317711705
# 2002-04-24, Current Portfolio Value : 289640.8884296417
# 2002-04-24, LIMIT SELL CREATE 13473 shares at 395.160785797738
# 2002-04-25, Current Portfolio Value : 293042.828125
# 2002-04-25, LIMIT SELL CREATE 13473 shares at 389.7030869832716
# 2002-04-26, Current Portfolio Value : 289809.31120872503
# 2002-04-26, LIMIT SELL CREATE 13473 shares at 396.1677444736112
# 2002-04-29, Current Portfolio Value : 289674.578125
# 2002-04-29, LIMIT SELL CREATE 13473 shares at 396.9934579630128
# 2002-04-30, Current Portfolio Value : 295771.10240173346
# 2002-04-30, LIMIT SELL CREATE 13473 shares at 407.51618841786393
# 2002-05-01, Current Portfolio Value : 301833.96268081665
# 2002-05-01, LIMIT SELL CREATE 13473 shares at 411.3023321427879
# 2002-05-02, Current Portfolio Value : 302911.8016529083
# 2002-05-02, LIMIT SELL CREATE 13473 shares at 407.8081843083103
# 2002-05-03, Current Portfolio Value : 301631.87590408325
# 2002-05-03, LIMIT SELL CREATE 13473 shares at 406.0460066255321
# 2002-05-06, Current Portfolio Value : 302305.515625
# 2002-05-06, LIMIT SELL CREATE 13473 shares at 406.3581613566577
# 2002-05-07, Current Portfolio Value : 298263.62590408325
# 2002-05-07, LIMIT SELL CREATE 13473 shares at 423.2851342396911
# 2002-05-08, Current Portfolio Value : 302844.4479598999
# 2002-05-08, LIMIT SELL CREATE 13473 shares at 431.0488077562304
# 2002-05-09, Current Portfolio Value : 298095.203125
# 2002-05-09, LIMIT SELL CREATE 13473 shares at 427.57478803249177
# 2002-05-10, Current Portfolio Value : 297084.71784591675
# 2002-05-10, LIMIT SELL CREATE 13473 shares at 427.333127783863
# 2002-05-13, Current Portfolio Value : 295973.2148761749
# 2002-05-13, LIMIT SELL CREATE 13473 shares at 438.1176465980819
# 2002-05-14, Current Portfolio Value : 294390.1332645416
# 2002-05-14, LIMIT SELL CREATE 13473 shares at 445.3576819360055
# 2002-05-15, Current Portfolio Value : 297724.69356918335
# 2002-05-15, LIMIT SELL CREATE 13473 shares at 452.2855625428036
# 2002-05-16, Current Portfolio Value : 299779.328125
# 2002-05-16, LIMIT SELL CREATE 13473 shares at 452.6178453846681
# 2002-05-17, Current Portfolio Value : 298263.62590408325
# 2002-05-17, LIMIT SELL CREATE 13473 shares at 457.8037071493672
# 2002-05-20, Current Portfolio Value : 292706.0082645416
# 2002-05-20, LIMIT SELL CREATE 13473 shares at 456.6356313977614
# 2002-05-21, Current Portfolio Value : 293716.46784591675
# 2002-05-21, LIMIT SELL CREATE 13473 shares at 458.6092617980897
# 2002-05-22, Current Portfolio Value : 290920.8398761749
# 2002-05-22, LIMIT SELL CREATE 13473 shares at 463.6742627085344
# 2002-05-23, Current Portfolio Value : 296411.078125
# 2002-05-23, LIMIT SELL CREATE 13473 shares at 457.2699895504119
# 2002-05-24, Current Portfolio Value : 297926.78034591675
# 2002-05-24, LIMIT SELL CREATE 13473 shares at 455.1856084461088
# 2002-05-28, Current Portfolio Value : 299375.128873825
# 2002-05-28, LIMIT SELL CREATE 13473 shares at 460.5123977159212
# 2002-05-29, Current Portfolio Value : 302777.06856918335
# 2002-05-29, LIMIT SELL CREATE 13473 shares at 459.938454625428
# 2002-05-30, Current Portfolio Value : 307122.1141529083
# 2002-05-30, LIMIT SELL CREATE 13473 shares at 458.9818315913724
# 2002-05-31, Current Portfolio Value : 305842.18840408325
# 2002-05-31, LIMIT SELL CREATE 13473 shares at 465.8392177156737
# Final Portfolio Value: 305842.18840408325
#
# STRATEGY INFO:
# OrderedDict([('sharperatio', 0.6276447431375926)])
# AutoOrderedDict([('len', 1), ('drawdown', 0.41674815646385877), ('moneydown', 1279.9257488250732), ('max', AutoOrderedDict([('len', 79), ('drawdown', 19.84538234303845), ('moneydown', 44225.138946533174)]))])
# OrderedDict([('rtot', 1.117899058763177), ('ravg', 0.00206254438886195), ('rnorm', 0.6816260058973242), ('rnorm100', 68.16260058973242)])
# For UNH, return was 205.84218840408326% for buy and hold vs 205.84218840408326%  for strategy
# {'MSFT': <backtrader.cerebro.Cerebro at 0x7fb660776410>,
#  'ADSK': <backtrader.cerebro.Cerebro at 0x7fb6609fea10>,
#  'XOM': <backtrader.cerebro.Cerebro at 0x7fb690825c50>,
#  'WAT': <backtrader.cerebro.Cerebro at 0x7fb6904be050>,
#  'HD': <backtrader.cerebro.Cerebro at 0x7fb67044e350>,
#  'UNH': <backtrader.cerebro.Cerebro at 0x7fb680f877d0>}

# %% [markdown]
# ### Library additionally has plotting
# Not sure how to reformat this, it's pretty ugly

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 8]
plt.rcParams.update({'font.size': 12}) 
cerebro_dict['UNH'].plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-22-73966f5e4f6c> in <module>
#       3 plt.rcParams['figure.figsize'] = [10, 8]
#       4 plt.rcParams.update({'font.size': 12})
# ----> 5 cerebro_dict['UNH'].plot()
#
# /opt/anaconda3/lib/python3.7/site-packages/backtrader/cerebro.py in plot(self, plotter, numfigs, iplot, start, end, width, height, dpi, tight, use, **kwargs)
#     972
#     973         if not plotter:
# --> 974             from . import plot
#     975             if self.p.oldsync:
#     976                 plotter = plot.Plot_OldSync(**kwargs)
#
# /opt/anaconda3/lib/python3.7/site-packages/backtrader/plot/__init__.py in <module>
#      40
#      41
# ---> 42 from .plot import Plot, Plot_OldSync
#      43 from .scheme import PlotScheme
#
# /opt/anaconda3/lib/python3.7/site-packages/backtrader/plot/plot.py in <module>
#      42 from .finance import plot_candlestick, plot_ohlc, plot_volume, plot_lineonclose
#      43 from .formatters import (MyVolFormatter, MyDateFormatter, getlocator)
# ---> 44 from . import locator as loc
#      45 from .multicursor import MultiCursor
#      46 from .scheme import PlotScheme
#
# /opt/anaconda3/lib/python3.7/site-packages/backtrader/plot/locator.py in <module>
#      33 from matplotlib.dates import AutoDateFormatter as ADFormatter
#      34
# ---> 35 from matplotlib.dates import (HOURS_PER_DAY, MIN_PER_HOUR, SEC_PER_MIN,
#      36                               MONTHS_PER_YEAR, DAYS_PER_WEEK,
#      37                               SEC_PER_HOUR, SEC_PER_DAY,
#
# ImportError: cannot import name 'warnings' from 'matplotlib.dates' (/opt/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py)

# %% [markdown]
# ### Ways to Improve:

# %% [markdown]
# Increase strategy trading volume. There are certain periods where sell orders are not going through for multiple days in a row, meaning that the price is lower than anticipated by model for that period. For example, if the last sell order didn't go through, we can find a way to use that information to inform our next sell order and make the prediction lower or try a market sell. Maybe train a "bear" model, one that only knows pain and suffering of bear markets, and only produces pessimistic high price predictions.
#
# Smarter entry points. Currently, buy orders are being executed at market price at the open. Returns may increase if entry constraints are increased.
#
# Resizing orders. Orders for this strategy baseline are currently 100% in or 100% out of position. This has beneifits if you want less exposure to the long term movement of the stocks. Depending on the situation and strategy, we might want to reserve a cash position to expose ourselves less to short term movements.
