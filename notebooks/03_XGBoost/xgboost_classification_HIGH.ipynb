# %% [markdown]
# # Using XGBoost to generate prediction models and find relevant features
# This notebook uses the XGBoost algorithm in combination with the SHAP library in attempt to generate accurate predictions and to find useful features to reduce dimensionality for our downstream models.

# %% [markdown]
# ### This class will handle the OHLCV pandas dataframe+indicators, create a prediction df, normalize, and optionally plot residuals and/or feature importances

# %%
import sys
sys.path.append('../../scripts')

# %%
from xgboost_for_tickers import TickerXGBClassifier

# %% [markdown]
# ## Analysis: Feature Importance

# %% [markdown]
# ### Example using MSFT data:

# %%
def preprocess(data):
    # keep feature data only
    data = data.iloc[:, 7:]
    data.columns = [c.lower() for c in data.columns]
    return data

ticker = 'MSFT'
df = pd.read_csv(f'../../data/ticker_data/{ticker}_full_data.csv')
df= preprocess(df)

# %%
modler = TickerXGBClassifier(df.copy())
modler.predict_with_xgb(target='close', gsearch_params={
    'max_depth': [1,2,3], 'learning_rate': [0.01, 0.005], 'colsample_bytree': [0.75, 1], 
    'n_estimators': [200, 300,500], 'objective': ['binary:logistic'], 'gamma':[0, 0.1]},
    normilization_type='return', test_size=0.2, timeframe=-1)
# Out:
# normilization_type: return
# target: close 1 day shifted
# SCORE=ACCURACY. START: Model is selected and saved to object based on best test score.
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.5128676470588235
# Train Score: 0.546896551724138
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.5367647058823529
# Train Score: 0.5542528735632184
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.5477941176470589
# Train Score: 0.5627586206896552
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.5569852941176471
# Train Score: 0.5889655172413794
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.5514705882352942
# Train Score: 0.6011494252873564
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.47058823529411764
# Train Score: 0.6167816091954023
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.4632352941176471
# Train Score: 0.6381609195402299
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.46139705882352944
# Train Score: 0.663448275862069
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.4577205882352941
# Train Score: 0.6993103448275862
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.005, 'max_depth': 1, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.44669117647058826
# Train Score: 0.5383908045977012
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.005, 'max_depth': 1, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.4577205882352941
# Train Score: 0.5464367816091954
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.005, 'max_depth': 1, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.5275735294117647
# Train Score: 0.5519540229885057
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.005, 'max_depth': 2, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.5202205882352942
# Train Score: 0.5703448275862069
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.005, 'max_depth': 2, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.5422794117647058
# Train Score: 0.58
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.005, 'max_depth': 2, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.5404411764705882
# Train Score: 0.5951724137931035
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.005, 'max_depth': 3, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.45036764705882354
# Train Score: 0.6064367816091955
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.005, 'max_depth': 3, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.45588235294117646
# Train Score: 0.6232183908045977
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.005, 'max_depth': 3, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.45955882352941174
# Train Score: 0.6514942528735632
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.5128676470588235
# Train Score: 0.546896551724138
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.5367647058823529
# Train Score: 0.5542528735632184
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.5477941176470589
# Train Score: 0.5627586206896552
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.5569852941176471
# Train Score: 0.5889655172413794
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.5514705882352942
# Train Score: 0.6011494252873564
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.47058823529411764
# Train Score: 0.6167816091954023
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.45588235294117646
# Train Score: 0.6393103448275862
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.45955882352941174
# Train Score: 0.6616091954022989
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.45036764705882354
# Train Score: 0.6944827586206896
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0.1, 'learning_rate': 0.005, 'max_depth': 1, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.44669117647058826
# Train Score: 0.5383908045977012
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0.1, 'learning_rate': 0.005, 'max_depth': 1, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.4577205882352941
# Train Score: 0.5464367816091954
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0.1, 'learning_rate': 0.005, 'max_depth': 1, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.5275735294117647
# Train Score: 0.5519540229885057
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0.1, 'learning_rate': 0.005, 'max_depth': 2, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.5202205882352942
# Train Score: 0.5703448275862069
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0.1, 'learning_rate': 0.005, 'max_depth': 2, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.5422794117647058
# Train Score: 0.58
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0.1, 'learning_rate': 0.005, 'max_depth': 2, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.5404411764705882
# Train Score: 0.5951724137931035
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0.1, 'learning_rate': 0.005, 'max_depth': 3, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.45036764705882354
# Train Score: 0.6068965517241379
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0.1, 'learning_rate': 0.005, 'max_depth': 3, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.4540441176470588
# Train Score: 0.6213793103448276
#
# Testing {'colsample_bytree': 0.75, 'gamma': 0.1, 'learning_rate': 0.005, 'max_depth': 3, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.46139705882352944
# Train Score: 0.6526436781609195
#
# Testing {'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.5128676470588235
# Train Score: 0.546896551724138
#
# Testing {'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.5367647058823529
# Train Score: 0.5540229885057472
#
# Testing {'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.5441176470588235
# Train Score: 0.5636781609195403
#
# Testing {'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.5459558823529411
# Train Score: 0.5898850574712644
#
# Testing {'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.5477941176470589
# Train Score: 0.6018390804597701
#
# Testing {'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.46691176470588236
# Train Score: 0.6181609195402299
#
# Testing {'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.4577205882352941
# Train Score: 0.6395402298850574
#
# Testing {'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.46139705882352944
# Train Score: 0.6641379310344827
#
# Testing {'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.45955882352941174
# Train Score: 0.6940229885057472
#
# Testing {'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.005, 'max_depth': 1, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.44669117647058826
# Train Score: 0.5379310344827586
#
# Testing {'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.005, 'max_depth': 1, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.4577205882352941
# Train Score: 0.5457471264367816
#
# Testing {'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.005, 'max_depth': 1, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.5275735294117647
# Train Score: 0.5501149425287356
#
# Testing {'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.005, 'max_depth': 2, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.5330882352941176
# Train Score: 0.5701149425287356
#
# Testing {'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.005, 'max_depth': 2, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.5386029411764706
# Train Score: 0.5783908045977012
#
# Testing {'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.005, 'max_depth': 2, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.5459558823529411
# Train Score: 0.5972413793103448
#
# Testing {'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.005, 'max_depth': 3, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.47058823529411764
# Train Score: 0.607816091954023
#
# Testing {'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.005, 'max_depth': 3, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.4522058823529412
# Train Score: 0.6255172413793103
#
# Testing {'colsample_bytree': 1, 'gamma': 0, 'learning_rate': 0.005, 'max_depth': 3, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.47058823529411764
# Train Score: 0.6535632183908046
#
# Testing {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.5128676470588235
# Train Score: 0.546896551724138
#
# Testing {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.5367647058823529
# Train Score: 0.5540229885057472
#
# Testing {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.5441176470588235
# Train Score: 0.5636781609195403
#
# Testing {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.5459558823529411
# Train Score: 0.5898850574712644
#
# Testing {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.5477941176470589
# Train Score: 0.6018390804597701
#
# Testing {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.46691176470588236
# Train Score: 0.6181609195402299
#
# Testing {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.45955882352941174
# Train Score: 0.64
#
# Testing {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.45955882352941174
# Train Score: 0.6639080459770115
#
# Testing {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.45588235294117646
# Train Score: 0.6963218390804597
#
# Testing {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.005, 'max_depth': 1, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.44669117647058826
# Train Score: 0.5379310344827586
#
# Testing {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.005, 'max_depth': 1, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.4577205882352941
# Train Score: 0.5457471264367816
#
# Testing {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.005, 'max_depth': 1, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.5275735294117647
# Train Score: 0.5501149425287356
#
# Testing {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.005, 'max_depth': 2, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.5330882352941176
# Train Score: 0.5701149425287356
#
# Testing {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.005, 'max_depth': 2, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.5386029411764706
# Train Score: 0.5783908045977012
#
# Testing {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.005, 'max_depth': 2, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.5459558823529411
# Train Score: 0.5972413793103448
#
# Testing {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.005, 'max_depth': 3, 'n_estimators': 200, 'objective': 'binary:logistic'}...
# Test Score: 0.47058823529411764
# Train Score: 0.607816091954023
#
# Testing {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.005, 'max_depth': 3, 'n_estimators': 300, 'objective': 'binary:logistic'}...
# Test Score: 0.4522058823529412
# Train Score: 0.6262068965517241
#
# Testing {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.005, 'max_depth': 3, 'n_estimators': 500, 'objective': 'binary:logistic'}...
# Test Score: 0.47058823529411764
# Train Score: 0.6510344827586206
#
# Best TEST Accuracy is 0.5569852941176471 with params: {'colsample_bytree': 0.75, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 200, 'objective': 'binary:logistic'}
# TRAIN Accuracy for best test params is 0.5889655172413794
# TRAIN REPORT:
#               precision    recall  f1-score   support
#
#            0       0.75      0.57      0.65      2890
#            1       0.42      0.62      0.50      1460
#
#     accuracy                           0.59      4350
#    macro avg       0.59      0.60      0.58      4350
# weighted avg       0.64      0.59      0.60      4350
#
# TEST REPORT:
#               precision    recall  f1-score   support
#
#            0       0.23      0.49      0.31       112
#            1       0.81      0.57      0.67       432
#
#     accuracy                           0.56       544
#    macro avg       0.52      0.53      0.49       544
# weighted avg       0.69      0.56      0.60       544
#
# HOLDOUT REPORT:
#               precision    recall  f1-score   support
#
#            0       0.43      0.16      0.24       241
#            1       0.56      0.83      0.67       303
#
#     accuracy                           0.53       544
#    macro avg       0.49      0.50      0.45       544
# weighted avg       0.50      0.53      0.48       544
#
# GENERATING FEATURE IMPORTANCES...

# %%
modler.test_data['close-1_return'].value_counts()
# Out:
# 1    608
# 0    481
# Name: close-1_return, dtype: int64

# %%
608 / (481+608)
# Out:
# 0.5583103764921947

# %% [markdown]
# Model is worse than just predicting a "1" (increase) every time for combined test + final holdout
