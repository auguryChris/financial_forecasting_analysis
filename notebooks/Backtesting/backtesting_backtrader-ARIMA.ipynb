# %% [markdown]
# # Backtesting with backtrader library
# Notes:
# Timestamp must be in the exact format specified for datafeed   **Timestamp needs to be first column index**
# Params for datafeed need to be specified as tuple of tuples
# Within strategy data is accessed via self.datas[0] for ex: self.datas[0].high_delta[0] would get you the first timeperiod's high_delta
# The current data has already happened and cannot be used to execute an order (ex. you cannot look at the current close price and simultaneously buy the current close, the order will be executed at open instead), orders will be executed on the following day.

# %%
import backtrader as bt
import datetime
import pandas as pd

# %% [markdown]
# ## Define Strategies and Data utils

# %%
class BasicStrategy(bt.Strategy):
    def __init__(self):
        # To keep track of pending orders
        self.order = None
        print('***The limit sells for this strategy are valid for 1 day***')
        
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        elif order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)
            
            self.bar_executed = len(self)
        
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')
        
        # set no pending order
        self.order = None


    def next(self):
        # STRATEGY 
        data = self.datas[0]
        self.log(f'Current Portfolio Value : {self.broker.get_value()}')
        
        # cancel if there is an order pending, this strategy should have 1 working order per day
        if self.order:
            self.log('ORDER CANCELLED')
            self.cancel(self.order)
        
        # Check if we are in the market
        if not self.position:
            # BUY
            try:
                self.size = int(self.broker.get_cash() / self.datas[0].open[1])
            except:
                print('Size Exception. If at the end of data, ignore.')
            # invest if prediction looks good
            self.log(f'MARKET BUY CREATE {self.size} shares at next open, current close price: {data.close[0]}')
            self.buy(size=self.size) # market order buys at next open                      
                
        else:
            # place sell order at predicted high if predicted high is greater than current close price
            # TODO: Make prediction and close a filter in the class constructor (more optimal)
            if data.prediction[0] >= data.close[0]:
                self.log(f'LIMIT SELL CREATE {self.size} shares at {data.prediction[0]}')  
                self.sell(exectype=bt.Order.Limit,
                             price=data.prediction[0],
                             valid=data.datetime.date(0) + datetime.timedelta(days=2),
                             size=self.size)
        # if prediction is less than current value sell at open (ASAP)
            else:
                self.log('MARKET SELL CREATE. PREDICTION < CURRENT CLOSE')
                self.sell(size=self.size)

# %%
class BuyAndHold(bt.Strategy):
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)

            self.bar_executed = len(self)

      
    def start(self):
        self.val_start = self.broker.get_cash()  # keep the starting cash

    def nextstart(self):
        # Buy all the available cash
        size = int(self.broker.get_cash() / self.datas[0].open[1])
        self.buy(size=size)

    def stop(self):
        # calculate the actual returns
        self.roi = (self.broker.get_value() / self.val_start) - 1.0
        print(f'Stop price: {self.datas[0].close[0]}')
        print('ROI:        {:.2f}%'.format(100.0 * self.roi))

# %%
def prepare_data(data, fromdate, todate, filepath):
    """Prepare data for backtrader datafeed object
        Returns prepared data filepath and params for the GenericCSVData class, also returns columns used"""
    data['timestamp'] = pd.to_datetime(data['timestamp'])
    # start param setup for backtrader
    start = data['timestamp'].iloc[0]
    end = data['timestamp'].iloc[-1]
    from_to = [(start.year, start.month, start.day), (end.year, end.month, end.day)]
    # Backtrader string format
    data['timestamp'] = data['timestamp'].dt.strftime('%Y-%m-%d %H:%M:%S')
    # backtrader data feed class needs a file path, this could be a temp file that's constantly overwritten
    data.to_csv(filepath)
    
    starting_params = [
    ('fromdate', datetime.datetime(*from_to[0])),
    ('todate', datetime.datetime(*from_to[1])),
    ('nullvalue', 0.0),
    ('dtformat', ('%Y-%m-%d %H:%M:%S')),
    ('tmformat', ('%H:%M:%S')),
    ('datetime', 1)]
    # skip nonfeatures (timestamp)
    cols = data.columns[1:]
    # get column position for each indicator and add to starting params list
    i = 2 # starting index since others are reserved
    for indicator in cols:
        starting_params.append((indicator, i))
        i+=1
    final_params = tuple(starting_params)

    return filepath, final_params, cols

# %% [markdown]
# ## Import Data and Run Backtest

# %%
import os

# %%
def capstone_data_prep(pred_folder_name, pred_col_name, ticker_df_filepath, starting_cash=100000):
    """Main loop, preps data and executes backtrader on all stocks in the prediction folder"""
    ticker_backtesting_dict = {}
    for pred_file in os.listdir(f'../../data/ticker_predictions/{pred_folder_name}'):
        # collect data
        ticker_name = pred_file.split('_')[0]
        pred_df = pd.read_csv(f'../../data/ticker_predictions/{pred_folder_name}/{pred_file}')
        ticker_df = pd.read_csv(ticker_df_filepath + f'/{ticker_name}_full_data.csv')
        
        # make timestamp in column position 0, SPECIFIC TO FULL DATA IN FILE 
        ticker_df = ticker_df.rename({'reportperiod':'timestamp'}, axis=1)
        ticker_cols = list(ticker_df.columns)
        ticker_cols[5] = 'ts_cpy'
        ticker_cols[0] = 'timestamp'
        ticker_df.columns = ticker_cols
        ticker_df['timestamp'] = ticker_df['ts_cpy']
        # merge prediction data with full data, on key = timestamp
        ticker_df = ticker_df.merge(pred_df.loc[:, ['timestamp', pred_col_name]], on='timestamp')
        # new prediction column name = "prediction", important because backtester strategy looks for this column name
        ticker_df = ticker_df.rename({pred_col_name:'prediction'}, axis=1)
        # remove all non-prediction rows in prediction field
        ticker_df = ticker_df[ticker_df.prediction > 0]
        # skip nonfeatures, keep timestamp, SPECIFIC TO FULL DATA IN FILE 
        nonfeatures = ticker_df.columns[1:7]
        features = [col for col in ticker_df.columns if col not in nonfeatures]
        # get index of start and end dates for trading
        ticker_df = ticker_df[features]
        ticker_df.columns = [c.lower() for c in ticker_df.columns]
        idx1 = ticker_df.prediction[ticker_df.prediction > 0].index[0]
        idx2 = ticker_df.prediction[ticker_df.prediction > 0].index[-1]
        start_date = pred_df.timestamp[idx1]
        end_date  = pred_df.timestamp[idx2]
        
        # Prepare data for backtrader
        prep_data = prepare_data(ticker_df.copy(), start_date, end_date, 'temp/prep_data.csv')
        class DataFeed(bt.feeds.GenericCSVData):
            lines = tuple(prep_data[2])
            params = prep_data[1]
        
        print(f"--------Ticker Name-------: {ticker_name}")
        ##### BUY AND HOLD #######
        print('BUY AND HOLD')
        # initialize everything and run strategy
        cerebro = bt.Cerebro(cheat_on_open=True)
        cerebro.broker.setcash(starting_cash)
        #cerebro.addsizer(bt.sizers.FixedSize, stake=10)
        print(f'Starting Portfolio Value: {cerebro.broker.getvalue()}')
        data = DataFeed(dataname=prep_data[0])
        cerebro.adddata(data)
        cerebro.addstrategy(BuyAndHold)
        cerebro.addanalyzer(bt.analyzers.SharpeRatio, timeframe=bt.TimeFrame.Months, _name = 'sharpe')
        cerebro.addanalyzer(bt.analyzers.DrawDown, _name = 'dd')
        cerebro.addanalyzer(bt.analyzers.Returns, _name = 'returns')
        buy_hold = cerebro.run()
        buy_hold_ret = cerebro.broker.getvalue() / starting_cash - 1
        print(f'Final Portfolio Value: {cerebro.broker.getvalue()}\n')
        print('STRATEGY INFO:')
        print(buy_hold[0].analyzers.sharpe.get_analysis())
        print(buy_hold[0].analyzers.dd.get_analysis())
        # rtot is total log returns over the strategy time period
        print(buy_hold[0].analyzers.returns.get_analysis())

        #### MAIN STRATEGY #####
        cerebro = bt.Cerebro(cheat_on_open=True)
        cerebro.broker.setcash(starting_cash)
        print(f'Starting Portfolio Value: {cerebro.broker.getvalue()}')
        data = DataFeed(dataname=prep_data[0])
        cerebro.adddata(data)
        cerebro.addstrategy(BasicStrategy)
        cerebro.addanalyzer(bt.analyzers.SharpeRatio, timeframe=bt.TimeFrame.Months, _name = 'sharpe')
        cerebro.addanalyzer(bt.analyzers.DrawDown, _name = 'dd')
        cerebro.addanalyzer(bt.analyzers.Returns, _name = 'returns')
        back = cerebro.run()
        strat_ret = cerebro.broker.getvalue() / starting_cash - 1
        print(f'Final Portfolio Value: {cerebro.broker.getvalue()}\n')
        print('STRATEGY INFO:')
        print(back[0].analyzers.sharpe.get_analysis())
        print(back[0].analyzers.dd.get_analysis())
        # rtot is total log returns over the strategy time period
        print(back[0].analyzers.returns.get_analysis())
        print(f"For {ticker_name}, return was {buy_hold_ret*100}% for buy and hold vs {strat_ret*100}%  for strategy")
        print('\n'*5)

        ticker_backtesting_dict[ticker_name] = cerebro
        
    return ticker_backtesting_dict

# %%
# pred_folder_name, pred_col_name, ticker_df_filepath, starting_cash=100000

cerebro_dict = capstone_data_prep('arima_preds', 'prediction', '../../data/ticker_data')
cerebro_dict
# Out:
# --------Ticker Name-------: WAT
# BUY AND HOLD
# Starting Portfolio Value: 100000
# 2019-09-18, BUY EXECUTED, 228.60
# Stop price: 349.9200134277344
# ROI:        53.02%
# Final Portfolio Value: 153016.8432006836
#
# STRATEGY INFO:
# OrderedDict([('sharperatio', 0.23066872516298156)])
# AutoOrderedDict([('len', 43), ('drawdown', 17.598069851467034), ('moneydown', 32678.859466552793), ('max', AutoOrderedDict([('len', 227), ('drawdown', 33.451625540555426), ('moneydown', 37568.890533447324)]))])
# OrderedDict([('rtot', 0.425377815624272), ('ravg', 0.0007848299181259631), ('rnorm', 0.2186907653606273), ('rnorm100', 21.869076536062728)])
# Starting Portfolio Value: 100000
# ***The limit sells for this strategy are valid for 1 day***
# 2019-09-17, Current Portfolio Value : 100000.0
# 2019-09-17, MARKET BUY CREATE 437 shares at next open, current close price: 228.69000244140625
# 2019-09-18, BUY EXECUTED, 228.60
# 2019-09-18, Current Portfolio Value : 99886.3757324219
# 2019-09-18, LIMIT SELL CREATE 437 shares at 230.130747057432
# 2019-09-19, Current Portfolio Value : 100043.69599914552
# 2019-09-19, LIMIT SELL CREATE 437 shares at 230.4935709635808
# 2019-09-20, SELL EXECUTED, 230.49
# 2019-09-20, Current Portfolio Value : 100827.48784384849
# 2019-09-20, MARKET BUY CREATE 442 shares at next open, current close price: 228.6999969482422
# 2019-09-23, BUY EXECUTED, 227.86
# 2019-09-23, Current Portfolio Value : 100796.54460654379
# 2019-09-23, LIMIT SELL CREATE 442 shares at 229.5764306204745
# 2019-09-24, Current Portfolio Value : 97813.04460654379
# 2019-09-24, LIMIT SELL CREATE 442 shares at 222.7734939140246
# 2019-09-25, Current Portfolio Value : 97441.76622519613
# 2019-09-25, LIMIT SELL CREATE 442 shares at 221.9269099258291
# 2019-09-26, Current Portfolio Value : 96129.02568564533
# 2019-09-26, LIMIT SELL CREATE 442 shares at 218.93361654471468
# 2019-09-27, SELL EXECUTED, 218.93
# 2019-09-27, Current Portfolio Value : 96882.02608683698
# 2019-09-27, MARKET BUY CREATE 435 shares at next open, current close price: 222.52999877929688
# 2019-09-30, BUY EXECUTED, 222.69
# 2019-09-30, Current Portfolio Value : 97116.92316630474
# 2019-09-30, LIMIT SELL CREATE 435 shares at 224.98067139489237
# 2019-10-01, SELL EXECUTED, 224.98
# 2019-10-01, Current Portfolio Value : 97878.46708160345
# 2019-10-01, MARKET BUY CREATE 440 shares at next open, current close price: 224.1999969482422
# 2019-10-02, BUY EXECUTED, 222.09
# 2019-10-02, Current Portfolio Value : 97834.47110992376
# 2019-10-02, LIMIT SELL CREATE 440 shares at 223.73095656806737
# 2019-10-03, SELL EXECUTED, 223.73
# 2019-10-03, Current Portfolio Value : 98600.4895828812
# 2019-10-03, MARKET BUY CREATE 436 shares at next open, current close price: 224.55999755859372
# 2019-10-04, BUY EXECUTED, 225.82
# 2019-10-04, Current Portfolio Value : 99114.96638952183
# 2019-10-04, LIMIT SELL CREATE 436 shares at 228.7802418317216
# 2019-10-07, Current Portfolio Value : 97580.24452672884
# 2019-10-07, LIMIT SELL CREATE 436 shares at 225.23263201364972
# 2019-10-08, Current Portfolio Value : 90835.32399450231
# 2019-10-08, LIMIT SELL CREATE 436 shares at 209.64130769466527
# 2019-10-09, Current Portfolio Value : 90983.56905065462
# 2019-10-09, LIMIT SELL CREATE 436 shares at 209.98398582380165
# 2019-10-10, SELL EXECUTED, 209.98
# 2019-10-10, Current Portfolio Value : 91695.98420869934
# 2019-10-10, MARKET BUY CREATE 426 shares at next open, current close price: 211.3000030517578
# 2019-10-11, BUY EXECUTED, 215.21
# 2019-10-11, Current Portfolio Value : 91018.6392685138
# 2019-10-11, LIMIT SELL CREATE 426 shares at 215.2953045947196
# 2019-10-14, Current Portfolio Value : 91125.1392685138
# 2019-10-14, LIMIT SELL CREATE 426 shares at 215.547265213477
# 2019-10-15, SELL EXECUTED, 215.55
# 2019-10-15, Current Portfolio Value : 91839.65632953313
# 2019-10-15, MARKET BUY CREATE 428 shares at next open, current close price: 215.38999938964844
# 2019-10-16, BUY EXECUTED, 214.33
# 2019-10-16, Current Portfolio Value : 91522.93397845892
# 2019-10-16, LIMIT SELL CREATE 428 shares at 215.2650705507452
# 2019-10-17, SELL EXECUTED, 215.27
# 2019-10-17, Current Portfolio Value : 92239.86574156067
# 2019-10-17, MARKET BUY CREATE 428 shares at next open, current close price: 214.75999450683597
# 2019-10-18, BUY EXECUTED, 215.28
# 2019-10-18, Current Portfolio Value : 92441.02626402161
# 2019-10-18, LIMIT SELL CREATE 428 shares at 217.4420139876385
# 2019-10-21, Current Portfolio Value : 93121.54469663881
# 2019-10-21, LIMIT SELL CREATE 428 shares at 219.04447983210625
# 2019-10-22, SELL EXECUTED, 219.04
# 2019-10-22, Current Portfolio Value : 93851.06363216309
# 2019-10-22, MARKET BUY CREATE 426 shares at next open, current close price: 219.0800018310547
# 2019-10-23, BUY EXECUTED, 219.81
# 2019-10-23, Current Portfolio Value : 91576.2251922217
# 2019-10-23, LIMIT SELL CREATE 426 shares at 216.15197684987703
# 2019-10-24, SELL EXECUTED, 216.15
# 2019-10-24, Current Portfolio Value : 92292.74681024978
# 2019-10-24, MARKET BUY CREATE 429 shares at next open, current close price: 215.8500061035156
# 2019-10-25, BUY EXECUTED, 215.07
# 2019-10-25, Current Portfolio Value : 93596.90393000077
# 2019-10-25, LIMIT SELL CREATE 429 shares at 219.82052284384665
# 2019-10-28, Current Portfolio Value : 94454.90393000077
# 2019-10-28, LIMIT SELL CREATE 429 shares at 221.83620779390583
# 2019-10-29, Current Portfolio Value : 91958.12078791091
# 2019-10-29, LIMIT SELL CREATE 429 shares at 215.9705572075748
# 2019-10-30, Current Portfolio Value : 92262.71366815994
# 2019-10-30, LIMIT SELL CREATE 429 shares at 216.6861321313663
# 2019-10-31, Current Portfolio Value : 90812.69157343337
# 2019-10-31, LIMIT SELL CREATE 429 shares at 213.2796196446604
# 2019-11-01, SELL EXECUTED, 213.84
# 2019-11-01, Current Portfolio Value : 91765.07209711503
# 2019-11-01, MARKET BUY CREATE 422 shares at next open, current close price: 215.08999633789065
# 2019-11-04, BUY EXECUTED, 217.38
# 2019-11-04, Current Portfolio Value : 90756.4923546834
# 2019-11-04, LIMIT SELL CREATE 422 shares at 216.67605924286008
# 2019-11-05, Current Portfolio Value : 90161.47080927323
# 2019-11-05, LIMIT SELL CREATE 422 shares at 215.2549976622389
# 2019-11-06, Current Portfolio Value : 89946.25312738847
# 2019-11-06, LIMIT SELL CREATE 422 shares at 214.7410035362179
# 2019-11-07, SELL EXECUTED, 214.74
# 2019-11-07, Current Portfolio Value : 90651.4135288521
# 2019-11-07, MARKET BUY CREATE 428 shares at next open, current close price: 211.97999572753903
# 2019-11-08, BUY EXECUTED, 211.33
# 2019-11-08, Current Portfolio Value : 90116.4135288521
# 2019-11-08, LIMIT SELL CREATE 428 shares at 211.7275489996353
# 2019-11-11, Current Portfolio Value : 89898.13587992633
# 2019-11-11, LIMIT SELL CREATE 428 shares at 211.21355487361427
# 2019-11-12, SELL EXECUTED, 211.21
# 2019-11-12, Current Portfolio Value : 90601.57423106761
# 2019-11-12, MARKET BUY CREATE 426 shares at next open, current close price: 212.5800018310547
# 2019-11-13, BUY EXECUTED, 212.50
# 2019-11-13, Current Portfolio Value : 90980.71397105785
# 2019-11-13, LIMIT SELL CREATE 426 shares at 215.0635051314304
# 2019-11-14, Current Portfolio Value : 91019.05241099924
# 2019-11-14, LIMIT SELL CREATE 426 shares at 215.15420726335364
# 2019-11-15, SELL EXECUTED, 215.15
# 2019-11-15, Current Portfolio Value : 91732.26652525626
# 2019-11-15, MARKET BUY CREATE 424 shares at next open, current close price: 217.32000732421875
# 2019-11-18, BUY EXECUTED, 216.07
# 2019-11-18, Current Portfolio Value : 91846.74186705315
# 2019-11-18, LIMIT SELL CREATE 424 shares at 218.0366373570766
# 2019-11-19, SELL EXECUTED, 218.04
# 2019-11-19, Current Portfolio Value : 92566.11765918798
# 2019-11-19, MARKET BUY CREATE 423 shares at next open, current close price: 219.72000122070312
# 2019-11-20, BUY EXECUTED, 218.41
# 2019-11-20, Current Portfolio Value : 92270.01895008155
# 2019-11-20, LIMIT SELL CREATE 423 shares at 219.41739200521707
# 2019-11-21, Current Portfolio Value : 92274.24662647315
# 2019-11-21, LIMIT SELL CREATE 423 shares at 219.42746489372328
# 2019-11-22, SELL EXECUTED, 219.43
# 2019-11-22, Current Portfolio Value : 92996.50376016067
# 2019-11-22, MARKET BUY CREATE 421 shares at next open, current close price: 218.72000122070312
# 2019-11-25, BUY EXECUTED, 220.52
# 2019-11-25, Current Portfolio Value : 93299.62427407672
# 2019-11-25, LIMIT SELL CREATE 421 shares at 222.97507471179517
# 2019-11-26, Current Portfolio Value : 93644.84093362259
# 2019-11-26, LIMIT SELL CREATE 421 shares at 223.8014975445224
# 2019-11-27, SELL EXECUTED, 223.80
# 2019-11-27, Current Portfolio Value : 94378.01242769856
# 2019-11-27, MARKET BUY CREATE 422 shares at next open, current close price: 223.5500030517578
# 2019-11-29, BUY EXECUTED, 223.43
# 2019-11-29, Current Portfolio Value : 93804.09860933918
# 2019-11-29, LIMIT SELL CREATE 422 shares at 223.8115858114844
# 2019-12-02, Current Portfolio Value : 94242.97577608725
# 2019-12-02, LIMIT SELL CREATE 422 shares at 224.8597352189947
# 2019-12-03, Current Portfolio Value : 93504.47577608725
# 2019-12-03, LIMIT SELL CREATE 422 shares at 223.09601088769287
# 2019-12-04, SELL EXECUTED, 223.10
# 2019-12-04, Current Portfolio Value : 94237.07211312526
# 2019-12-04, MARKET BUY CREATE 424 shares at next open, current close price: 224.9499969482422
# 2019-12-05, BUY EXECUTED, 222.09
# 2019-12-05, Current Portfolio Value : 94919.71237191431
# 2019-12-05, LIMIT SELL CREATE 424 shares at 225.4543585884328
# 2019-12-06, SELL EXECUTED, 225.52
# 2019-12-06, Current Portfolio Value : 95691.39547738305
# 2019-12-06, MARKET BUY CREATE 421 shares at next open, current close price: 226.3000030517578
# 2019-12-09, BUY EXECUTED, 227.20
# 2019-12-09, Current Portfolio Value : 95451.42881783715
# 2019-12-09, LIMIT SELL CREATE 421 shares at 228.4073450370665
# 2019-12-10, SELL EXECUTED, 228.41
# 2019-12-10, Current Portfolio Value : 96199.68902277808
# 2019-12-10, MARKET BUY CREATE 422 shares at next open, current close price: 227.92999267578125
# 2019-12-11, BUY EXECUTED, 227.45
# 2019-12-11, Current Portfolio Value : 96841.1308257566
# 2019-12-11, LIMIT SELL CREATE 422 shares at 230.7656927378064
# 2019-12-12, SELL EXECUTED, 230.77
# 2019-12-12, Current Portfolio Value : 97598.91264597418
# 2019-12-12, MARKET BUY CREATE 417 shares at next open, current close price: 233.69000244140625
# 2019-12-13, BUY EXECUTED, 233.69
# 2019-12-13, Current Portfolio Value : 97774.05188242439
# 2019-12-13, LIMIT SELL CREATE 417 shares at 235.9460024443204
# 2019-12-16, Current Portfolio Value : 97736.52340952397
# 2019-12-16, LIMIT SELL CREATE 417 shares at 235.85530031239708
# 2019-12-17, Current Portfolio Value : 96602.28290049078
# 2019-12-17, LIMIT SELL CREATE 417 shares at 233.1139675500401
# 2019-12-18, Current Portfolio Value : 95643.18162790778
# 2019-12-18, LIMIT SELL CREATE 417 shares at 230.79592678178085
# 2019-12-19, SELL EXECUTED, 230.80
# 2019-12-19, Current Portfolio Value : 96392.08309591039
# 2019-12-19, MARKET BUY CREATE 412 shares at next open, current close price: 231.8699951171875
# 2019-12-20, BUY EXECUTED, 233.52
# 2019-12-20, Current Portfolio Value : 96293.20083272681
# 2019-12-20, LIMIT SELL CREATE 412 shares at 235.10949134463112
# 2019-12-23, Current Portfolio Value : 96173.72359884011
# 2019-12-23, LIMIT SELL CREATE 412 shares at 234.81722379339308
# 2019-12-24, Current Portfolio Value : 96214.91982686745
# 2019-12-24, LIMIT SELL CREATE 412 shares at 234.9179988138226
# 2019-12-26, Current Portfolio Value : 96284.95907247292
# 2019-12-26, LIMIT SELL CREATE 412 shares at 235.08933018916292
# 2019-12-27, Current Portfolio Value : 96490.95907247292
# 2019-12-27, LIMIT SELL CREATE 412 shares at 235.5932514266777
# 2019-12-30, Current Portfolio Value : 96256.12234151587
# 2019-12-30, LIMIT SELL CREATE 412 shares at 235.01878921270784
# 2019-12-31, Current Portfolio Value : 96445.63882100808
# 2019-12-31, LIMIT SELL CREATE 412 shares at 235.48238813928623
# 2020-01-02, Current Portfolio Value : 97026.56032979711
# 2020-01-02, LIMIT SELL CREATE 412 shares at 236.90344971990731
# 2020-01-03, Current Portfolio Value : 95357.95907247292
# 2020-01-03, LIMIT SELL CREATE 412 shares at 232.82168462034636
# 2020-01-06, Current Portfolio Value : 94480.40334737525
# 2020-01-06, LIMIT SELL CREATE 412 shares at 230.67499060588312
# 2020-01-07, SELL EXECUTED, 230.67
# 2020-01-07, Current Portfolio Value : 95219.93746528034
# 2020-01-07, MARKET BUY CREATE 430 shares at next open, current close price: 231.97999572753903
# 2020-01-08, BUY EXECUTED, 221.00
# 2020-01-08, Current Portfolio Value : 97520.44008979204
# 2020-01-08, LIMIT SELL CREATE 430 shares at 228.12515037433465
# 2020-01-09, SELL EXECUTED, 228.13
# 2020-01-09, Current Portfolio Value : 98283.75212624423
# 2020-01-09, MARKET BUY CREATE 426 shares at next open, current close price: 228.8000030517578
# 2020-01-10, BUY EXECUTED, 230.19
# 2020-01-10, Current Portfolio Value : 98577.6931662833
# 2020-01-10, LIMIT SELL CREATE 426 shares at 232.69067555594236
# 2020-01-13, Current Portfolio Value : 97700.13420632236
# 2020-01-13, LIMIT SELL CREATE 426 shares at 230.61452251793423
# 2020-01-14, SELL EXECUTED, 230.61
# 2020-01-14, Current Portfolio Value : 98464.59767884515
# 2020-01-14, MARKET BUY CREATE 423 shares at next open, current close price: 232.0800018310547
# 2020-01-15, BUY EXECUTED, 232.53
# 2020-01-15, Current Portfolio Value : 99238.6884533813
# 2020-01-15, LIMIT SELL CREATE 423 shares at 236.19796306307785
# 2020-01-16, SELL EXECUTED, 236.20
# 2020-01-16, Current Portfolio Value : 100016.1465708845
# 2020-01-16, MARKET BUY CREATE 419 shares at next open, current close price: 237.6100006103516
# 2020-01-17, BUY EXECUTED, 238.14
# 2020-01-17, Current Portfolio Value : 100627.88938399484
# 2020-01-17, LIMIT SELL CREATE 419 shares at 241.47906316847696
# 2020-01-21, Current Portfolio Value : 102333.2160594099
# 2020-01-21, LIMIT SELL CREATE 419 shares at 245.5809740450505
# 2020-01-22, SELL EXECUTED, 245.58
# 2020-01-22, Current Portfolio Value : 103133.91495149798
# 2020-01-22, MARKET BUY CREATE 424 shares at next open, current close price: 244.08999633789065
# 2020-01-23, BUY EXECUTED, 242.98
# 2020-01-23, Current Portfolio Value : 102688.71365755268
# 2020-01-23, LIMIT SELL CREATE 424 shares at 243.82732260225492
# 2020-01-24, Current Portfolio Value : 100823.1162454433
# 2020-01-24, LIMIT SELL CREATE 424 shares at 239.39282186350692
# 2020-01-27, Current Portfolio Value : 98635.27469270893
# 2020-01-27, LIMIT SELL CREATE 424 shares at 234.1923510015248
# 2020-01-28, SELL EXECUTED, 234.19
# 2020-01-28, Current Portfolio Value : 99407.95358766794
# 2020-01-28, MARKET BUY CREATE 419 shares at next open, current close price: 235.8600006103516
# 2020-01-29, BUY EXECUTED, 236.72
# 2020-01-29, Current Portfolio Value : 98272.4607745576
# 2020-01-29, LIMIT SELL CREATE 419 shares at 235.84521204543515
# 2020-01-30, Current Portfolio Value : 96093.6620532441
# 2020-01-30, LIMIT SELL CREATE 419 shares at 230.60443425097228
# 2020-01-31, Current Portfolio Value : 93990.28026308298
# 2020-01-31, LIMIT SELL CREATE 419 shares at 225.54506072035605
# 2020-02-03, Current Portfolio Value : 94937.22435487986
# 2020-02-03, LIMIT SELL CREATE 419 shares at 227.82279455613465
# 2020-02-04, Current Portfolio Value : 92016.79384340525
# 2020-02-04, LIMIT SELL CREATE 419 shares at 220.7981312749018
# 2020-02-05, SELL EXECUTED, 221.78
# 2020-02-05, Current Portfolio Value : 93148.09256471873
# 2020-02-05, MARKET BUY CREATE 419 shares at next open, current close price: 220.7400054931641
# 2020-02-06, BUY EXECUTED, 222.16
# 2020-02-06, Current Portfolio Value : 92280.7594958711
# 2020-02-06, LIMIT SELL CREATE 419 shares at 221.81604663843763
# 2020-02-07, Current Portfolio Value : 91136.89128603223
# 2020-02-07, LIMIT SELL CREATE 419 shares at 219.0646409875744
# 2020-02-10, Current Portfolio Value : 91878.52307619335
# 2020-02-10, LIMIT SELL CREATE 419 shares at 220.8485264743444
# 2020-02-11, SELL EXECUTED, 220.85
# 2020-02-11, Current Portfolio Value : 92598.58362304521
# 2020-02-11, MARKET BUY CREATE 413 shares at next open, current close price: 223.22000122070312
# 2020-02-12, BUY EXECUTED, 224.11
# 2020-02-12, Current Portfolio Value : 92705.96135436844
# 2020-02-12, LIMIT SELL CREATE 413 shares at 226.1296112012879
# 2020-02-13, Current Portfolio Value : 91140.69412719559
# 2020-02-13, LIMIT SELL CREATE 413 shares at 222.3098949874462
# 2020-02-14, Current Portfolio Value : 89273.9323626692
# 2020-02-14, LIMIT SELL CREATE 413 shares at 217.75444269434476
# 2020-02-18, Current Portfolio Value : 89455.65337097
# 2020-02-18, LIMIT SELL CREATE 413 shares at 218.19789584391071
# 2020-02-19, Current Portfolio Value : 89517.60085021806
# 2020-02-19, LIMIT SELL CREATE 413 shares at 218.34906606378289
# 2020-02-20, Current Portfolio Value : 89802.57185851884
# 2020-02-20, LIMIT SELL CREATE 413 shares at 219.04447983210625
# 2020-02-21, Current Portfolio Value : 89406.09538757156
# 2020-02-21, LIMIT SELL CREATE 413 shares at 218.076959668013
# 2020-02-24, Current Portfolio Value : 86800.06639587235
# 2020-02-24, LIMIT SELL CREATE 413 shares at 211.71747611112903
# 2020-02-25, Current Portfolio Value : 84032.96135436844
# 2020-02-25, LIMIT SELL CREATE 413 shares at 204.96491922566608
# 2020-02-26, SELL EXECUTED, 205.84
# 2020-02-26, Current Portfolio Value : 85053.07185851884
# 2020-02-26, MARKET BUY CREATE 427 shares at next open, current close price: 202.6000061035156
# 2020-02-27, BUY EXECUTED, 199.14
# 2020-02-27, Current Portfolio Value : 84916.43524658037
# 2020-02-27, LIMIT SELL CREATE 427 shares at 200.37924826704597
# 2020-02-28, Current Portfolio Value : 83238.32185851884
# 2020-02-28, LIMIT SELL CREATE 427 shares at 196.4184193433826
# 2020-03-02, Current Portfolio Value : 86573.19081603838
# 2020-03-02, LIMIT SELL CREATE 427 shares at 204.28966661281092
# 2020-03-03, SELL EXECUTED, 204.29
# 2020-03-03, Current Portfolio Value : 87251.97976280922
# 2020-03-03, MARKET BUY CREATE 426 shares at next open, current close price: 201.47000122070312
# 2020-03-04, BUY EXECUTED, 204.67
# 2020-03-04, Current Portfolio Value : 88858.00158287758
# 2020-03-04, LIMIT SELL CREATE 426 shares at 210.07468795572493
# 2020-03-05, Current Portfolio Value : 84802.47976280922
# 2020-03-05, LIMIT SELL CREATE 426 shares at 200.48002328747543
# 2020-03-06, Current Portfolio Value : 85262.56054283852
# 2020-03-06, LIMIT SELL CREATE 426 shares at 201.56849500592213
# 2020-03-09, Current Portfolio Value : 81253.89898277994
# 2020-03-09, LIMIT SELL CREATE 426 shares at 192.08469362506412
# 2020-03-10, SELL EXECUTED, 195.76
# 2020-03-10, Current Portfolio Value : 83456.31820275064
# 2020-03-10, MARKET BUY CREATE 435 shares at next open, current close price: 196.72000122070312
# 2020-03-11, BUY EXECUTED, 191.78
# 2020-03-11, Current Portfolio Value : 80115.52138878578
# 2020-03-11, LIMIT SELL CREATE 435 shares at 185.5438058043336
# 2020-03-12, Current Portfolio Value : 72698.77006127115
# 2020-03-12, LIMIT SELL CREATE 435 shares at 168.3600885293876
# 2020-03-13, SELL EXECUTED, 177.42
# 2020-03-13, Current Portfolio Value : 77209.71793724771
# 2020-03-13, MARKET BUY CREATE 470 shares at next open, current close price: 184.47999572753903
# 2020-03-16, BUY EXECUTED, 164.20
# 2020-03-16, Current Portfolio Value : 81778.11851097818
# 2020-03-16, LIMIT SELL CREATE 470 shares at 175.2839614117352
# 2020-03-17, SELL EXECUTED, 177.19
# 2020-03-17, Current Portfolio Value : 83315.02051903482
# 2020-03-17, MARKET BUY CREATE 473 shares at next open, current close price: 183.2700042724609
# 2020-03-18, BUY EXECUTED, 175.97
# 2020-03-18, Current Portfolio Value : 83712.33878685709
# 2020-03-18, LIMIT SELL CREATE 473 shares at 178.19662554943255
# 2020-03-19, SELL EXECUTED, 178.20
# 2020-03-19, Current Portfolio Value : 84368.21382652385
# 2020-03-19, MARKET BUY CREATE 472 shares at next open, current close price: 177.4199981689453
# 2020-03-20, BUY EXECUTED, 178.44
# 2020-03-20, Current Portfolio Value : 82017.65584312541
# 2020-03-20, LIMIT SELL CREATE 472 shares at 174.82036248515678
# 2020-03-23, Current Portfolio Value : 76778.45296226603
# 2020-03-23, LIMIT SELL CREATE 472 shares at 163.63330486094583
# 2020-03-24, SELL EXECUTED, 169.16
# 2020-03-24, Current Portfolio Value : 79988.05440269572
# 2020-03-24, MARKET BUY CREATE 449 shares at next open, current close price: 180.67999267578125
# 2020-03-25, BUY EXECUTED, 177.82
# 2020-03-25, Current Portfolio Value : 79530.07248436076
# 2020-03-25, LIMIT SELL CREATE 449 shares at 178.1865526609263
# 2020-03-26, SELL EXECUTED, 178.19
# 2020-03-26, Current Portfolio Value : 80152.63325887741
# 2020-03-26, MARKET BUY CREATE 433 shares at next open, current close price: 191.4199981689453
# 2020-03-27, BUY EXECUTED, 185.06
# 2020-03-27, Current Portfolio Value : 80282.53458028857
# 2020-03-27, LIMIT SELL CREATE 433 shares at 186.8136817866269
# 2020-03-30, Current Portfolio Value : 81486.2740517241
# 2020-03-30, LIMIT SELL CREATE 433 shares at 189.6154826369327
# 2020-03-31, SELL EXECUTED, 189.62
# 2020-03-31, Current Portfolio Value : 82125.15829779819
# 2020-03-31, MARKET BUY CREATE 465 shares at next open, current close price: 182.0500030517578
# 2020-04-01, BUY EXECUTED, 176.58
# 2020-04-01, Current Portfolio Value : 84789.60631110384
# 2020-04-01, LIMIT SELL CREATE 465 shares at 183.73975916209537
# 2020-04-02, SELL EXECUTED, 183.74
# 2020-04-02, Current Portfolio Value : 85454.44545673211
# 2020-04-02, MARKET BUY CREATE 465 shares at next open, current close price: 186.02999877929688
# 2020-04-03, BUY EXECUTED, 183.71
# 2020-04-03, Current Portfolio Value : 83701.39347003777
# 2020-04-03, LIMIT SELL CREATE 465 shares at 181.35117741738105
# 2020-04-06, Current Portfolio Value : 87863.14205097039
# 2020-04-06, LIMIT SELL CREATE 465 shares at 190.3713644932049
# 2020-04-07, SELL EXECUTED, 193.95
# 2020-04-07, Current Portfolio Value : 90216.04091571648
# 2020-04-07, MARKET BUY CREATE 473 shares at next open, current close price: 190.0800018310547
# 2020-04-08, BUY EXECUTED, 190.41
# 2020-04-08, Current Portfolio Value : 92897.95004962763
# 2020-04-08, LIMIT SELL CREATE 473 shares at 197.61775434922075
# 2020-04-09, SELL EXECUTED, 197.62
# 2020-04-09, Current Portfolio Value : 93625.30699072017
# 2020-04-09, MARKET BUY CREATE 483 shares at next open, current close price: 195.92999267578125
# 2020-04-13, BUY EXECUTED, 193.83
# 2020-04-13, Current Portfolio Value : 90640.36315832273
# 2020-04-13, LIMIT SELL CREATE 483 shares at 189.12163428792417
# 2020-04-14, SELL EXECUTED, 189.67
# 2020-04-14, Current Portfolio Value : 91616.02522192134
# 2020-04-14, MARKET BUY CREATE 475 shares at next open, current close price: 193.6499938964844
# 2020-04-15, BUY EXECUTED, 192.64
# 2020-04-15, Current Portfolio Value : 90081.77725134027
# 2020-04-15, LIMIT SELL CREATE 475 shares at 190.8954468861879
# 2020-04-16, SELL EXECUTED, 191.62
# 2020-04-16, Current Portfolio Value : 91131.5231925024
# 2020-04-16, MARKET BUY CREATE 463 shares at next open, current close price: 192.9600067138672
# 2020-04-17, BUY EXECUTED, 196.72
# 2020-04-17, Current Portfolio Value : 91497.2900839819
# 2020-04-17, LIMIT SELL CREATE 463 shares at 199.0589617068544
# 2020-04-20, Current Portfolio Value : 90024.95347509517
# 2020-04-20, LIMIT SELL CREATE 463 shares at 195.8540300179189
# 2020-04-21, Current Portfolio Value : 85885.73234472408
# 2020-04-21, LIMIT SELL CREATE 463 shares at 186.8439158306013
# 2020-04-22, SELL EXECUTED, 187.46
# 2020-04-22, Current Portfolio Value : 86844.14573583736
# 2020-04-22, MARKET BUY CREATE 455 shares at next open, current close price: 190.33999633789065
# 2020-04-23, BUY EXECUTED, 190.75
# 2020-04-23, Current Portfolio Value : 86853.24767980707
# 2020-04-23, LIMIT SELL CREATE 455 shares at 192.2661132673664
# 2020-04-24, SELL EXECUTED, 192.27
# 2020-04-24, Current Portfolio Value : 87533.97727248906
# 2020-04-24, MARKET BUY CREATE 454 shares at next open, current close price: 191.32000732421875
# 2020-04-27, BUY EXECUTED, 192.46
# 2020-04-27, Current Portfolio Value : 88691.67173049689
# 2020-04-27, LIMIT SELL CREATE 454 shares at 196.53935551928035
# 2020-04-28, Current Portfolio Value : 83743.07450149299
# 2020-04-28, LIMIT SELL CREATE 454 shares at 185.55387869283987
# 2020-04-29, SELL EXECUTED, 187.15
# 2020-04-29, Current Portfolio Value : 85123.23145339728
# 2020-04-29, MARKET BUY CREATE 445 shares at next open, current close price: 192.6499938964844
# 2020-04-30, BUY EXECUTED, 191.07
# 2020-04-30, Current Portfolio Value : 83312.07819411994
# 2020-04-30, LIMIT SELL CREATE 445 shares at 188.4665428305372
# 2020-05-01, Current Portfolio Value : 79342.67900893927
# 2020-05-01, LIMIT SELL CREATE 445 shares at 179.47658979868777
# 2020-05-04, Current Portfolio Value : 80388.4249348426
# 2020-05-04, LIMIT SELL CREATE 445 shares at 181.8450103879339
# 2020-05-05, SELL EXECUTED, 182.53
# 2020-05-05, Current Portfolio Value : 81322.92765090705
# 2020-05-05, MARKET BUY CREATE 444 shares at next open, current close price: 181.88999938964844
# 2020-05-06, BUY EXECUTED, 183.04
# 2020-05-06, Current Portfolio Value : 82206.49008987189
# 2020-05-06, LIMIT SELL CREATE 444 shares at 186.4810919244524
# 2020-05-07, SELL EXECUTED, 187.55
# 2020-05-07, Current Portfolio Value : 83325.37198684455
# 2020-05-07, MARKET BUY CREATE 442 shares at next open, current close price: 185.97999572753903
# 2020-05-08, BUY EXECUTED, 188.42
# 2020-05-08, Current Portfolio Value : 82688.89090774297
# 2020-05-08, LIMIT SELL CREATE 442 shares at 188.44638167506895
# 2020-05-11, Current Portfolio Value : 83718.75171706914
# 2020-05-11, LIMIT SELL CREATE 442 shares at 190.79465648730263
# 2020-05-12, Current Portfolio Value : 80699.89090774297
# 2020-05-12, LIMIT SELL CREATE 442 shares at 183.9110905374357
# 2020-05-13, Current Portfolio Value : 79073.33414504767
# 2020-05-13, LIMIT SELL CREATE 442 shares at 180.20223761098552
# 2020-05-14, SELL EXECUTED, 180.20
# 2020-05-14, Current Portfolio Value : 79693.12182022633
# 2020-05-14, MARKET BUY CREATE 442 shares at next open, current close price: 180.27999877929688
# 2020-05-15, BUY EXECUTED, 180.25
# 2020-05-15, Current Portfolio Value : 78901.94478775562
# 2020-05-15, LIMIT SELL CREATE 442 shares at 179.85957486030483
# 2020-05-18, Current Portfolio Value : 83224.70424820486
# 2020-05-18, LIMIT SELL CREATE 442 shares at 189.716273035818
# 2020-05-19, Current Portfolio Value : 81346.20424820486
# 2020-05-19, LIMIT SELL CREATE 442 shares at 185.43294251694212
# 2020-05-20, SELL EXECUTED, 185.77
# 2020-05-20, Current Portfolio Value : 82132.96370865405
# 2020-05-20, MARKET BUY CREATE 443 shares at next open, current close price: 185.25999450683597
# 2020-05-21, BUY EXECUTED, 185.18
# 2020-05-21, Current Portfolio Value : 82168.40451981129
# 2020-05-21, LIMIT SELL CREATE 443 shares at 186.71289138774165
# 2020-05-22, SELL EXECUTED, 186.71
# 2020-05-22, Current Portfolio Value : 82812.0378380525
# 2020-05-22, MARKET BUY CREATE 433 shares at next open, current close price: 186.67999267578125
# 2020-05-26, BUY EXECUTED, 190.99
# 2020-05-26, Current Portfolio Value : 83717.00625235913
# 2020-05-26, LIMIT SELL CREATE 433 shares at 194.5942269241319
# 2020-05-27, SELL EXECUTED, 195.77
# 2020-05-27, Current Portfolio Value : 84881.77730948802
# 2020-05-27, MARKET BUY CREATE 423 shares at next open, current close price: 198.88999938964844
# 2020-05-28, BUY EXECUTED, 200.42
# 2020-05-28, Current Portfolio Value : 83841.20092398998
# 2020-05-28, LIMIT SELL CREATE 423 shares at 199.51250312338223
# 2020-05-29, SELL EXECUTED, 199.51
# 2020-05-29, Current Portfolio Value : 84497.90690521484
# 2020-05-29, MARKET BUY CREATE 423 shares at next open, current close price: 199.8500061035156
# 2020-06-01, BUY EXECUTED, 199.43
# 2020-06-01, Current Portfolio Value : 84599.42922882324
# 2020-06-01, LIMIT SELL CREATE 423 shares at 201.2359051437477
# 2020-06-02, SELL EXECUTED, 201.24
# 2020-06-02, Current Portfolio Value : 85261.80787916464
# 2020-06-02, MARKET BUY CREATE 418 shares at next open, current close price: 202.83999633789065
# 2020-06-03, BUY EXECUTED, 203.75
# 2020-06-03, Current Portfolio Value : 84292.0448176412
# 2020-06-03, LIMIT SELL CREATE 418 shares at 203.00970236355573
# 2020-06-04, SELL EXECUTED, 203.01
# 2020-06-04, Current Portfolio Value : 84952.36346713094
# 2020-06-04, MARKET BUY CREATE 412 shares at next open, current close price: 202.38999938964844
# 2020-06-05, BUY EXECUTED, 206.00
# 2020-06-05, Current Portfolio Value : 86159.52044955282
# 2020-06-05, LIMIT SELL CREATE 412 shares at 210.5685209262778
# 2020-06-08, Current Portfolio Value : 85867.00397006063
# 2020-06-08, LIMIT SELL CREATE 412 shares at 209.852961380942
# 2020-06-09, Current Portfolio Value : 81400.92547884969
# 2020-06-09, LIMIT SELL CREATE 412 shares at 198.9279526424504
# 2020-06-10, Current Portfolio Value : 80239.08246127155
# 2020-06-10, LIMIT SELL CREATE 412 shares at 196.0858294812081
# 2020-06-11, Current Portfolio Value : 74878.96472445516
# 2020-06-11, LIMIT SELL CREATE 412 shares at 182.97380441731696
# 2020-06-12, SELL EXECUTED, 186.90
# 2020-06-12, Current Portfolio Value : 77083.16095248252
# 2020-06-12, MARKET BUY CREATE 423 shares at next open, current close price: 185.55999755859372
# 2020-06-15, BUY EXECUTED, 182.07
# 2020-06-15, Current Portfolio Value : 79642.3057889083
# 2020-06-15, LIMIT SELL CREATE 423 shares at 189.5953214814645
# 2020-06-16, SELL EXECUTED, 193.26
# 2020-06-16, Current Portfolio Value : 81816.5255307296
# 2020-06-16, MARKET BUY CREATE 431 shares at next open, current close price: 189.41000366210935
# 2020-06-17, BUY EXECUTED, 189.41
# 2020-06-17, Current Portfolio Value : 81424.31395236048
# 2020-06-17, LIMIT SELL CREATE 431 shares at 189.9783065430816
# 2020-06-18, SELL EXECUTED, 189.98
# 2020-06-18, Current Portfolio Value : 82061.46407242864
# 2020-06-18, MARKET BUY CREATE 422 shares at next open, current close price: 193.6000061035156
# 2020-06-19, BUY EXECUTED, 194.19
# 2020-06-19, Current Portfolio Value : 80449.42098160833
# 2020-06-19, LIMIT SELL CREATE 422 shares at 191.8629670502812
# 2020-06-22, Current Portfolio Value : 78415.384329997
# 2020-06-22, LIMIT SELL CREATE 422 shares at 187.0051743174354
# 2020-06-23, SELL EXECUTED, 187.23
# 2020-06-23, Current Portfolio Value : 79124.34123917668
# 2020-06-23, MARKET BUY CREATE 427 shares at next open, current close price: 185.57000732421875
# 2020-06-24, BUY EXECUTED, 184.89
# 2020-06-24, Current Portfolio Value : 75909.03176041691
# 2020-06-24, LIMIT SELL CREATE 427 shares at 178.75094198639
# 2020-06-25, Current Portfolio Value : 75396.6330635175
# 2020-06-25, LIMIT SELL CREATE 427 shares at 177.5415340920456
# 2020-06-26, Current Portfolio Value : 74798.82915421574
# 2020-06-26, LIMIT SELL CREATE 427 shares at 176.1305453999307
# 2020-06-29, Current Portfolio Value : 75593.04941483586
# 2020-06-29, LIMIT SELL CREATE 427 shares at 178.005133018624
# 2020-06-30, SELL EXECUTED, 178.01
# 2020-06-30, Current Portfolio Value : 76184.50329874925
# 2020-06-30, MARKET BUY CREATE 422 shares at next open, current close price: 180.3999938964844
# 2020-07-01, BUY EXECUTED, 180.47
# 2020-07-01, Current Portfolio Value : 76049.46020792895
# 2020-07-01, LIMIT SELL CREATE 422 shares at 181.56281572520209
# 2020-07-02, SELL EXECUTED, 182.50
# 2020-07-02, Current Portfolio Value : 77041.16278361253
# 2020-07-02, MARKET BUY CREATE 421 shares at next open, current close price: 180.82000732421875
# 2020-07-06, BUY EXECUTED, 182.89
# 2020-07-06, Current Portfolio Value : 77660.03329752856
# 2020-07-06, LIMIT SELL CREATE 421 shares at 185.80583931159728
# 2020-07-07, SELL EXECUTED, 185.81
# 2020-07-07, Current Portfolio Value : 78268.73139075299
# 2020-07-07, MARKET BUY CREATE 420 shares at next open, current close price: 185.33999633789065
# 2020-07-08, BUY EXECUTED, 186.03
# 2020-07-08, Current Portfolio Value : 77857.13318518658
# 2020-07-08, LIMIT SELL CREATE 420 shares at 186.5012530799206
# 2020-07-09, SELL EXECUTED, 186.50
# 2020-07-09, Current Portfolio Value : 78466.65819701494
# 2020-07-09, MARKET BUY CREATE 415 shares at next open, current close price: 188.6300048828125
# 2020-07-10, BUY EXECUTED, 188.64
# 2020-07-10, Current Portfolio Value : 78512.30845031084
# 2020-07-10, LIMIT SELL CREATE 415 shares at 190.230267161839
# 2020-07-13, Current Portfolio Value : 80388.11022338211
# 2020-07-13, LIMIT SELL CREATE 415 shares at 194.7857194549404
# 2020-07-14, SELL EXECUTED, 194.79
# 2020-07-14, Current Portfolio Value : 81017.13202411111
# 2020-07-14, MARKET BUY CREATE 383 shares at next open, current close price: 198.07000732421875
# 2020-07-15, BUY EXECUTED, 211.51
# 2020-07-15, Current Portfolio Value : 84575.20529681617
# 2020-07-15, LIMIT SELL CREATE 383 shares at 222.5316215622292
# 2020-07-16, SELL EXECUTED, 222.53
# 2020-07-16, Current Portfolio Value : 85238.41518632672
# 2020-07-16, MARKET BUY CREATE 378 shares at next open, current close price: 224.0399932861328
# 2020-07-17, BUY EXECUTED, 225.13
# 2020-07-17, Current Portfolio Value : 85903.6931099107
# 2020-07-17, LIMIT SELL CREATE 378 shares at 228.66937854433013
# 2020-07-20, Current Portfolio Value : 85967.95241777202
# 2020-07-20, LIMIT SELL CREATE 378 shares at 228.84070991967045
# 2020-07-21, Current Portfolio Value : 84365.23610917828
# 2020-07-21, LIMIT SELL CREATE 378 shares at 224.5674676677566
# 2020-07-22, SELL EXECUTED, 224.57
# 2020-07-22, Current Portfolio Value : 85025.7761190356
# 2020-07-22, MARKET BUY CREATE 378 shares at next open, current close price: 223.83999633789065
# 2020-07-23, BUY EXECUTED, 224.41
# 2020-07-23, Current Portfolio Value : 85770.43658046139
# 2020-07-23, LIMIT SELL CREATE 378 shares at 228.1553844183091
# 2020-07-24, Current Portfolio Value : 84511.69588832272
# 2020-07-24, LIMIT SELL CREATE 378 shares at 224.7992671310458
# 2020-07-27, Current Portfolio Value : 86174.89358119381
# 2020-07-27, LIMIT SELL CREATE 378 shares at 229.2337678697938
# 2020-07-28, SELL EXECUTED, 229.23
# 2020-07-28, Current Portfolio Value : 86849.15898954032
# 2020-07-28, MARKET BUY CREATE 387 shares at next open, current close price: 223.4900054931641
# 2020-07-29, BUY EXECUTED, 224.19
# 2020-07-29, Current Portfolio Value : 83880.86969815847
# 2020-07-29, LIMIT SELL CREATE 387 shares at 218.2180569993789
# 2020-07-30, Current Portfolio Value : 82425.74591886162
# 2020-07-30, LIMIT SELL CREATE 387 shares at 214.42855945105592
# 2020-07-31, SELL EXECUTED, 214.43
# 2020-07-31, Current Portfolio Value : 83071.48055227473
# 2020-07-31, MARKET BUY CREATE 387 shares at next open, current close price: 213.1499938964844
# 2020-08-03, BUY EXECUTED, 214.18
# 2020-08-03, Current Portfolio Value : 82634.17456777766
# 2020-08-03, LIMIT SELL CREATE 387 shares at 214.7208423807497
# 2020-08-04, Current Portfolio Value : 81492.52574880792
# 2020-08-04, LIMIT SELL CREATE 387 shares at 211.74771015510348
# 2020-08-05, SELL EXECUTED, 211.75
# 2020-08-05, Current Portfolio Value : 82130.18721677244
# 2020-08-05, MARKET BUY CREATE 388 shares at next open, current close price: 211.17999267578125
# 2020-08-06, BUY EXECUTED, 211.17
# 2020-08-06, Current Portfolio Value : 81924.54769040525
# 2020-08-06, LIMIT SELL CREATE 388 shares at 212.29193832509893
# 2020-08-07, SELL EXECUTED, 212.29
# 2020-08-07, Current Portfolio Value : 82565.49999736004
# 2020-08-07, MARKET BUY CREATE 388 shares at next open, current close price: 212.33999633789065
# 2020-08-10, BUY EXECUTED, 212.65
# 2020-08-10, Current Portfolio Value : 82588.78497050455
# 2020-08-10, LIMIT SELL CREATE 388 shares at 214.378179630069
# 2020-08-11, SELL EXECUTED, 214.38
# 2020-08-11, Current Portfolio Value : 83236.03606199086
# 2020-08-11, MARKET BUY CREATE 385 shares at next open, current close price: 213.63999938964844
# 2020-08-12, BUY EXECUTED, 215.73
# 2020-08-12, Current Portfolio Value : 83035.8402917272
# 2020-08-12, LIMIT SELL CREATE 385 shares at 216.89778581764304
# 2020-08-13, SELL EXECUTED, 216.90
# 2020-08-13, Current Portfolio Value : 83685.6352466809
# 2020-08-13, MARKET BUY CREATE 386 shares at next open, current close price: 217.0
# 2020-08-14, BUY EXECUTED, 216.35
# 2020-08-14, Current Portfolio Value : 83318.93053476687
# 2020-08-14, LIMIT SELL CREATE 386 shares at 217.08926296999587
# 2020-08-17, Current Portfolio Value : 83427.01006357545
# 2020-08-17, LIMIT SELL CREATE 386 shares at 217.37145763272767
# 2020-08-18, Current Portfolio Value : 83187.69194834106
# 2020-08-18, LIMIT SELL CREATE 386 shares at 216.74660021931516
# 2020-08-19, SELL EXECUTED, 216.75
# 2020-08-19, Current Portfolio Value : 83838.72057537953
# 2020-08-19, MARKET BUY CREATE 389 shares at next open, current close price: 216.9499969482422
# 2020-08-20, BUY EXECUTED, 215.29
# 2020-08-20, Current Portfolio Value : 83620.88152508654
# 2020-08-20, LIMIT SELL CREATE 389 shares at 216.41401035714065
# 2020-08-21, SELL EXECUTED, 216.41
# 2020-08-21, Current Portfolio Value : 84275.96321600158
# 2020-08-21, MARKET BUY CREATE 387 shares at next open, current close price: 216.2400054931641
# 2020-08-24, BUY EXECUTED, 217.73
# 2020-08-24, Current Portfolio Value : 83227.19652288634
# 2020-08-24, LIMIT SELL CREATE 387 shares at 216.70629328683447
# 2020-08-25, SELL EXECUTED, 216.71
# 2020-08-25, Current Portfolio Value : 83879.79037144891
# 2020-08-25, MARKET BUY CREATE 388 shares at next open, current close price: 216.13999938964844
# 2020-08-26, BUY EXECUTED, 215.95
# 2020-08-26, Current Portfolio Value : 83934.11013463252
# 2020-08-26, LIMIT SELL CREATE 388 shares at 217.78467673831923
# 2020-08-27, Current Portfolio Value : 83806.0694241833
# 2020-08-27, LIMIT SELL CREATE 388 shares at 217.4520868761448
# 2020-08-28, SELL EXECUTED, 217.45
# 2020-08-28, Current Portfolio Value : 84462.60126347512
# 2020-08-28, MARKET BUY CREATE 387 shares at next open, current close price: 217.42999267578125
# 2020-08-31, BUY EXECUTED, 217.82
# 2020-08-31, Current Portfolio Value : 83858.87630314799
# 2020-08-31, LIMIT SELL CREATE 387 shares at 217.9560081136596
# 2020-09-01, Current Portfolio Value : 82218.00008244484
# 2020-09-01, LIMIT SELL CREATE 387 shares at 213.6827658617456
# 2020-09-02, SELL EXECUTED, 213.68
# 2020-09-02, Current Portfolio Value : 82861.48881749802
# 2020-09-02, MARKET BUY CREATE 380 shares at next open, current close price: 217.07000732421875
# 2020-09-03, BUY EXECUTED, 218.00
# 2020-09-03, Current Portfolio Value : 79437.69090490037
# 2020-09-03, LIMIT SELL CREATE 380 shares at 210.6290043926824
# 2020-09-04, Current Portfolio Value : 78328.09160070114
# 2020-09-04, LIMIT SELL CREATE 380 shares at 207.6861062110106
# 2020-09-08, Current Portfolio Value : 77682.08696202927
# 2020-09-08, LIMIT SELL CREATE 380 shares at 205.97276170069568
# 2020-09-09, SELL EXECUTED, 205.97
# 2020-09-09, Current Portfolio Value : 78291.13826376238
# 2020-09-09, MARKET BUY CREATE 377 shares at next open, current close price: 206.2400054931641
# 2020-09-10, BUY EXECUTED, 207.65
# 2020-09-10, Current Portfolio Value : 76926.40010458267
# 2020-09-10, LIMIT SELL CREATE 377 shares at 205.630098950015
# 2020-09-11, SELL EXECUTED, 205.63
# 2020-09-11, Current Portfolio Value : 77529.6378689434
# 2020-09-11, MARKET BUY CREATE 376 shares at next open, current close price: 203.92999267578125
# 2020-09-14, BUY EXECUTED, 206.01
# 2020-09-14, Current Portfolio Value : 77255.1594753887
# 2020-09-14, LIMIT SELL CREATE 376 shares at 206.889902043802
# 2020-09-15, SELL EXECUTED, 206.89
# 2020-09-15, Current Portfolio Value : 77860.48310284264
# 2020-09-15, MARKET BUY CREATE 376 shares at next open, current close price: 205.6100006103516
# 2020-09-16, BUY EXECUTED, 206.96
# 2020-09-16, Current Portfolio Value : 77721.35920147547
# 2020-09-16, LIMIT SELL CREATE 376 shares at 208.21017322553791
# 2020-09-17, Current Portfolio Value : 76672.32172588952
# 2020-09-17, LIMIT SELL CREATE 376 shares at 205.3982994867258
# 2020-09-18, Current Portfolio Value : 73540.24103741295
# 2020-09-18, LIMIT SELL CREATE 376 shares at 197.00296982431445
# 2020-09-21, Current Portfolio Value : 73122.88080792078
# 2020-09-21, LIMIT SELL CREATE 376 shares at 195.8842640618934
# 2020-09-22, Current Portfolio Value : 73073.99897198325
# 2020-09-22, LIMIT SELL CREATE 376 shares at 195.75323961903365
# 2020-09-23, Current Portfolio Value : 71709.12287335044
# 2020-09-23, LIMIT SELL CREATE 376 shares at 192.09478189202605
# 2020-09-24, Current Portfolio Value : 71348.16034893639
# 2020-09-24, LIMIT SELL CREATE 376 shares at 191.12724634947716
# 2020-09-25, SELL EXECUTED, 191.13
# 2020-09-25, Current Portfolio Value : 71907.36520583199
# 2020-09-25, MARKET BUY CREATE 371 shares at next open, current close price: 191.05999755859372
# 2020-09-28, BUY EXECUTED, 193.41
# 2020-09-28, Current Portfolio Value : 71862.8413563447
# 2020-09-28, LIMIT SELL CREATE 371 shares at 194.8058652319529
# 2020-09-29, SELL EXECUTED, 194.81
# 2020-09-29, Current Portfolio Value : 72425.22984824395
# 2020-09-29, MARKET BUY CREATE 372 shares at next open, current close price: 193.38999938964844
# 2020-09-30, BUY EXECUTED, 194.19
# 2020-09-30, Current Portfolio Value : 72979.50621543145
# 2020-09-30, LIMIT SELL CREATE 372 shares at 197.21460813213545
# 2020-10-01, SELL EXECUTED, 197.25
# 2020-10-01, Current Portfolio Value : 73563.54894004083
# 2020-10-01, MARKET BUY CREATE 380 shares at next open, current close price: 195.67999267578125
# 2020-10-02, BUY EXECUTED, 193.49
# 2020-10-02, Current Portfolio Value : 74475.54662070487
# 2020-10-02, LIMIT SELL CREATE 380 shares at 197.4262618184122
# 2020-10-05, Current Portfolio Value : 75524.34453330254
# 2020-10-05, LIMIT SELL CREATE 380 shares at 200.20790151324988
# 2020-10-06, Current Portfolio Value : 74775.74406943534
# 2020-10-06, LIMIT SELL CREATE 380 shares at 198.2224506071651
# 2020-10-07, SELL EXECUTED, 198.22
# 2020-10-07, Current Portfolio Value : 75361.87808336121
# 2020-10-07, MARKET BUY CREATE 373 shares at next open, current close price: 200.08999633789065
# 2020-10-08, BUY EXECUTED, 201.65
# 2020-10-08, Current Portfolio Value : 75190.30127061706
# 2020-10-08, LIMIT SELL CREATE 373 shares at 202.76783001176028
# 2020-10-09, SELL EXECUTED, 202.77
# 2020-10-09, Current Portfolio Value : 75778.83095435912
# 2020-10-09, MARKET BUY CREATE 371 shares at next open, current close price: 202.8000030517578
# 2020-10-12, BUY EXECUTED, 204.01
# 2020-10-12, Current Portfolio Value : 75081.3548038464
# 2020-10-12, LIMIT SELL CREATE 371 shares at 203.71520439884105
# 2020-10-13, SELL EXECUTED, 205.35
# 2020-10-13, Current Portfolio Value : 76275.97525672727
# 2020-10-13, MARKET BUY CREATE 354 shares at next open, current close price: 216.4499969482422
# 2020-10-14, BUY EXECUTED, 215.44
# 2020-10-14, Current Portfolio Value : 75125.47525672727
# 2020-10-14, LIMIT SELL CREATE 354 shares at 213.854097237086
# 2020-10-15, SELL EXECUTED, 213.85
# 2020-10-15, Current Portfolio Value : 75714.56481439789
# 2020-10-15, MARKET BUY CREATE 352 shares at next open, current close price: 213.6999969482422
# 2020-10-16, BUY EXECUTED, 215.04
# 2020-10-16, Current Portfolio Value : 74327.68932611663
# 2020-10-16, LIMIT SELL CREATE 352 shares at 212.75555263013308
# 2020-10-19, Current Portfolio Value : 73894.72545892914
# 2020-10-19, LIMIT SELL CREATE 352 shares at 211.51589531335856
# 2020-10-20, SELL EXECUTED, 211.52
# 2020-10-20, Current Portfolio Value : 74474.08232798135
# 2020-10-20, MARKET BUY CREATE 347 shares at next open, current close price: 213.0800018310547
# 2020-10-21, BUY EXECUTED, 214.46
# 2020-10-21, Current Portfolio Value : 74626.75788034953
# 2020-10-21, LIMIT SELL CREATE 347 shares at 216.58534173248103
# 2020-10-22, SELL EXECUTED, 216.59
# 2020-10-22, Current Portfolio Value : 75211.57357944034
# 2020-10-22, MARKET BUY CREATE 338 shares at next open, current close price: 221.97999572753903
# 2020-10-23, BUY EXECUTED, 222.41
# 2020-10-23, Current Portfolio Value : 75056.09131015325
# 2020-10-23, LIMIT SELL CREATE 338 shares at 223.6906342571309
# 2020-10-26, Current Portfolio Value : 74501.77151645206
# 2020-10-26, LIMIT SELL CREATE 338 shares at 222.0377732132206
# 2020-10-27, SELL EXECUTED, 225.00
# 2020-10-27, Current Portfolio Value : 76086.99234164739
# 2020-10-27, MARKET BUY CREATE 344 shares at next open, current close price: 223.9600067138672
# 2020-10-28, BUY EXECUTED, 220.80
# 2020-10-28, Current Portfolio Value : 77452.67276156925
# 2020-10-28, LIMIT SELL CREATE 344 shares at 226.5327574183732
# 2020-10-29, SELL EXECUTED, 226.53
# 2020-10-29, Current Portfolio Value : 78059.05984376308
# 2020-10-29, MARKET BUY CREATE 347 shares at next open, current close price: 225.5800018310547
# 2020-10-30, BUY EXECUTED, 224.79
# 2020-10-30, Current Portfolio Value : 77375.4747149789
# 2020-10-30, LIMIT SELL CREATE 347 shares at 224.5674676677566
# 2020-11-02, Current Portfolio Value : 77167.27259705898
# 2020-11-02, LIMIT SELL CREATE 347 shares at 223.96275603135652
# 2020-11-03, SELL EXECUTED, 225.31
# 2020-11-03, Current Portfolio Value : 78239.50132630701
# 2020-11-03, MARKET BUY CREATE 358 shares at next open, current close price: 217.1300048828125
# 2020-11-04, BUY EXECUTED, 218.45
# 2020-11-04, Current Portfolio Value : 76313.46504090662
# 2020-11-04, LIMIT SELL CREATE 358 shares at 214.7410035362179
# 2020-11-05, SELL EXECUTED, 216.32
# 2020-11-05, Current Portfolio Value : 77476.96504090662
# 2020-11-05, MARKET BUY CREATE 353 shares at next open, current close price: 217.6999969482422
# 2020-11-06, BUY EXECUTED, 219.20
# 2020-11-06, Current Portfolio Value : 78634.8046099984
# 2020-11-06, LIMIT SELL CREATE 353 shares at 224.22478953862012
# 2020-11-09, Current Portfolio Value : 81444.68697999354
# 2020-11-09, LIMIT SELL CREATE 353 shares at 232.2472224063764
# 2020-11-10, Current Portfolio Value : 79633.79525636071
# 2020-11-10, LIMIT SELL CREATE 353 shares at 227.07698558836864
# 2020-11-11, SELL EXECUTED, 227.08
# 2020-11-11, Current Portfolio Value : 80257.54203087126
# 2020-11-11, MARKET BUY CREATE 359 shares at next open, current close price: 223.13999938964844
# 2020-11-12, BUY EXECUTED, 223.41
# 2020-11-12, Current Portfolio Value : 81391.98334556854
# 2020-11-12, LIMIT SELL CREATE 359 shares at 228.34687694911764
# 2020-11-13, SELL EXECUTED, 228.35
# 2020-11-13, Current Portfolio Value : 82029.87954090725
# 2020-11-13, MARKET BUY CREATE 352 shares at next open, current close price: 232.6499938964844
# 2020-11-16, BUY EXECUTED, 232.99
# 2020-11-16, Current Portfolio Value : 81625.076318251
# 2020-11-16, LIMIT SELL CREATE 352 shares at 233.6581957200356
# 2020-11-17, Current Portfolio Value : 81396.27846668848
# 2020-11-17, LIMIT SELL CREATE 352 shares at 233.0031042626486
# 2020-11-18, Current Portfolio Value : 79108.27846668848
# 2020-11-18, LIMIT SELL CREATE 352 shares at 226.45212817495613
# 2020-11-19, SELL EXECUTED, 226.45
# 2020-11-19, Current Portfolio Value : 79728.54672489804
# 2020-11-19, MARKET BUY CREATE 352 shares at next open, current close price: 226.3500061035156
# 2020-11-20, BUY EXECUTED, 226.23
# 2020-11-20, Current Portfolio Value : 79436.38608036682
# 2020-11-20, LIMIT SELL CREATE 352 shares at 227.167687720292
# 2020-11-23, Current Portfolio Value : 80524.07016239807
# 2020-11-23, LIMIT SELL CREATE 352 shares at 230.28193265575985
# 2020-11-24, SELL EXECUTED, 231.13
# 2020-11-24, Current Portfolio Value : 81453.3499475543
# 2020-11-24, MARKET BUY CREATE 352 shares at next open, current close price: 232.25
# 2020-11-25, BUY EXECUTED, 231.09
# 2020-11-25, Current Portfolio Value : 79922.15317021056
# 2020-11-25, LIMIT SELL CREATE 352 shares at 228.518208324458
# 2020-11-27, Current Portfolio Value : 80460.71274052303
# 2020-11-27, LIMIT SELL CREATE 352 shares at 230.0602060809768
# 2020-11-30, Current Portfolio Value : 81777.18930302306
# 2020-11-30, LIMIT SELL CREATE 352 shares at 233.82952709537597
# 2020-12-01, SELL EXECUTED, 234.94
# 2020-12-01, Current Portfolio Value : 82808.55209599179
# 2020-12-01, MARKET BUY CREATE 355 shares at next open, current close price: 234.19000244140625
# 2020-12-02, BUY EXECUTED, 232.76
# 2020-12-02, Current Portfolio Value : 83646.35231266658
# 2020-12-02, LIMIT SELL CREATE 355 shares at 236.96391780785623
# 2020-12-03, SELL EXECUTED, 236.96
# 2020-12-03, Current Portfolio Value : 84300.94486785399
# 2020-12-03, MARKET BUY CREATE 360 shares at next open, current close price: 232.58999633789065
# 2020-12-04, BUY EXECUTED, 233.77
# 2020-12-04, Current Portfolio Value : 85730.14530730715
# 2020-12-04, LIMIT SELL CREATE 360 shares at 239.60447554978373
# 2020-12-07, Current Portfolio Value : 85280.14530730715
# 2020-12-07, LIMIT SELL CREATE 360 shares at 238.34467245599672
# 2020-12-08, SELL EXECUTED, 238.34
# 2020-12-08, Current Portfolio Value : 85947.82541392688
# 2020-12-08, MARKET BUY CREATE 359 shares at next open, current close price: 239.22999572753903
# 2020-12-09, BUY EXECUTED, 238.75
# 2020-12-09, Current Portfolio Value : 86084.24716685657
# 2020-12-09, LIMIT SELL CREATE 359 shares at 241.00537597493664
# 2020-12-10, SELL EXECUTED, 241.01
# 2020-12-10, Current Portfolio Value : 86757.50538892913
# 2020-12-10, MARKET BUY CREATE 360 shares at next open, current close price: 241.55999755859372
# 2020-12-11, BUY EXECUTED, 240.54
# 2020-12-11, Current Portfolio Value : 86681.908465101
# 2020-12-11, LIMIT SELL CREATE 360 shares at 242.214783869281
# 2020-12-14, Current Portfolio Value : 86833.10780592132
# ...
# 2021-06-10, MARKET BUY CREATE 485 shares at next open, current close price: 277.5
# 2021-06-11, BUY EXECUTED, 278.50
# 2021-06-11, Current Portfolio Value : 134798.43377261356
# 2021-06-11, LIMIT SELL CREATE 485 shares at 281.040733645806
# 2021-06-14, Current Portfolio Value : 136258.2737079163
# 2021-06-14, LIMIT SELL CREATE 485 shares at 284.0890084696373
# 2021-06-15, Current Portfolio Value : 134434.68377261356
# 2021-06-15, LIMIT SELL CREATE 485 shares at 280.28119149302967
# 2021-06-16, Current Portfolio Value : 132955.42489199832
# 2021-06-16, LIMIT SELL CREATE 485 shares at 277.19236819489646
# 2021-06-17, SELL EXECUTED, 277.19
# 2021-06-17, Current Portfolio Value : 134644.37761081022
# 2021-06-17, MARKET BUY CREATE 488 shares at next open, current close price: 276.3399963378906
# 2021-06-18, BUY EXECUTED, 275.52
# 2021-06-18, Current Portfolio Value : 135844.86833346647
# 2021-06-18, LIMIT SELL CREATE 488 shares at 281.5167146311131
# 2021-06-21, Current Portfolio Value : 138401.98356784147
# 2021-06-21, LIMIT SELL CREATE 488 shares at 286.8233725819717
# 2021-06-22, Current Portfolio Value : 139792.7865463571
# 2021-06-22, LIMIT SELL CREATE 488 shares at 289.7096389436915
# 2021-06-23, Current Portfolio Value : 138621.58952487272
# 2021-06-23, LIMIT SELL CREATE 488 shares at 287.2791102359772
# 2021-06-24, SELL EXECUTED, 287.28
# 2021-06-24, Current Portfolio Value : 140382.82876729523
# 2021-06-24, MARKET BUY CREATE 485 shares at next open, current close price: 286.9599914550781
# 2021-06-25, BUY EXECUTED, 288.86
# 2021-06-25, Current Portfolio Value : 140324.6311354593
# 2021-06-25, LIMIT SELL CREATE 485 shares at 292.4135917002995
# 2021-06-28, Current Portfolio Value : 142565.32876729523
# 2021-06-28, LIMIT SELL CREATE 485 shares at 297.0923664164656
# 2021-06-29, SELL EXECUTED, 297.09
# 2021-06-29, Current Portfolio Value : 144375.53358377324
# 2021-06-29, MARKET BUY CREATE 486 shares at next open, current close price: 297.739990234375
# 2021-06-30, BUY EXECUTED, 296.67
# 2021-06-30, Current Portfolio Value : 142057.30409158574
# 2021-06-30, LIMIT SELL CREATE 486 shares at 295.6137996793656
# 2021-07-01, Current Portfolio Value : 142932.11299051152
# 2021-07-01, LIMIT SELL CREATE 486 shares at 297.43671938953827
# 2021-07-02, SELL EXECUTED, 297.44
# 2021-07-02, Current Portfolio Value : 144748.15268120993
# 2021-07-02, MARKET BUY CREATE 485 shares at next open, current close price: 297.739990234375
# 2021-07-06, BUY EXECUTED, 298.19
# 2021-07-06, Current Portfolio Value : 143492.00445733298
# 2021-07-06, LIMIT SELL CREATE 485 shares at 299.3608866620684
# 2021-07-07, Current Portfolio Value : 143739.3443926357
# 2021-07-07, LIMIT SELL CREATE 485 shares at 299.8773543099787
# 2021-07-08, Current Portfolio Value : 142943.95208916892
# 2021-07-08, LIMIT SELL CREATE 485 shares at 298.2165048736162
# 2021-07-09, Current Portfolio Value : 143385.30386529196
# 2021-07-09, LIMIT SELL CREATE 485 shares at 299.1380863943533
# 2021-07-12, Current Portfolio Value : 141712.0479448818
# 2021-07-12, LIMIT SELL CREATE 485 shares at 295.6441801292426
# 2021-07-13, SELL EXECUTED, 295.64
# 2021-07-13, Current Portfolio Value : 143513.42885981058
# 2021-07-13, MARKET BUY CREATE 480 shares at next open, current close price: 296.4200134277344
# 2021-07-14, BUY EXECUTED, 298.50
# 2021-07-14, Current Portfolio Value : 142841.43178949808
# 2021-07-14, LIMIT SELL CREATE 480 shares at 300.879970967621
# 2021-07-15, Current Portfolio Value : 141732.63296137308
# 2021-07-15, LIMIT SELL CREATE 480 shares at 298.5405836095379
# 2021-07-16, Current Portfolio Value : 141031.82241449808
# 2021-07-16, LIMIT SELL CREATE 480 shares at 297.0619859665885
# 2021-07-19, Current Portfolio Value : 138142.22768793555
# 2021-07-19, LIMIT SELL CREATE 480 shares at 290.96540541307644
# 2021-07-20, SELL EXECUTED, 290.97
# 2021-07-20, Current Portfolio Value : 139896.82345808728
# 2021-07-20, MARKET BUY CREATE 474 shares at next open, current close price: 296.1199951171875
# 2021-07-21, BUY EXECUTED, 294.82
# 2021-07-21, Current Portfolio Value : 143195.8594077943
# 2021-07-21, LIMIT SELL CREATE 474 shares at 305.61950658354124
# 2021-07-22, SELL EXECUTED, 305.62
# 2021-07-22, Current Portfolio Value : 145015.78610700613
# 2021-07-22, MARKET BUY CREATE 467 shares at next open, current close price: 308.510009765625
# 2021-07-23, BUY EXECUTED, 310.19
# 2021-07-23, Current Portfolio Value : 146164.60211652762
# 2021-07-23, LIMIT SELL CREATE 467 shares at 316.62779923950984
# 2021-07-26, Current Portfolio Value : 146617.59268659598
# 2021-07-26, LIMIT SELL CREATE 467 shares at 317.61014166000115
# 2021-07-27, Current Portfolio Value : 144109.80496686941
# 2021-07-27, LIMIT SELL CREATE 467 shares at 312.1718247910587
# 2021-07-28, SELL EXECUTED, 312.17
# 2021-07-28, Current Portfolio Value : 145941.29714429384
# 2021-07-28, MARKET BUY CREATE 465 shares at next open, current close price: 313.1300048828125
# 2021-07-29, BUY EXECUTED, 313.68
# 2021-07-29, Current Portfolio Value : 149112.60055005556
# 2021-07-29, LIMIT SELL CREATE 465 shares at 324.5776799530716
# 2021-07-30, Current Portfolio Value : 149405.55282056337
# 2021-07-30, LIMIT SELL CREATE 465 shares at 325.2157003063396
# 2021-08-02, Current Portfolio Value : 149842.65395581728
# 2021-08-02, LIMIT SELL CREATE 465 shares at 326.1676622769538
# 2021-08-03, SELL EXECUTED, 326.17
# 2021-08-03, Current Portfolio Value : 151748.06350883908
# 2021-08-03, MARKET BUY CREATE 462 shares at next open, current close price: 327.6099853515625
# 2021-08-04, BUY EXECUTED, 328.00
# 2021-08-04, Current Portfolio Value : 152251.64181694455
# 2021-08-04, LIMIT SELL CREATE 462 shares at 333.27696570083424
# 2021-08-05, Current Portfolio Value : 152126.90689262815
# 2021-08-05, LIMIT SELL CREATE 462 shares at 333.0035416519405
# 2021-08-06, SELL EXECUTED, 333.00
# 2021-08-06, Current Portfolio Value : 154059.6997520356
# 2021-08-06, MARKET BUY CREATE 462 shares at next open, current close price: 332.7699890136719
# 2021-08-09, BUY EXECUTED, 333.18
# 2021-08-09, Current Portfolio Value : 153870.27806014108
# 2021-08-09, LIMIT SELL CREATE 462 shares at 337.0037784463861
# 2021-08-10, Current Portfolio Value : 153181.90257185983
# 2021-08-10, LIMIT SELL CREATE 462 shares at 335.4948312594089
# 2021-08-11, Current Portfolio Value : 151962.2299034028
# 2021-08-11, LIMIT SELL CREATE 462 shares at 332.821258952678
# 2021-08-12, Current Portfolio Value : 153537.63749617623
# 2021-08-12, LIMIT SELL CREATE 462 shares at 336.2746167434869
# 2021-08-13, Current Portfolio Value : 153874.90257185983
# 2021-08-13, LIMIT SELL CREATE 462 shares at 337.0139155649616
# 2021-08-16, Current Portfolio Value : 152673.6997520356
# 2021-08-16, LIMIT SELL CREATE 462 shares at 334.3808299208339
# 2021-08-17, Current Portfolio Value : 150141.9487754731
# 2021-08-17, LIMIT SELL CREATE 462 shares at 328.8311283709586
# 2021-08-18, Current Portfolio Value : 149596.77806014108
# 2021-08-18, LIMIT SELL CREATE 462 shares at 327.6360918954784
# 2021-08-19, SELL EXECUTED, 327.64
# 2021-08-19, Current Portfolio Value : 151498.4175915357
# 2021-08-19, MARKET BUY CREATE 456 shares at next open, current close price: 330.3500061035156
# 2021-08-20, BUY EXECUTED, 331.65
# 2021-08-20, Current Portfolio Value : 152743.30260130132
# 2021-08-20, LIMIT SELL CREATE 456 shares at 338.6342783387209
# 2021-08-23, Current Portfolio Value : 153828.58482786382
# 2021-08-23, LIMIT SELL CREATE 456 shares at 341.0445637151336
# 2021-08-24, SELL EXECUTED, 341.04
# 2021-08-24, Current Portfolio Value : 155782.34142883975
# 2021-08-24, MARKET BUY CREATE 454 shares at next open, current close price: 341.07000732421875
# 2021-08-25, BUY EXECUTED, 342.52
# 2021-08-25, Current Portfolio Value : 155668.84142883975
# 2021-08-25, LIMIT SELL CREATE 454 shares at 346.6246457148859
# 2021-08-26, Current Portfolio Value : 141104.52752503115
# 2021-08-26, LIMIT SELL CREATE 454 shares at 314.13650963204134
# 2021-08-27, SELL EXECUTED, 314.23
# 2021-08-27, Current Portfolio Value : 142938.69140442568
# 2021-08-27, MARKET BUY CREATE 450 shares at next open, current close price: 315.6400146484375
# 2021-08-30, BUY EXECUTED, 316.94
# 2021-08-30, Current Portfolio Value : 141341.19689758975
# 2021-08-30, LIMIT SELL CREATE 450 shares at 317.37723517956
# 2021-08-31, Current Portfolio Value : 139856.18865784365
# 2021-08-31, LIMIT SELL CREATE 450 shares at 314.0352311638347
# 2021-09-01, SELL EXECUTED, 314.04
# 2021-09-01, Current Portfolio Value : 141631.54432951848
# 2021-09-01, MARKET BUY CREATE 462 shares at next open, current close price: 303.239990234375
# 2021-09-02, BUY EXECUTED, 306.50
# 2021-09-02, Current Portfolio Value : 132839.68489348333
# 2021-09-02, LIMIT SELL CREATE 462 shares at 291.1274447810374
# 2021-09-03, SELL EXECUTED, 291.13
# 2021-09-03, Current Portfolio Value : 134529.42381835775
# 2021-09-03, MARKET BUY CREATE 462 shares at next open, current close price: 288.75
# 2021-09-07, BUY EXECUTED, 290.76
# 2021-09-07, Current Portfolio Value : 133004.8153588851
# 2021-09-07, LIMIT SELL CREATE 462 shares at 291.11730766246194
# 2021-09-08, Current Portfolio Value : 133975.0181787093
# 2021-09-08, LIMIT SELL CREATE 462 shares at 293.2440318714053
# 2021-09-09, Current Portfolio Value : 133106.45592284994
# 2021-09-09, LIMIT SELL CREATE 462 shares at 291.34010793017694
# 2021-09-10, Current Portfolio Value : 131604.95592284994
# 2021-09-10, LIMIT SELL CREATE 462 shares at 288.0487586014797
# 2021-09-13, Current Portfolio Value : 130149.65874267416
# 2021-09-13, LIMIT SELL CREATE 462 shares at 284.85868774098907
# 2021-09-14, Current Portfolio Value : 129258.00212646322
# 2021-09-14, LIMIT SELL CREATE 462 shares at 282.90414001858187
# 2021-09-15, SELL EXECUTED, 282.90
# 2021-09-15, Current Portfolio Value : 130900.01199522383
# 2021-09-15, MARKET BUY CREATE 455 shares at next open, current close price: 286.6199951171875
# 2021-09-16, BUY EXECUTED, 287.11
# 2021-09-16, Current Portfolio Value : 132524.36532774335
# 2021-09-16, LIMIT SELL CREATE 455 shares at 294.37827654128216
# 2021-09-17, Current Portfolio Value : 131373.21588316327
# 2021-09-17, LIMIT SELL CREATE 455 shares at 291.81608891548404
# 2021-09-20, Current Portfolio Value : 129302.9714373625
# 2021-09-20, LIMIT SELL CREATE 455 shares at 287.2082122176476
# 2021-09-21, Current Portfolio Value : 129116.41977110274
# 2021-09-21, LIMIT SELL CREATE 455 shares at 286.79299213209464
# 2021-09-22, SELL EXECUTED, 286.79
# 2021-09-22, Current Portfolio Value : 130755.78008036595
# 2021-09-22, MARKET BUY CREATE 454 shares at next open, current close price: 286.4200134277344
# 2021-09-23, BUY EXECUTED, 287.86
# 2021-09-23, Current Portfolio Value : 132707.98839335423
# 2021-09-23, LIMIT SELL CREATE 454 shares at 295.87711751553314
# 2021-09-24, Current Portfolio Value : 133847.53282694798
# 2021-09-24, LIMIT SELL CREATE 454 shares at 298.4190618100296
# 2021-09-27, Current Portfolio Value : 133570.5856223581
# 2021-09-27, LIMIT SELL CREATE 454 shares at 297.8012847880631
# 2021-09-28, Current Portfolio Value : 130751.24950175267
# 2021-09-28, LIMIT SELL CREATE 454 shares at 291.51228441671327
# 2021-09-29, SELL EXECUTED, 291.51
# 2021-09-29, Current Portfolio Value : 132413.9238559444
# 2021-09-29, MARKET BUY CREATE 456 shares at next open, current close price: 287.989990234375
# 2021-09-30, BUY EXECUTED, 290.33
# 2021-09-30, Current Portfolio Value : 130060.97610203814
# 2021-09-30, LIMIT SELL CREATE 456 shares at 288.7981945415298
# 2021-10-01, Current Portfolio Value : 129554.80886570999
# 2021-10-01, LIMIT SELL CREATE 456 shares at 287.6740560843792
# 2021-10-04, Current Portfolio Value : 124479.52663914752
# 2021-10-04, LIMIT SELL CREATE 456 shares at 276.40244559224305
# 2021-10-05, SELL EXECUTED, 276.40
# 2021-10-05, Current Portfolio Value : 126062.9651690541
# 2021-10-05, MARKET BUY CREATE 461 shares at next open, current close price: 275.9800109863281
# 2021-10-06, BUY EXECUTED, 272.95
# 2021-10-06, Current Portfolio Value : 128123.63573179825
# 2021-10-06, LIMIT SELL CREATE 461 shares at 280.9495922961747
# 2021-10-07, SELL EXECUTED, 280.95
# 2021-10-07, Current Portfolio Value : 129750.77159014925
# 2021-10-07, MARKET BUY CREATE 456 shares at next open, current close price: 283.0199890136719
# 2021-10-08, BUY EXECUTED, 284.05
# 2021-10-08, Current Portfolio Value : 127420.61826983675
# 2021-10-08, LIMIT SELL CREATE 456 shares at 282.4889199330289
# 2021-10-11, Current Portfolio Value : 126326.22105303987
# 2021-10-11, LIMIT SELL CREATE 456 shares at 280.0583912253146
# 2021-10-12, Current Portfolio Value : 126038.93882647737
# 2021-10-12, LIMIT SELL CREATE 456 shares at 279.42037087204665
# 2021-10-13, SELL EXECUTED, 279.42
# 2021-10-13, Current Portfolio Value : 127639.66627420876
# 2021-10-13, MARKET BUY CREATE 444 shares at next open, current close price: 283.45001220703125
# 2021-10-14, BUY EXECUTED, 286.85
# 2021-10-14, Current Portfolio Value : 128669.74952616189
# 2021-10-14, LIMIT SELL CREATE 444 shares at 292.8490860230034
# 2021-10-15, Current Portfolio Value : 129566.6246482322
# 2021-10-15, LIMIT SELL CREATE 444 shares at 294.8947750950418
# 2021-10-18, Current Portfolio Value : 130223.74952616189
# 2021-10-18, LIMIT SELL CREATE 444 shares at 296.3936160692928
# 2021-10-19, SELL EXECUTED, 296.39
# 2021-10-19, Current Portfolio Value : 131877.02909901383
# 2021-10-19, MARKET BUY CREATE 442 shares at next open, current close price: 296.69000244140625
# 2021-10-20, BUY EXECUTED, 297.81
# 2021-10-20, Current Portfolio Value : 132243.8966527248
# 2021-10-20, LIMIT SELL CREATE 442 shares at 302.4395728416261
# 2021-10-21, SELL EXECUTED, 302.44
# 2021-10-21, Current Portfolio Value : 133923.30137411415
# 2021-10-21, MARKET BUY CREATE 437 shares at next open, current close price: 305.67999267578125
# 2021-10-22, BUY EXECUTED, 306.00
# 2021-10-22, Current Portfolio Value : 135050.75550619423
# 2021-10-22, LIMIT SELL CREATE 437 shares at 312.5060097397066
# 2021-10-25, Current Portfolio Value : 136453.535108245
# 2021-10-25, LIMIT SELL CREATE 437 shares at 315.75687240580066
# 2021-10-26, Current Portfolio Value : 136894.8960396415
# 2021-10-26, LIMIT SELL CREATE 437 shares at 316.7797014888952
# 2021-10-27, Current Portfolio Value : 135020.17564169227
# 2021-10-27, LIMIT SELL CREATE 437 shares at 312.4351426272263
# 2021-10-28, SELL EXECUTED, 312.44
# 2021-10-28, Current Portfolio Value : 136735.45870221205
# 2021-10-28, MARKET BUY CREATE 433 shares at next open, current close price: 317.1000061035156
# 2021-10-29, BUY EXECUTED, 315.53
# 2021-10-29, Current Portfolio Value : 137636.09288800307
# 2021-10-29, LIMIT SELL CREATE 433 shares at 321.65089602289925
# 2021-11-01, Current Portfolio Value : 136510.30345929213
# 2021-11-01, LIMIT SELL CREATE 433 shares at 319.0178412846209
# 2021-11-02, Current Portfolio Value : 136471.3350449855
# 2021-11-02, LIMIT SELL CREATE 433 shares at 318.92669993498964
# 2021-11-03, Current Portfolio Value : 133635.1771165187
# 2021-11-03, LIMIT SELL CREATE 433 shares at 312.29334659056707
# 2021-11-04, SELL EXECUTED, 312.29
# 2021-11-04, Current Portfolio Value : 135333.98830449206
# 2021-11-04, MARKET BUY CREATE 422 shares at next open, current close price: 318.9700012207031
# 2021-11-05, BUY EXECUTED, 320.00
# 2021-11-05, Current Portfolio Value : 137241.4236682616
# 2021-11-05, LIMIT SELL CREATE 422 shares at 328.6488147658468
# 2021-11-08, Current Portfolio Value : 139161.53139531237
# 2021-11-08, LIMIT SELL CREATE 422 shares at 333.2567223695326
# Final Portfolio Value: 139161.53139531237
#
# STRATEGY INFO:
# OrderedDict([('sharperatio', 0.1599444778358812)])
# AutoOrderedDict([('len', 208), ('drawdown', 14.096751103105554), ('moneydown', 22836.452595189883), ('max', AutoOrderedDict([('len', 208), ('drawdown', 33.37034499951599), ('moneydown', 41877.36626914388)]))])
# OrderedDict([('rtot', 0.3304651688004377), ('ravg', 0.0006119725348156254), ('rnorm', 0.16674413467586113), ('rnorm100', 16.674413467586113)])
# For ADSK, return was 114.70636517333985% for buy and hold vs 39.16153139531238%  for strategy
# {'WAT': <backtrader.cerebro.Cerebro at 0x7fbd985bba10>,
#  'UNH': <backtrader.cerebro.Cerebro at 0x7fbd9870a790>,
#  'HD': <backtrader.cerebro.Cerebro at 0x7fbda9220710>,
#  'MSFT': <backtrader.cerebro.Cerebro at 0x7fbda967d5d0>,
#  'XOM': <backtrader.cerebro.Cerebro at 0x7fbda9217050>,
#  'ADSK': <backtrader.cerebro.Cerebro at 0x7fbdd8a43950>}

# %% [markdown]
# ### Library additionally has plotting
# Not sure how to reformat this, it's pretty ugly

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 8]
plt.rcParams.update({'font.size': 12}) 
cerebro_dict['UNH'].plot()

# %% [markdown]
# ### Ways to Improve:

# %% [markdown]
# Increase strategy trading volume. There are certain periods where sell orders are not going through for multiple days in a row, meaning that the price is lower than anticipated by model for that period. For example, if the last sell order didn't go through, we can find a way to use that information to inform our next sell order and make the prediction lower or try a market sell. Maybe train a "bear" model, one that only knows pain and suffering of bear markets, and only produces pessimistic high price predictions.
#
# Smarter entry points. Currently, buy orders are being executed at market price at the open. Returns may increase if entry constraints are increased.
#
# Resizing orders. Orders for this strategy baseline are currently 100% in or 100% out of position. This has beneifits if you want less exposure to the long term movement of the stocks. Depending on the situation and strategy, we might want to reserve a cash position to expose ourselves less to short term movements.
