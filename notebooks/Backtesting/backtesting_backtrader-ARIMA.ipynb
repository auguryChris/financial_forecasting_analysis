# %% [markdown]
# # Backtesting with backtrader library
# Notes:
# Timestamp must be in the exact format specified for datafeed   **Timestamp needs to be first column index**
# Params for datafeed need to be specified as tuple of tuples
# Within strategy data is accessed via self.datas[0] for ex: self.datas[0].high_delta[0] would get you the first timeperiod's high_delta
# The current data has already happened and cannot be used to execute an order (ex. you cannot look at the current close price and simultaneously buy the current close, the order will be executed at open instead), orders will be executed on the following day.

# %%
import backtrader as bt
import datetime
import pandas as pd

# %% [markdown]
# ## Define Strategies and Data utils

# %%
class BasicStrategy(bt.Strategy):
    def __init__(self):
        # To keep track of pending orders
        self.order = None
        print('***The limit sells for this strategy are valid for 1 day***')
        
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)

            self.bar_executed = len(self)

            # Note: This logic does not properly work
#         elif order.status in [order.Expired]:
#             if order.isbuy():
#                 self.log('BUY ORDER EXPIRED')
#             elif order.issell():
#                 self.log('SELL ORDER EXPIRED')
        
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')
        
        self.order = None



    def next(self):
        # STRATEGY 
        data = self.datas[0]
        self.log(f'Current Portfolio Value : {self.broker.get_value()}')
        
        # Check if we are in the market
        if not self.position:
            # BUY
            try:
                self.size = int(self.broker.get_cash() / self.datas[0].open[1])
            except:
                print('Size Exception. If at the end of data, ignore.')
            # invest if prediction looks good
            # TODO: Make this a filter in the class constructor
            if (data.prediction[0] >= data.close[0]):
                self.log(f'MARKET BUY CREATE {self.size} shares at next open, current close price: {data.close[0]}')
                # Keep track of the created order to avoid a 2nd order
                self.order = self.buy(size=self.size) # market order buys at next open
                
        else:
            # place sell order at predicted high if predicted high is greater than current close price
            if data.prediction[0] > data.close[0]:
                self.log(f'LIMIT SELL CREATE {self.size} shares at {data.prediction[0]}')
                # Keep track of the created order to avoid a 2nd order, order valid for 1 day
                self.order = self.sell(exectype=bt.Order.Limit,
                             price=data.prediction[0],
                             valid=data.datetime.date(0) + datetime.timedelta(days=2),
                             size=self.size)
            # if prediction is less than current value sell at open
            else:
                self.log('MARKET SELL CREATE. PREDICTION < CURRENT CLOSE')
                self.order = self.sell(size=self.size)

# %%
class BuyAndHold(bt.Strategy):
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)

            self.bar_executed = len(self)

      
    def start(self):
        self.val_start = self.broker.get_cash()  # keep the starting cash

    def nextstart(self):
        # Buy all the available cash
        size = int(self.broker.get_cash() / self.datas[0].open[1])
        self.buy(size=size)

    def stop(self):
        # calculate the actual returns
        self.roi = (self.broker.get_value() / self.val_start) - 1.0
        print(f'Stop price: {self.datas[0].close[0]}')
        print('ROI:        {:.2f}%'.format(100.0 * self.roi))

# %%
def prepare_data(data, fromdate, todate, filepath):
    """Prepare data for backtrader datafeed object
        Returns prepared data filepath and params for the GenericCSVData class, also returns columns used"""
    data['timestamp'] = pd.to_datetime(data['timestamp'])
    # start param setup for backtrader
    start = data['timestamp'].iloc[0]
    end = data['timestamp'].iloc[-1]
    from_to = [(start.year, start.month, start.day), (end.year, end.month, end.day)]
    # Backtrader string format
    data['timestamp'] = data['timestamp'].dt.strftime('%Y-%m-%d %H:%M:%S')
    # backtrader data feed class needs a file path, this could be a temp file that's constantly overwritten
    data.to_csv(filepath)
    
    starting_params = [
    ('fromdate', datetime.datetime(*from_to[0])),
    ('todate', datetime.datetime(*from_to[1])),
    ('nullvalue', 0.0),
    ('dtformat', ('%Y-%m-%d %H:%M:%S')),
    ('tmformat', ('%H:%M:%S')),
    ('datetime', 1)]
    # skip nonfeatures (timestamp)
    cols = data.columns[1:]
    # get column position for each indicator and add to starting params list
    i = 2 # starting index since others are reserved
    for indicator in cols:
        starting_params.append((indicator, i))
        i+=1
    final_params = tuple(starting_params)

    return filepath, final_params, cols

# %% [markdown]
# ## Import Data and Run Backtest

# %%
import os

# %%
def capstone_data_prep(pred_folder_name, pred_col_name, ticker_df_filepath, starting_cash=100000):
    """Main loop, preps data and executes backtrader on all stocks in the prediction folder"""
    ticker_backtesting_dict = {}
    for pred_file in os.listdir(f'../data/ticker_predictions/{pred_folder_name}'):
        ticker_name = pred_file.split('_')[0]
        pred_df = pd.read_csv(f'../data/ticker_predictions/{pred_folder_name}/{pred_file}')
        ticker_df = pd.read_csv(ticker_df_filepath + f'/{ticker_name}_full_data.csv')
        # new prediction column name = "prediction", important because backtester strategy looks for this column name
        ticker_df['prediction'] = pred_df[pred_col_name]
        # remove all non-prediction rows, use "timestamp" as the common datetime name
        ticker_df = ticker_df[ticker_df.prediction > 0]
        ticker_df = ticker_df.rename({'reportperiod':'timestamp'}, axis=1)

        # make timestamp in column position 0 
        ticker_cols = list(ticker_df.columns)
        ticker_cols[5] = 'ts_cpy'
        ticker_cols[0] = 'timestamp'
        ticker_df.columns = ticker_cols
        ticker_df['timestamp'] = ticker_df['ts_cpy']

        # skip nonfeatures, keep timestamp
        nonfeatures = ticker_df.columns[1:7]
        features = [col for col in ticker_df.columns if col not in nonfeatures]
        # get index of start and end dates for trading
        ticker_df = ticker_df[features]
        ticker_df.columns = [c.lower() for c in ticker_df.columns]
        idx1 = ticker_df.prediction[ticker_df.prediction > 0].index[0]
        idx2 = ticker_df.prediction[ticker_df.prediction > 0].index[-1]
        start_date = pred_df.timestamp[idx1]
        end_date  = pred_df.timestamp[idx2]

        # Prepare data for backtrader
        prep_data = prepare_data(ticker_df.copy(), start_date, end_date, 'temp/prep_data.csv')
        class DataFeed(bt.feeds.GenericCSVData):
            lines = tuple(prep_data[2])
            params = prep_data[1]
        
        print(f"--------Ticker Name-------: {ticker_name}")
        ##### BUY AND HOLD #######
        print('BUY AND HOLD')
        # initialize everything and run strategy
        cerebro = bt.Cerebro(cheat_on_open=True)
        cerebro.broker.setcash(starting_cash)
        #cerebro.addsizer(bt.sizers.FixedSize, stake=10)
        print(f'Starting Portfolio Value: {cerebro.broker.getvalue()}')
        data = DataFeed(dataname=prep_data[0])
        cerebro.adddata(data)
        cerebro.addstrategy(BuyAndHold)
        cerebro.addanalyzer(bt.analyzers.SharpeRatio, timeframe=bt.TimeFrame.Months, _name = 'sharpe')
        cerebro.addanalyzer(bt.analyzers.DrawDown, _name = 'dd')
        cerebro.addanalyzer(bt.analyzers.Returns, _name = 'returns')
        buy_hold = cerebro.run()
        buy_hold_ret = cerebro.broker.getvalue() / starting_cash - 1
        print(f'Final Portfolio Value: {cerebro.broker.getvalue()}\n')
        print('STRATEGY INFO:')
        print(buy_hold[0].analyzers.sharpe.get_analysis())
        print(buy_hold[0].analyzers.dd.get_analysis())
        # rtot is total log returns over the strategy time period
        print(buy_hold[0].analyzers.returns.get_analysis())

        #### MAIN STRATEGY #####
        cerebro = bt.Cerebro(cheat_on_open=True)
        cerebro.broker.setcash(starting_cash)
        print(f'Starting Portfolio Value: {cerebro.broker.getvalue()}')
        data = DataFeed(dataname=prep_data[0])
        cerebro.adddata(data)
        cerebro.addstrategy(BasicStrategy)
        cerebro.addanalyzer(bt.analyzers.SharpeRatio, timeframe=bt.TimeFrame.Months, _name = 'sharpe')
        cerebro.addanalyzer(bt.analyzers.DrawDown, _name = 'dd')
        cerebro.addanalyzer(bt.analyzers.Returns, _name = 'returns')
        back = cerebro.run()
        strat_ret = cerebro.broker.getvalue() / starting_cash - 1
        print(f'Final Portfolio Value: {cerebro.broker.getvalue()}\n')
        print('STRATEGY INFO:')
        print(back[0].analyzers.sharpe.get_analysis())
        print(back[0].analyzers.dd.get_analysis())
        # rtot is total log returns over the strategy time period
        print(back[0].analyzers.returns.get_analysis())
        print(f"For {ticker_name}, return was {buy_hold_ret*100}% for buy and hold vs {strat_ret*100}%  for strategy")
        print('\n'*5)

        ticker_backtesting_dict[ticker_name] = cerebro
        
    return ticker_backtesting_dict
#     return ticker_df

# %%
# pred_folder_name, pred_col_name, ticker_df_filepath, starting_cash=100000

cerebro_dict = capstone_data_prep('arima_preds', 'prediction', '../data/ticker_data')
cerebro_dict
# Out:
# --------Ticker Name-------: WAT
# BUY AND HOLD
# Starting Portfolio Value: 100000
# 2000-04-03, BUY EXECUTED, 47.25
# Stop price: 26.65999984741211
# ROI:        -43.57%
# Final Portfolio Value: 56431.55967712402
#
# STRATEGY INFO:
# OrderedDict([('sharperatio', -0.03987808414248128)])
# AutoOrderedDict([('len', 416), ('drawdown', 70.49368783303537), ('moneydown', 134820.94032287598), ('max', AutoOrderedDict([('len', 416), ('drawdown', 74.93031505846456), ('moneydown', 143306.10080718994)]))])
# OrderedDict([('rtot', -0.5721416152409546), ('ravg', -0.0010556118362379237), ('rnorm', -0.2335717426226032), ('rnorm100', -23.35717426226032)])
# Starting Portfolio Value: 100000
# ***The limit sells for this strategy are valid for 1 day***
# 2000-03-31, Current Portfolio Value : 100000.0
# 2000-03-31, MARKET BUY CREATE 2116 shares at next open, current close price: 47.625
# 2000-04-03, BUY EXECUTED, 47.25
# 2000-04-03, Current Portfolio Value : 92197.25
# 2000-04-03, LIMIT SELL CREATE 2116 shares at 230.130747057432
# 2000-04-04, Current Portfolio Value : 93189.125
# 2000-04-04, LIMIT SELL CREATE 2116 shares at 230.4935709635808
# 2000-04-05, Current Portfolio Value : 97090.5
# 2000-04-05, LIMIT SELL CREATE 2116 shares at 230.4935709635808
# 2000-04-06, Current Portfolio Value : 98611.375
# 2000-04-06, LIMIT SELL CREATE 2116 shares at 229.5764306204745
# 2000-04-07, Current Portfolio Value : 103041.75
# 2000-04-07, LIMIT SELL CREATE 2116 shares at 222.7734939140246
# 2000-04-10, Current Portfolio Value : 101587.0
# 2000-04-10, LIMIT SELL CREATE 2116 shares at 221.9269099258291
# 2000-04-11, Current Portfolio Value : 96098.625
# 2000-04-11, LIMIT SELL CREATE 2116 shares at 218.93361654471468
# 2000-04-12, Current Portfolio Value : 93718.125
# 2000-04-12, LIMIT SELL CREATE 2116 shares at 224.2751847380628
# 2000-04-13, Current Portfolio Value : 93453.625
# 2000-04-13, LIMIT SELL CREATE 2116 shares at 224.98067139489237
# 2000-04-14, Current Portfolio Value : 89287.75
# 2000-04-14, LIMIT SELL CREATE 2116 shares at 225.9582798259476
# 2000-04-17, Current Portfolio Value : 81947.875
# 2000-04-17, LIMIT SELL CREATE 2116 shares at 223.73095656806737
# 2000-04-18, Current Portfolio Value : 82675.25
# 2000-04-18, LIMIT SELL CREATE 2116 shares at 226.3211037320964
# 2000-04-19, Current Portfolio Value : 87105.625
# 2000-04-19, LIMIT SELL CREATE 2116 shares at 228.7802418317216
# 2000-04-20, Current Portfolio Value : 87634.625
# 2000-04-20, LIMIT SELL CREATE 2116 shares at 225.23263201364972
# 2000-04-24, Current Portfolio Value : 84923.5
# 2000-04-24, LIMIT SELL CREATE 2116 shares at 209.64130769466527
# 2000-04-25, Current Portfolio Value : 91073.125
# 2000-04-25, LIMIT SELL CREATE 2116 shares at 209.98398582380165
# 2000-04-26, Current Portfolio Value : 95900.25
# 2000-04-26, LIMIT SELL CREATE 2116 shares at 212.95711804944787
# 2000-04-27, Current Portfolio Value : 91469.875
# 2000-04-27, LIMIT SELL CREATE 2116 shares at 215.2953045947196
# 2000-04-28, Current Portfolio Value : 100264.5
# 2000-04-28, LIMIT SELL CREATE 2116 shares at 215.547265213477
# 2000-05-01, Current Portfolio Value : 98016.25
# 2000-05-01, LIMIT SELL CREATE 2116 shares at 217.0791900814896
# 2000-05-02, Current Portfolio Value : 96363.125
# 2000-05-02, LIMIT SELL CREATE 2116 shares at 215.2650705507452
# 2000-05-03, Current Portfolio Value : 92065.0
# 2000-05-03, LIMIT SELL CREATE 2116 shares at 216.4442444011152
# 2000-05-04, Current Portfolio Value : 94114.875
# 2000-05-04, LIMIT SELL CREATE 2116 shares at 217.4420139876385
# 2000-05-05, Current Portfolio Value : 97024.375
# 2000-05-05, LIMIT SELL CREATE 2116 shares at 219.04447983210625
# 2000-05-08, Current Portfolio Value : 97487.25
# 2000-05-08, LIMIT SELL CREATE 2116 shares at 220.7981312749018
# 2000-05-09, Current Portfolio Value : 98677.5
# 2000-05-09, LIMIT SELL CREATE 2116 shares at 216.15197684987703
# 2000-05-10, Current Portfolio Value : 95305.125
# 2000-05-10, LIMIT SELL CREATE 2116 shares at 217.54280438652373
# 2000-05-11, Current Portfolio Value : 97090.5
# 2000-05-11, LIMIT SELL CREATE 2116 shares at 219.82052284384665
# 2000-05-12, Current Portfolio Value : 96627.625
# 2000-05-12, LIMIT SELL CREATE 2116 shares at 221.83620779390583
# 2000-05-15, Current Portfolio Value : 96627.625
# 2000-05-15, LIMIT SELL CREATE 2116 shares at 215.9705572075748
# 2000-05-16, Current Portfolio Value : 99206.5
# 2000-05-16, LIMIT SELL CREATE 2116 shares at 216.6861321313663
# 2000-05-17, Current Portfolio Value : 101058.0
# 2000-05-17, LIMIT SELL CREATE 2116 shares at 213.2796196446604
# 2000-05-18, Current Portfolio Value : 102116.0
# 2000-05-18, LIMIT SELL CREATE 2116 shares at 216.7768342632896
# 2000-05-19, Current Portfolio Value : 98346.875
# 2000-05-19, LIMIT SELL CREATE 2116 shares at 216.67605924286008
# 2000-05-22, Current Portfolio Value : 95239.0
# 2000-05-22, LIMIT SELL CREATE 2116 shares at 215.2549976622389
# 2000-05-23, Current Portfolio Value : 92329.5
# 2000-05-23, LIMIT SELL CREATE 2116 shares at 214.7410035362179
# 2000-05-24, Current Portfolio Value : 94114.875
# 2000-05-24, LIMIT SELL CREATE 2116 shares at 213.64244355080925
# 2000-05-25, Current Portfolio Value : 93519.75
# 2000-05-25, LIMIT SELL CREATE 2116 shares at 211.7275489996353
# 2000-05-26, Current Portfolio Value : 93056.875
# 2000-05-26, LIMIT SELL CREATE 2116 shares at 211.21355487361427
# 2000-05-30, Current Portfolio Value : 99404.875
# 2000-05-30, LIMIT SELL CREATE 2116 shares at 214.24715518720933
# 2000-05-31, Current Portfolio Value : 100000.0
# 2000-05-31, LIMIT SELL CREATE 2116 shares at 215.0635051314304
# 2000-06-01, Current Portfolio Value : 105951.25
# 2000-06-01, LIMIT SELL CREATE 2116 shares at 215.15420726335364
# 2000-06-02, Current Portfolio Value : 116134.5
# 2000-06-02, LIMIT SELL CREATE 2116 shares at 219.02433405509373
# 2000-06-05, Current Portfolio Value : 110712.25
# 2000-06-05, LIMIT SELL CREATE 2116 shares at 218.0366373570766
# 2000-06-06, Current Portfolio Value : 111241.25
# 2000-06-06, LIMIT SELL CREATE 2116 shares at 221.4431498437825
# 2000-06-07, Current Portfolio Value : 108993.0
# 2000-06-07, LIMIT SELL CREATE 2116 shares at 219.41739200521707
# 2000-06-08, Current Portfolio Value : 107935.0
# 2000-06-08, LIMIT SELL CREATE 2116 shares at 219.42746489372328
# 2000-06-09, Current Portfolio Value : 111109.0
# 2000-06-09, LIMIT SELL CREATE 2116 shares at 220.4353073687529
# 2000-06-12, Current Portfolio Value : 114018.5
# 2000-06-12, LIMIT SELL CREATE 2116 shares at 222.97507471179517
# 2000-06-13, Current Portfolio Value : 117853.75
# 2000-06-13, LIMIT SELL CREATE 2116 shares at 223.8014975445224
# 2000-06-14, Current Portfolio Value : 118647.25
# 2000-06-14, LIMIT SELL CREATE 2116 shares at 225.3031883685606
# 2000-06-15, Current Portfolio Value : 124796.875
# 2000-06-15, LIMIT SELL CREATE 2116 shares at 223.8115858114844
# 2000-06-16, Current Portfolio Value : 126979.0
# 2000-06-16, LIMIT SELL CREATE 2116 shares at 224.8597352189947
# 2000-06-19, Current Portfolio Value : 128103.125
# 2000-06-19, LIMIT SELL CREATE 2116 shares at 223.09601088769287
# 2000-06-20, Current Portfolio Value : 131144.875
# 2000-06-20, LIMIT SELL CREATE 2116 shares at 226.71416168221975
# 2000-06-21, Current Portfolio Value : 132269.0
# 2000-06-21, LIMIT SELL CREATE 2116 shares at 225.4543585884328
# 2000-06-22, Current Portfolio Value : 126714.5
# 2000-06-22, LIMIT SELL CREATE 2116 shares at 228.07475517489203
# 2000-06-23, Current Portfolio Value : 119573.0
# 2000-06-23, LIMIT SELL CREATE 2116 shares at 228.4073450370665
# 2000-06-26, Current Portfolio Value : 132798.0
# 2000-06-26, LIMIT SELL CREATE 2116 shares at 229.7175279518404
# 2000-06-27, Current Portfolio Value : 126251.625
# 2000-06-27, LIMIT SELL CREATE 2116 shares at 230.7656927378064
# 2000-06-28, Current Portfolio Value : 132269.0
# 2000-06-28, LIMIT SELL CREATE 2116 shares at 235.52271045022263
# 2000-06-29, Current Portfolio Value : 137030.0
# 2000-06-29, LIMIT SELL CREATE 2116 shares at 235.9460024443204
# 2000-06-30, Current Portfolio Value : 132120.21875
# 2000-06-30, LIMIT SELL CREATE 2116 shares at 235.85530031239708
# 2000-07-03, Current Portfolio Value : 137162.25
# 2000-07-03, LIMIT SELL CREATE 2116 shares at 233.1139675500401
# 2000-07-05, Current Portfolio Value : 147874.5
# 2000-07-05, LIMIT SELL CREATE 2116 shares at 230.79592678178085
# 2000-07-06, Current Portfolio Value : 133856.0
# 2000-07-06, LIMIT SELL CREATE 2116 shares at 233.68842976401
# 2000-07-07, Current Portfolio Value : 138088.0
# 2000-07-07, LIMIT SELL CREATE 2116 shares at 235.10949134463112
# 2000-07-10, Current Portfolio Value : 147081.0
# 2000-07-10, LIMIT SELL CREATE 2116 shares at 234.81722379339308
# 2000-07-11, Current Portfolio Value : 147081.0
# 2000-07-11, LIMIT SELL CREATE 2116 shares at 234.9179988138226
# 2000-07-12, Current Portfolio Value : 155478.875
# 2000-07-12, LIMIT SELL CREATE 2116 shares at 235.08933018916292
# 2000-07-13, Current Portfolio Value : 144700.5
# 2000-07-13, LIMIT SELL CREATE 2116 shares at 235.5932514266777
# 2000-07-14, Current Portfolio Value : 139675.0
# 2000-07-14, LIMIT SELL CREATE 2116 shares at 235.01878921270784
# 2000-07-17, Current Portfolio Value : 151974.25
# 2000-07-17, LIMIT SELL CREATE 2116 shares at 235.48238813928623
# 2000-07-18, Current Portfolio Value : 141791.0
# 2000-07-18, LIMIT SELL CREATE 2116 shares at 236.90344971990731
# 2000-07-19, Current Portfolio Value : 136170.375
# 2000-07-19, LIMIT SELL CREATE 2116 shares at 232.82168462034636
# 2000-07-20, Current Portfolio Value : 138815.375
# 2000-07-20, LIMIT SELL CREATE 2116 shares at 230.67499060588312
# 2000-07-21, Current Portfolio Value : 135178.5
# 2000-07-21, LIMIT SELL CREATE 2116 shares at 233.79929305140143
# 2000-07-24, Current Portfolio Value : 135575.25
# 2000-07-24, LIMIT SELL CREATE 2116 shares at 228.12515037433465
# 2000-07-25, Current Portfolio Value : 129293.375
# 2000-07-25, LIMIT SELL CREATE 2116 shares at 230.5943613624661
# 2000-07-26, Current Portfolio Value : 138220.25
# 2000-07-26, LIMIT SELL CREATE 2116 shares at 232.69067555594236
# 2000-07-27, Current Portfolio Value : 132136.75
# 2000-07-27, LIMIT SELL CREATE 2116 shares at 230.61452251793423
# 2000-07-28, Current Portfolio Value : 126714.5
# 2000-07-28, LIMIT SELL CREATE 2116 shares at 233.90008345028676
# 2000-07-31, Current Portfolio Value : 125524.25
# 2000-07-31, LIMIT SELL CREATE 2116 shares at 236.19796306307785
# 2000-08-01, Current Portfolio Value : 142584.5
# 2000-08-01, LIMIT SELL CREATE 2116 shares at 239.47345110692405
# 2000-08-02, Current Portfolio Value : 137625.125
# 2000-08-02, LIMIT SELL CREATE 2116 shares at 241.47906316847696
# 2000-08-03, Current Portfolio Value : 140038.6875
# 2000-08-03, LIMIT SELL CREATE 2116 shares at 245.5809740450505
# 2000-08-04, Current Portfolio Value : 142782.875
# 2000-08-04, LIMIT SELL CREATE 2116 shares at 246.00426603914832
# 2000-08-07, Current Portfolio Value : 140600.75
# 2000-08-07, LIMIT SELL CREATE 2116 shares at 243.82732260225492
# 2000-08-08, Current Portfolio Value : 141262.0
# 2000-08-08, LIMIT SELL CREATE 2116 shares at 239.39282186350692
# 2000-08-09, Current Portfolio Value : 141493.4375
# 2000-08-09, LIMIT SELL CREATE 2116 shares at 234.1923510015248
# 2000-08-10, Current Portfolio Value : 143378.0
# 2000-08-10, LIMIT SELL CREATE 2116 shares at 237.70972677562224
# 2000-08-11, Current Portfolio Value : 149593.75
# 2000-08-11, LIMIT SELL CREATE 2116 shares at 235.84521204543515
# 2000-08-14, Current Portfolio Value : 154718.4375
# 2000-08-14, LIMIT SELL CREATE 2116 shares at 230.60443425097228
# 2000-08-15, Current Portfolio Value : 151842.0
# 2000-08-15, LIMIT SELL CREATE 2116 shares at 225.54506072035605
# 2000-08-16, Current Portfolio Value : 148767.1875
# 2000-08-16, LIMIT SELL CREATE 2116 shares at 227.82279455613465
# 2000-08-17, Current Portfolio Value : 151709.75
# 2000-08-17, LIMIT SELL CREATE 2116 shares at 220.7981312749018
# 2000-08-18, Current Portfolio Value : 150585.625
# 2000-08-18, LIMIT SELL CREATE 2116 shares at 222.4711534742804
# 2000-08-21, Current Portfolio Value : 155545.0
# 2000-08-21, LIMIT SELL CREATE 2116 shares at 221.81604663843763
# 2000-08-22, Current Portfolio Value : 158818.1875
# 2000-08-22, LIMIT SELL CREATE 2116 shares at 219.0646409875744
# 2000-08-23, Current Portfolio Value : 156768.3125
# 2000-08-23, LIMIT SELL CREATE 2116 shares at 220.8485264743444
# 2000-08-24, Current Portfolio Value : 159248.0
# 2000-08-24, LIMIT SELL CREATE 2116 shares at 224.97059850638612
# 2000-08-25, Current Portfolio Value : 165992.75
# 2000-08-25, LIMIT SELL CREATE 2116 shares at 226.1296112012879
# 2000-08-28, Current Portfolio Value : 177234.0
# 2000-08-28, LIMIT SELL CREATE 2116 shares at 222.3098949874462
# 2000-08-29, Current Portfolio Value : 167513.625
# 2000-08-29, LIMIT SELL CREATE 2116 shares at 217.75444269434476
# 2000-08-30, Current Portfolio Value : 164273.5
# 2000-08-30, LIMIT SELL CREATE 2116 shares at 218.19789584391071
# 2000-08-31, Current Portfolio Value : 168373.25
# 2000-08-31, LIMIT SELL CREATE 2116 shares at 218.34906606378289
# 2000-09-01, Current Portfolio Value : 171415.0
# 2000-09-01, LIMIT SELL CREATE 2116 shares at 219.04447983210625
# 2000-09-05, Current Portfolio Value : 165067.0
# 2000-09-05, LIMIT SELL CREATE 2116 shares at 218.076959668013
# 2000-09-06, Current Portfolio Value : 162951.0
# 2000-09-06, LIMIT SELL CREATE 2116 shares at 211.71747611112903
# 2000-09-07, Current Portfolio Value : 163480.0
# 2000-09-07, LIMIT SELL CREATE 2116 shares at 204.96491922566608
# 2000-09-08, Current Portfolio Value : 162289.75
# 2000-09-08, LIMIT SELL CREATE 2116 shares at 204.1888915923814
# 2000-09-11, Current Portfolio Value : 163083.25
# 2000-09-11, LIMIT SELL CREATE 2116 shares at 200.37924826704597
# 2000-09-12, Current Portfolio Value : 153693.5
# 2000-09-12, LIMIT SELL CREATE 2116 shares at 196.4184193433826
# 2000-09-13, Current Portfolio Value : 155016.0
# 2000-09-13, LIMIT SELL CREATE 2116 shares at 204.28966661281092
# 2000-09-14, Current Portfolio Value : 160041.5
# 2000-09-14, LIMIT SELL CREATE 2116 shares at 203.0500246744921
# 2000-09-15, Current Portfolio Value : 161893.0
# 2000-09-15, LIMIT SELL CREATE 2116 shares at 210.07468795572493
# 2000-09-18, Current Portfolio Value : 161893.0
# 2000-09-18, LIMIT SELL CREATE 2116 shares at 200.48002328747543
# 2000-09-19, Current Portfolio Value : 157661.0
# 2000-09-19, LIMIT SELL CREATE 2116 shares at 201.56849500592213
# 2000-09-20, Current Portfolio Value : 159777.0
# 2000-09-20, LIMIT SELL CREATE 2116 shares at 192.08469362506412
# 2000-09-21, Current Portfolio Value : 169563.5
# 2000-09-21, LIMIT SELL CREATE 2116 shares at 198.26277291810143
# 2000-09-22, Current Portfolio Value : 170158.625
# 2000-09-22, LIMIT SELL CREATE 2116 shares at 185.5438058043336
# 2000-09-25, Current Portfolio Value : 183053.0
# 2000-09-25, LIMIT SELL CREATE 2116 shares at 168.3600885293876
# 2000-09-26, Current Portfolio Value : 171415.0
# 2000-09-26, LIMIT SELL CREATE 2116 shares at 185.92677548749492
# 2000-09-27, Current Portfolio Value : 173795.5
# 2000-09-27, LIMIT SELL CREATE 2116 shares at 175.2839614117352
# 2000-09-28, Current Portfolio Value : 191252.5
# 2000-09-28, LIMIT SELL CREATE 2116 shares at 184.7072947046443
# 2000-09-29, Current Portfolio Value : 188343.0
# 2000-09-29, LIMIT SELL CREATE 2116 shares at 178.19662554943255
# 2000-10-02, Current Portfolio Value : 187285.0
# 2000-10-02, LIMIT SELL CREATE 2116 shares at 178.81141007433882
# 2000-10-03, Current Portfolio Value : 184375.5
# 2000-10-03, LIMIT SELL CREATE 2116 shares at 174.82036248515678
# 2000-10-04, Current Portfolio Value : 159777.0
# 2000-10-04, LIMIT SELL CREATE 2116 shares at 163.63330486094583
# 2000-10-05, Current Portfolio Value : 151313.0
# 2000-10-05, LIMIT SELL CREATE 2116 shares at 182.0969710066913
# 2000-10-06, Current Portfolio Value : 154487.0
# 2000-10-06, LIMIT SELL CREATE 2116 shares at 178.1865526609263
# 2000-10-09, Current Portfolio Value : 150784.0
# 2000-10-09, LIMIT SELL CREATE 2116 shares at 192.92120472475335
# 2000-10-10, Current Portfolio Value : 150651.75
# 2000-10-10, LIMIT SELL CREATE 2116 shares at 186.8136817866269
# 2000-10-11, Current Portfolio Value : 148668.0
# 2000-10-11, LIMIT SELL CREATE 2116 shares at 189.6154826369327
# 2000-10-12, Current Portfolio Value : 145494.0
# 2000-10-12, LIMIT SELL CREATE 2116 shares at 183.47772565483177
# 2000-10-13, Current Portfolio Value : 148403.5
# 2000-10-13, LIMIT SELL CREATE 2116 shares at 183.73975916209537
# 2000-10-16, Current Portfolio Value : 153693.5
# 2000-10-16, LIMIT SELL CREATE 2116 shares at 187.488934399482
# 2000-10-17, Current Portfolio Value : 163480.0
# 2000-10-17, LIMIT SELL CREATE 2116 shares at 181.35117741738105
# 2000-10-18, Current Portfolio Value : 162025.25
# 2000-10-18, LIMIT SELL CREATE 2116 shares at 190.3713644932049
# 2000-10-19, Current Portfolio Value : 154487.0
# 2000-10-19, LIMIT SELL CREATE 2116 shares at 191.5706994990431
# 2000-10-20, Current Portfolio Value : 140336.25
# 2000-10-20, LIMIT SELL CREATE 2116 shares at 197.61775434922075
# 2000-10-23, Current Portfolio Value : 147610.0
# 2000-10-23, LIMIT SELL CREATE 2116 shares at 197.4665687508929
# 2000-10-24, Current Portfolio Value : 152635.5
# 2000-10-24, LIMIT SELL CREATE 2116 shares at 189.12163428792417
# 2000-10-25, Current Portfolio Value : 142187.75
# 2000-10-25, LIMIT SELL CREATE 2116 shares at 195.16868913810185
# 2000-10-26, Current Portfolio Value : 139013.75
# 2000-10-26, LIMIT SELL CREATE 2116 shares at 190.8954468861879
# 2000-10-27, Current Portfolio Value : 136501.0
# 2000-10-27, LIMIT SELL CREATE 2116 shares at 194.4732907482342
# 2000-10-30, Current Portfolio Value : 139939.5
# 2000-10-30, LIMIT SELL CREATE 2116 shares at 199.0589617068544
# 2000-10-31, Current Portfolio Value : 153561.25
# 2000-10-31, LIMIT SELL CREATE 2116 shares at 195.8540300179189
# 2000-11-01, Current Portfolio Value : 145097.25
# 2000-11-01, LIMIT SELL CREATE 2116 shares at 186.8439158306013
# 2000-11-02, Current Portfolio Value : 149726.0
# 2000-11-02, LIMIT SELL CREATE 2116 shares at 191.83273300630677
# 2000-11-03, Current Portfolio Value : 157528.75
# 2000-11-03, LIMIT SELL CREATE 2116 shares at 192.2661132673664
# 2000-11-06, Current Portfolio Value : 157925.5
# 2000-11-06, LIMIT SELL CREATE 2116 shares at 192.82042970432383
# 2000-11-07, Current Portfolio Value : 156206.25
# 2000-11-07, LIMIT SELL CREATE 2116 shares at 196.53935551928035
# 2000-11-08, Current Portfolio Value : 151842.0
# 2000-11-08, LIMIT SELL CREATE 2116 shares at 185.55387869283987
# 2000-11-09, Current Portfolio Value : 150255.0
# 2000-11-09, LIMIT SELL CREATE 2116 shares at 194.16084666307225
# 2000-11-10, Current Portfolio Value : 140997.5
# 2000-11-10, LIMIT SELL CREATE 2116 shares at 188.4665428305372
# 2000-11-13, Current Portfolio Value : 132665.75
# 2000-11-13, LIMIT SELL CREATE 2116 shares at 179.47658979868777
# 2000-11-14, Current Portfolio Value : 138220.25
# 2000-11-14, LIMIT SELL CREATE 2116 shares at 181.8450103879339
# 2000-11-15, Current Portfolio Value : 148139.0
# 2000-11-15, LIMIT SELL CREATE 2116 shares at 183.31646716799764
# 2000-11-16, Current Portfolio Value : 144039.25
# 2000-11-16, LIMIT SELL CREATE 2116 shares at 186.4810919244524
# 2000-11-17, Current Portfolio Value : 146023.0
# 2000-11-17, LIMIT SELL CREATE 2116 shares at 187.43853920003932
# 2000-11-20, Current Portfolio Value : 143113.5
# 2000-11-20, LIMIT SELL CREATE 2116 shares at 188.44638167506895
# 2000-11-21, Current Portfolio Value : 149197.0
# 2000-11-21, LIMIT SELL CREATE 2116 shares at 190.79465648730263
# 2000-11-22, Current Portfolio Value : 151313.0
# 2000-11-22, LIMIT SELL CREATE 2116 shares at 183.9110905374357
# 2000-11-24, Current Portfolio Value : 154883.75
# 2000-11-24, LIMIT SELL CREATE 2116 shares at 180.20223761098552
# 2000-11-27, Current Portfolio Value : 159777.0
# 2000-11-27, LIMIT SELL CREATE 2116 shares at 181.6938401680617
# 2000-11-28, Current Portfolio Value : 152900.0
# 2000-11-28, LIMIT SELL CREATE 2116 shares at 179.85957486030483
# 2000-11-29, Current Portfolio Value : 148139.0
# 2000-11-29, LIMIT SELL CREATE 2116 shares at 189.716273035818
# 2000-11-30, Current Portfolio Value : 136104.25
# 2000-11-30, LIMIT SELL CREATE 2116 shares at 185.43294251694212
# 2000-12-01, Current Portfolio Value : 141526.5
# 2000-12-01, LIMIT SELL CREATE 2116 shares at 186.71289138774165
# 2000-12-04, Current Portfolio Value : 146155.25
# 2000-12-04, LIMIT SELL CREATE 2116 shares at 186.71289138774165
# 2000-12-05, Current Portfolio Value : 154354.75
# 2000-12-05, LIMIT SELL CREATE 2116 shares at 188.14402585686895
# 2000-12-06, Current Portfolio Value : 152371.0
# 2000-12-06, LIMIT SELL CREATE 2116 shares at 194.5942269241319
# 2000-12-07, Current Portfolio Value : 152503.25
# 2000-12-07, LIMIT SELL CREATE 2116 shares at 200.44978924350104
# 2000-12-08, Current Portfolio Value : 165067.0
# 2000-12-08, LIMIT SELL CREATE 2116 shares at 199.51250312338223
# 2000-12-11, Current Portfolio Value : 169299.0
# 2000-12-11, LIMIT SELL CREATE 2116 shares at 201.41732478605
# 2000-12-12, Current Portfolio Value : 172605.25
# 2000-12-12, LIMIT SELL CREATE 2116 shares at 201.2359051437477
# 2000-12-13, Current Portfolio Value : 173398.75
# 2000-12-13, LIMIT SELL CREATE 2116 shares at 204.43076394417687
# 2000-12-14, Current Portfolio Value : 167844.25
# 2000-12-14, LIMIT SELL CREATE 2116 shares at 203.00970236355573
# 2000-12-15, Current Portfolio Value : 169431.25
# 2000-12-15, LIMIT SELL CREATE 2116 shares at 203.97723790610468
# 2000-12-18, Current Portfolio Value : 167050.75
# 2000-12-18, LIMIT SELL CREATE 2116 shares at 210.5685209262778
# 2000-12-19, Current Portfolio Value : 172605.25
# 2000-12-19, LIMIT SELL CREATE 2116 shares at 209.852961380942
# 2000-12-20, Current Portfolio Value : 166918.5
# 2000-12-20, LIMIT SELL CREATE 2116 shares at 198.9279526424504
# 2000-12-21, Current Portfolio Value : 153958.0
# 2000-12-21, LIMIT SELL CREATE 2116 shares at 196.0858294812081
# 2000-12-22, Current Portfolio Value : 161099.5
# 2000-12-22, LIMIT SELL CREATE 2116 shares at 182.97380441731696
# 2000-12-26, Current Portfolio Value : 164009.0
# 2000-12-26, LIMIT SELL CREATE 2116 shares at 187.0152472059416
# 2000-12-27, Current Portfolio Value : 169166.75
# 2000-12-27, LIMIT SELL CREATE 2116 shares at 189.5953214814645
# 2000-12-28, Current Portfolio Value : 175250.25
# 2000-12-28, LIMIT SELL CREATE 2116 shares at 190.8954468861879
# 2000-12-29, Current Portfolio Value : 176705.0
# 2000-12-29, LIMIT SELL CREATE 2116 shares at 189.9783065430816
# 2001-01-02, Current Portfolio Value : 166918.5
# 2001-01-02, LIMIT SELL CREATE 2116 shares at 195.1183093171149
# 2001-01-03, Current Portfolio Value : 157661.0
# 2001-01-03, LIMIT SELL CREATE 2116 shares at 191.8629670502812
# 2001-01-04, Current Portfolio Value : 148139.0
# 2001-01-04, LIMIT SELL CREATE 2116 shares at 187.0051743174354
# 2001-01-05, Current Portfolio Value : 140997.5
# 2001-01-05, LIMIT SELL CREATE 2116 shares at 187.0253354729036
# 2001-01-08, Current Portfolio Value : 136236.5
# 2001-01-08, LIMIT SELL CREATE 2116 shares at 178.75094198639
# 2001-01-09, Current Portfolio Value : 139410.5
# 2001-01-09, LIMIT SELL CREATE 2116 shares at 177.5415340920456
# 2001-01-10, Current Portfolio Value : 146684.25
# 2001-01-10, LIMIT SELL CREATE 2116 shares at 176.1305453999307
# 2001-01-11, Current Portfolio Value : 147081.0
# 2001-01-11, LIMIT SELL CREATE 2116 shares at 178.005133018624
# 2001-01-12, Current Portfolio Value : 148006.75
# 2001-01-12, LIMIT SELL CREATE 2116 shares at 181.8147763439595
# 2001-01-16, Current Portfolio Value : 146419.75
# 2001-01-16, LIMIT SELL CREATE 2116 shares at 181.56281572520209
# 2001-01-17, Current Portfolio Value : 143113.5
# 2001-01-17, LIMIT SELL CREATE 2116 shares at 182.23808371651296
# 2001-01-18, Current Portfolio Value : 132533.5
# 2001-01-18, LIMIT SELL CREATE 2116 shares at 185.80583931159728
# 2001-01-19, Current Portfolio Value : 126979.0
# 2001-01-19, LIMIT SELL CREATE 2116 shares at 186.79352063115869
# 2001-01-22, Current Portfolio Value : 135310.75
# 2001-01-22, LIMIT SELL CREATE 2116 shares at 186.5012530799206
# 2001-01-23, Current Portfolio Value : 145758.5
# 2001-01-23, LIMIT SELL CREATE 2116 shares at 190.10933098594128
# 2001-01-24, Current Portfolio Value : 150122.75
# 2001-01-24, LIMIT SELL CREATE 2116 shares at 190.230267161839
# 2001-01-25, Current Portfolio Value : 147345.5
# 2001-01-25, LIMIT SELL CREATE 2116 shares at 194.7857194549404
# 2001-01-26, Current Portfolio Value : 146155.25
# 2001-01-26, LIMIT SELL CREATE 2116 shares at 199.6233664107737
# 2001-01-29, Current Portfolio Value : 153429.0
# 2001-01-29, LIMIT SELL CREATE 2116 shares at 222.5316215622292
# 2001-01-30, Current Portfolio Value : 150360.80645751953
# 2001-01-30, LIMIT SELL CREATE 2116 shares at 225.79702133911343
# 2001-01-31, Current Portfolio Value : 155608.4774169922
# 2001-01-31, LIMIT SELL CREATE 2116 shares at 228.66937854433013
# 2001-02-01, Current Portfolio Value : 147885.07418823242
# 2001-02-01, LIMIT SELL CREATE 2116 shares at 228.84070991967045
# 2001-02-02, Current Portfolio Value : 150381.95483398438
# 2001-02-02, LIMIT SELL CREATE 2116 shares at 224.5674676677566
# 2001-02-05, Current Portfolio Value : 147292.59677124023
# 2001-02-05, LIMIT SELL CREATE 2116 shares at 225.5954559197987
# 2001-02-06, Current Portfolio Value : 153640.59677124023
# 2001-02-06, LIMIT SELL CREATE 2116 shares at 228.1553844183091
# 2001-02-07, Current Portfolio Value : 157639.83547973633
# 2001-02-07, LIMIT SELL CREATE 2116 shares at 224.7992671310458
# 2001-02-08, Current Portfolio Value : 152117.07418823242
# 2001-02-08, LIMIT SELL CREATE 2116 shares at 229.2337678697938
# 2001-02-09, Current Portfolio Value : 148139.0
# 2001-02-09, LIMIT SELL CREATE 2116 shares at 225.2427202806118
# 2001-02-12, Current Portfolio Value : 151207.19354248047
# 2001-02-12, LIMIT SELL CREATE 2116 shares at 218.2180569993789
# 2001-02-13, Current Portfolio Value : 150889.80645751953
# 2001-02-13, LIMIT SELL CREATE 2116 shares at 214.42855945105592
# 2001-02-14, Current Portfolio Value : 149979.92581176758
# 2001-02-14, LIMIT SELL CREATE 2116 shares at 214.82161740117925
# 2001-02-15, Current Portfolio Value : 152265.19354248047
# 2001-02-15, LIMIT SELL CREATE 2116 shares at 214.7208423807497
# 2001-02-16, Current Portfolio Value : 151270.68710327148
# 2001-02-16, LIMIT SELL CREATE 2116 shares at 211.74771015510348
# 2001-02-20, Current Portfolio Value : 148456.40322875977
# 2001-02-20, LIMIT SELL CREATE 2116 shares at 212.83616649509443
# 2001-02-21, Current Portfolio Value : 145599.80645751953
# 2001-02-21, LIMIT SELL CREATE 2116 shares at 212.29193832509893
# 2001-02-22, Current Portfolio Value : 139040.19354248047
# 2001-02-22, LIMIT SELL CREATE 2116 shares at 214.0052674569582
# 2001-02-23, Current Portfolio Value : 141431.28387451172
# 2001-02-23, LIMIT SELL CREATE 2116 shares at 214.378179630069
# 2001-02-26, Current Portfolio Value : 143907.0
# 2001-02-26, LIMIT SELL CREATE 2116 shares at 215.3154657501878
# 2001-02-27, Current Portfolio Value : 142214.19354248047
# 2001-02-27, LIMIT SELL CREATE 2116 shares at 216.89778581764304
# 2001-02-28, Current Portfolio Value : 139378.7612915039
# 2001-02-28, LIMIT SELL CREATE 2116 shares at 218.7018170814255
# 2001-03-01, Current Portfolio Value : 134808.20161437988
# 2001-03-01, LIMIT SELL CREATE 2116 shares at 217.08926296999587
# 2001-03-02, Current Portfolio Value : 134490.79838562012
# 2001-03-02, LIMIT SELL CREATE 2116 shares at 217.37145763272767
# 2001-03-05, Current Portfolio Value : 133327.0
# 2001-03-05, LIMIT SELL CREATE 2116 shares at 216.74660021931516
# 2001-03-06, Current Portfolio Value : 130787.79838562012
# 2001-03-06, LIMIT SELL CREATE 2116 shares at 218.65142188198288
# 2001-03-07, Current Portfolio Value : 125455.4774169922
# 2001-03-07, LIMIT SELL CREATE 2116 shares at 216.41401035714065
# 2001-03-08, Current Portfolio Value : 126428.84355163574
# 2001-03-08, LIMIT SELL CREATE 2116 shares at 217.9358623366471
# 2001-03-09, Current Portfolio Value : 124228.20161437988
# 2001-03-09, LIMIT SELL CREATE 2116 shares at 216.70629328683447
# 2001-03-12, Current Portfolio Value : 104761.0
# 2001-03-12, LIMIT SELL CREATE 2116 shares at 217.83507193776185
# 2001-03-13, Current Portfolio Value : 107723.40322875977
# 2001-03-13, LIMIT SELL CREATE 2116 shares at 217.78467673831923
# 2001-03-14, Current Portfolio Value : 104761.0
# 2001-03-14, LIMIT SELL CREATE 2116 shares at 217.4520868761448
# 2001-03-15, Current Portfolio Value : 105184.20161437988
# 2001-03-15, LIMIT SELL CREATE 2116 shares at 219.1351819640295
# 2001-03-16, Current Portfolio Value : 99153.59677124022
# 2001-03-16, LIMIT SELL CREATE 2116 shares at 217.9560081136596
# 2001-03-19, Current Portfolio Value : 100529.0
# 2001-03-19, LIMIT SELL CREATE 2116 shares at 213.6827658617456
# 2001-03-20, Current Portfolio Value : 91641.79838562012
# 2001-03-20, LIMIT SELL CREATE 2116 shares at 218.77237343633635
# 2001-03-21, Current Portfolio Value : 94181.0
# 2001-03-21, LIMIT SELL CREATE 2116 shares at 210.6290043926824
# 2001-03-22, Current Portfolio Value : 76195.0
# 2001-03-22, LIMIT SELL CREATE 2116 shares at 207.6861062110106
# 2001-03-23, Current Portfolio Value : 85188.0
# 2001-03-23, LIMIT SELL CREATE 2116 shares at 205.97276170069568
# 2001-03-26, Current Portfolio Value : 88383.15644836426
# 2001-03-26, LIMIT SELL CREATE 2116 shares at 207.85743758635095
# 2001-03-27, Current Portfolio Value : 90393.35806274414
# 2001-03-27, LIMIT SELL CREATE 2116 shares at 205.630098950015
# 2001-03-28, Current Portfolio Value : 91620.64193725586
# 2001-03-28, LIMIT SELL CREATE 2116 shares at 205.52930855112976
# 2001-03-29, Current Portfolio Value : 94392.59677124022
# 2001-03-29, LIMIT SELL CREATE 2116 shares at 206.889902043802
# 2001-03-30, Current Portfolio Value : 98307.20161437988
# 2001-03-30, LIMIT SELL CREATE 2116 shares at 207.2224919059765
# 2001-04-02, Current Portfolio Value : 90753.08226013184
# 2001-04-02, LIMIT SELL CREATE 2116 shares at 208.21017322553791
# 2001-04-03, Current Portfolio Value : 86775.0
# 2001-04-03, LIMIT SELL CREATE 2116 shares at 205.3982994867258
# 2001-04-04, Current Portfolio Value : 83410.55967712402
# 2001-04-04, LIMIT SELL CREATE 2116 shares at 197.00296982431445
# 2001-04-05, Current Portfolio Value : 90478.0
# 2001-04-05, LIMIT SELL CREATE 2116 shares at 195.8842640618934
# 2001-04-06, Current Portfolio Value : 90795.40322875977
# 2001-04-06, LIMIT SELL CREATE 2116 shares at 195.75323961903365
# 2001-04-09, Current Portfolio Value : 92445.88064575195
# 2001-04-09, LIMIT SELL CREATE 2116 shares at 192.09478189202605
# 2001-04-10, Current Portfolio Value : 81485.0
# 2001-04-10, LIMIT SELL CREATE 2116 shares at 191.12724634947716
# 2001-04-11, Current Portfolio Value : 78543.7612915039
# 2001-04-11, LIMIT SELL CREATE 2116 shares at 192.5583808186045
# 2001-04-12, Current Portfolio Value : 81802.40322875977
# 2001-04-12, LIMIT SELL CREATE 2116 shares at 194.8058652319529
# 2001-04-16, Current Portfolio Value : 78628.40322875977
# 2001-04-16, LIMIT SELL CREATE 2116 shares at 194.90665563083817
# 2001-04-17, Current Portfolio Value : 87409.79838562012
# 2001-04-17, LIMIT SELL CREATE 2116 shares at 197.21460813213545
# 2001-04-18, Current Portfolio Value : 99471.0
# 2001-04-18, LIMIT SELL CREATE 2116 shares at 197.21460813213545
# 2001-04-19, Current Portfolio Value : 100529.0
# 2001-04-19, LIMIT SELL CREATE 2116 shares at 197.4262618184122
# 2001-04-20, Current Portfolio Value : 98095.59677124022
# 2001-04-20, LIMIT SELL CREATE 2116 shares at 200.20790151324988
# 2001-04-23, Current Portfolio Value : 96402.79838562012
# 2001-04-23, LIMIT SELL CREATE 2116 shares at 198.2224506071651
# 2001-04-24, Current Portfolio Value : 93609.67903137207
# 2001-04-24, LIMIT SELL CREATE 2116 shares at 201.65919713784544
# 2001-04-25, Current Portfolio Value : 94117.52258300781
# 2001-04-25, LIMIT SELL CREATE 2116 shares at 202.76783001176028
# 2001-04-26, Current Portfolio Value : 96720.20161437988
# 2001-04-26, LIMIT SELL CREATE 2116 shares at 204.39045701169616
# 2001-04-27, Current Portfolio Value : 104443.59677124022
# 2001-04-27, LIMIT SELL CREATE 2116 shares at 203.71520439884105
# 2001-04-30, Current Portfolio Value : 110474.20161437988
# 2001-04-30, LIMIT SELL CREATE 2116 shares at 218.14750064446807
# 2001-05-01, Current Portfolio Value : 117837.88064575195
# 2001-05-01, LIMIT SELL CREATE 2116 shares at 213.854097237086
# 2001-05-02, Current Portfolio Value : 119382.55967712402
# 2001-05-02, LIMIT SELL CREATE 2116 shares at 215.37593383813663
# 2001-05-03, Current Portfolio Value : 117668.59677124022
# 2001-05-03, LIMIT SELL CREATE 2116 shares at 212.75555263013308
# 2001-05-04, Current Portfolio Value : 113225.0
# 2001-05-04, LIMIT SELL CREATE 2116 shares at 211.51589531335856
# 2001-05-07, Current Portfolio Value : 114177.20161437988
# 2001-05-07, LIMIT SELL CREATE 2116 shares at 214.7510764247241
# 2001-05-08, Current Portfolio Value : 110897.40322875977
# 2001-05-08, LIMIT SELL CREATE 2116 shares at 216.58534173248103
# 2001-05-09, Current Portfolio Value : 109839.40322875977
# 2001-05-09, LIMIT SELL CREATE 2116 shares at 223.72086830110533
# 2001-05-10, Current Portfolio Value : 108887.20161437988
# 2001-05-10, LIMIT SELL CREATE 2116 shares at 223.6906342571309
# 2001-05-11, Current Portfolio Value : 109627.79838562012
# 2001-05-11, LIMIT SELL CREATE 2116 shares at 222.0377732132206
# 2001-05-14, Current Portfolio Value : 107236.71612548828
# 2001-05-14, LIMIT SELL CREATE 2116 shares at 225.7164074741521
# 2001-05-15, Current Portfolio Value : 107786.88064575195
# 2001-05-15, LIMIT SELL CREATE 2116 shares at 226.5327574183732
# 2001-05-16, Current Portfolio Value : 108993.0
# 2001-05-16, LIMIT SELL CREATE 2116 shares at 227.34910736259425
# 2001-05-17, Current Portfolio Value : 115996.96290588379
# 2001-05-17, LIMIT SELL CREATE 2116 shares at 224.5674676677566
# 2001-05-18, Current Portfolio Value : 111849.59677124022
# 2001-05-18, LIMIT SELL CREATE 2116 shares at 223.96275603135652
# 2001-05-21, Current Portfolio Value : 118197.59677124022
# 2001-05-21, LIMIT SELL CREATE 2116 shares at 218.8328415242852
# 2001-05-22, Current Portfolio Value : 118620.79838562012
# 2001-05-22, LIMIT SELL CREATE 2116 shares at 214.7410035362179
# 2001-05-23, Current Portfolio Value : 112865.28387451172
# 2001-05-23, LIMIT SELL CREATE 2116 shares at 219.40730373825508
# 2001-05-24, Current Portfolio Value : 115552.59677124022
# 2001-05-24, LIMIT SELL CREATE 2116 shares at 224.22478953862012
# 2001-05-25, Current Portfolio Value : 117541.64193725586
# 2001-05-25, LIMIT SELL CREATE 2116 shares at 232.2472224063764
# 2001-05-29, Current Portfolio Value : 112167.0
# 2001-05-29, LIMIT SELL CREATE 2116 shares at 227.07698558836864
# 2001-05-30, Current Portfolio Value : 106030.59677124022
# 2001-05-30, LIMIT SELL CREATE 2116 shares at 224.8899692629691
# 2001-05-31, Current Portfolio Value : 105141.88064575195
# 2001-05-31, LIMIT SELL CREATE 2116 shares at 228.34687694911764
# 2001-06-01, Current Portfolio Value : 105501.59677124022
# 2001-06-01, LIMIT SELL CREATE 2116 shares at 234.47454566425665
# 2001-06-04, Current Portfolio Value : 105628.55967712402
# 2001-06-04, LIMIT SELL CREATE 2116 shares at 233.6581957200356
# 2001-06-05, Current Portfolio Value : 107935.0
# 2001-06-05, LIMIT SELL CREATE 2116 shares at 233.0031042626486
# 2001-06-06, Current Portfolio Value : 107935.0
# 2001-06-06, LIMIT SELL CREATE 2116 shares at 226.45212817495613
# 2001-06-07, Current Portfolio Value : 107088.59677124022
# 2001-06-07, LIMIT SELL CREATE 2116 shares at 228.12515037433465
# 2001-06-08, Current Portfolio Value : 105395.79838562012
# 2001-06-08, LIMIT SELL CREATE 2116 shares at 227.167687720292
# 2001-06-11, Current Portfolio Value : 98624.59677124022
# 2001-06-11, LIMIT SELL CREATE 2116 shares at 230.28193265575985
# 2001-06-12, Current Portfolio Value : 91324.40322875977
# 2001-06-12, LIMIT SELL CREATE 2116 shares at 234.07141482562707
# 2001-06-13, Current Portfolio Value : 92996.0370941162
# 2001-06-13, LIMIT SELL CREATE 2116 shares at 228.518208324458
# 2001-06-14, Current Portfolio Value : 89610.44032287598
# 2001-06-14, LIMIT SELL CREATE 2116 shares at 230.0602060809768
# 2001-06-15, Current Portfolio Value : 91409.0370941162
# 2001-06-15, LIMIT SELL CREATE 2116 shares at 233.82952709537597
# 2001-06-18, Current Portfolio Value : 90097.11935424805
# 2001-06-18, LIMIT SELL CREATE 2116 shares at 236.02663168773745
# 2001-06-19, Current Portfolio Value : 63393.20161437988
# 2001-06-19, LIMIT SELL CREATE 2116 shares at 236.96391780785623
# 2001-06-20, Current Portfolio Value : 58420.60080718994
# 2001-06-20, LIMIT SELL CREATE 2116 shares at 234.4140775763078
# 2001-06-21, Current Portfolio Value : 62017.79838562012
# 2001-06-21, LIMIT SELL CREATE 2116 shares at 239.60447554978373
# 2001-06-22, Current Portfolio Value : 61700.399192810066
# 2001-06-22, LIMIT SELL CREATE 2116 shares at 238.34467245599672
# 2001-06-25, Current Portfolio Value : 58632.20161437988
# 2001-06-25, LIMIT SELL CREATE 2116 shares at 241.1061509953661
# 2001-06-26, Current Portfolio Value : 57341.44032287598
# 2001-06-26, LIMIT SELL CREATE 2116 shares at 241.00537597493664
# 2001-06-27, Current Portfolio Value : 57024.04113006592
# 2001-06-27, LIMIT SELL CREATE 2116 shares at 243.45442580759985
# 2001-06-28, Current Portfolio Value : 56304.60080718994
# 2001-06-28, LIMIT SELL CREATE 2116 shares at 242.214783869281
# 2001-06-29, Current Portfolio Value : 58441.7612915039
# 2001-06-29, LIMIT SELL CREATE 2116 shares at 242.6380758633788
# 2001-07-02, Current Portfolio Value : 57976.2387084961
# 2001-07-02, LIMIT SELL CREATE 2116 shares at 246.18568568145056
# 2001-07-03, Current Portfolio Value : 55881.399192810066
# 2001-07-03, LIMIT SELL CREATE 2116 shares at 244.351404995238
# 2001-07-05, Current Portfolio Value : 55585.16048431397
# 2001-07-05, LIMIT SELL CREATE 2116 shares at 252.70642772516868
# 2001-07-06, Current Portfolio Value : 53765.399192810066
# 2001-07-06, LIMIT SELL CREATE 2116 shares at 252.34360381901976
# 2001-07-09, Current Portfolio Value : 53130.60080718994
# 2001-07-09, LIMIT SELL CREATE 2116 shares at 249.3301492824372
# 2001-07-10, Current Portfolio Value : 52178.399192810066
# 2001-07-10, LIMIT SELL CREATE 2116 shares at 248.2215164085223
# 2001-07-11, Current Portfolio Value : 50506.7612915039
# 2001-07-11, LIMIT SELL CREATE 2116 shares at 248.2416775639905
# 2001-07-12, Current Portfolio Value : 49745.0
# 2001-07-12, LIMIT SELL CREATE 2116 shares at 249.0277934642372
# 2001-07-13, Current Portfolio Value : 50760.67903137207
# 2001-07-13, LIMIT SELL CREATE 2116 shares at 248.9773982647945
# 2001-07-16, Current Portfolio Value : 49893.11935424805
# 2001-07-16, LIMIT SELL CREATE 2116 shares at 247.7982244144245
# 2001-07-17, Current Portfolio Value : 50147.04113006592
# 2001-07-17, LIMIT SELL CREATE 2116 shares at 247.48579570771824
# 2001-07-18, Current Portfolio Value : 47946.399192810066
# 2001-07-18, LIMIT SELL CREATE 2116 shares at 249.3603833264116
# 2001-07-19, Current Portfolio Value : 49956.60080718994
# 2001-07-19, LIMIT SELL CREATE 2116 shares at 252.11178897727484
# 2001-07-20, Current Portfolio Value : 54294.399192810066
# 2001-07-20, LIMIT SELL CREATE 2116 shares at 257.4331960151547
# 2001-07-23, Current Portfolio Value : 53765.399192810066
# 2001-07-23, LIMIT SELL CREATE 2116 shares at 264.5284156512984
# 2001-07-24, Current Portfolio Value : 59372.79838562012
# 2001-07-24, LIMIT SELL CREATE 2116 shares at 262.8352476749073
# 2001-07-25, Current Portfolio Value : 61213.72016143799
# 2001-07-25, LIMIT SELL CREATE 2116 shares at 263.8733241939114
# 2001-07-26, Current Portfolio Value : 62377.5185470581
# 2001-07-26, LIMIT SELL CREATE 2116 shares at 268.13647817886334
# 2001-07-27, Current Portfolio Value : 65847.7612915039
# 2001-07-27, LIMIT SELL CREATE 2116 shares at 268.6001078623532
# 2001-07-30, Current Portfolio Value : 63625.95886993408
# 2001-07-30, LIMIT SELL CREATE 2116 shares at 266.8766750850764
# 2001-07-31, Current Portfolio Value : 62441.0
# 2001-07-31, LIMIT SELL CREATE 2116 shares at 264.9617805339024
# 2001-08-01, Current Portfolio Value : 62970.0
# 2001-08-01, LIMIT SELL CREATE 2116 shares at 270.4343577916544
# 2001-08-02, Current Portfolio Value : 62017.79838562012
# 2001-08-02, LIMIT SELL CREATE 2116 shares at 273.9517489442075
# 2001-08-03, Current Portfolio Value : 61594.60080718994
# 2001-08-03, LIMIT SELL CREATE 2116 shares at 273.25633517588415
# 2001-08-06, Current Portfolio Value : 59753.67903137207
# 2001-08-06, LIMIT SELL CREATE 2116 shares at 273.38735961874386
# 2001-08-07, Current Portfolio Value : 60325.0
# 2001-08-07, LIMIT SELL CREATE 2116 shares at 275.76585309649624
# 2001-08-08, Current Portfolio Value : 59901.79838562012
# 2001-08-08, LIMIT SELL CREATE 2116 shares at 275.4937467007264
# 2001-08-09, Current Portfolio Value : 58420.60080718994
# 2001-08-09, LIMIT SELL CREATE 2116 shares at 272.6516235394841
# 2001-08-10, Current Portfolio Value : 59097.72016143799
# 2001-08-10, LIMIT SELL CREATE 2116 shares at 268.04577604694003
# 2001-08-13, Current Portfolio Value : 62462.16048431397
# 2001-08-13, LIMIT SELL CREATE 2116 shares at 268.65048768334003
# 2001-08-14, Current Portfolio Value : 61933.16048431397
# 2001-08-14, LIMIT SELL CREATE 2116 shares at 266.7456813991281
# 2001-08-15, Current Portfolio Value : 61806.20161437988
# 2001-08-15, LIMIT SELL CREATE 2116 shares at 270.9181332521567
# 2001-08-16, Current Portfolio Value : 61277.20161437988
# 2001-08-16, LIMIT SELL CREATE 2116 shares at 293.5945889403229
# 2001-08-17, Current Portfolio Value : 60282.67903137207
# 2001-08-17, LIMIT SELL CREATE 2116 shares at 283.47584187909047
# 2001-08-20, Current Portfolio Value : 61383.0
# 2001-08-20, LIMIT SELL CREATE 2116 shares at 288.69648927499657
# 2001-08-21, Current Portfolio Value : 60430.79838562012
# 2001-08-21, LIMIT SELL CREATE 2116 shares at 285.70319589388214
# 2001-08-22, Current Portfolio Value : 65615.0
# 2001-08-22, LIMIT SELL CREATE 2116 shares at 286.73118414592426
# 2001-08-23, Current Portfolio Value : 68048.40322875977
# 2001-08-23, LIMIT SELL CREATE 2116 shares at 284.927137503686
# 2001-08-24, Current Portfolio Value : 71687.91773986816
# 2001-08-24, LIMIT SELL CREATE 2116 shares at 286.2474086854219
# 2001-08-27, Current Portfolio Value : 74988.88064575195
# 2001-08-27, LIMIT SELL CREATE 2116 shares at 285.0480736795837
# 2001-08-28, Current Portfolio Value : 74608.0
# 2001-08-28, LIMIT SELL CREATE 2116 shares at 286.17688308742254
# 2001-08-29, Current Portfolio Value : 73211.44032287598
# 2001-08-29, LIMIT SELL CREATE 2116 shares at 284.725587462827
# 2001-08-30, Current Portfolio Value : 72259.2387084961
# 2001-08-30, LIMIT SELL CREATE 2116 shares at 284.7961130608263
# 2001-08-31, Current Portfolio Value : 70122.08226013184
# 2001-08-31, LIMIT SELL CREATE 2116 shares at 283.00215468555007
# 2001-09-04, Current Portfolio Value : 71116.59677124023
# 2001-09-04, LIMIT SELL CREATE 2116 shares at 283.9293832956184
# 2001-09-05, Current Portfolio Value : 73021.0
# 2001-09-05, LIMIT SELL CREATE 2116 shares at 282.0044004774824
# 2001-09-06, Current Portfolio Value : 75158.15644836426
# 2001-09-06, LIMIT SELL CREATE 2116 shares at 281.06711435736366
# 2001-09-07, Current Portfolio Value : 73190.28387451172
# 2001-09-07, LIMIT SELL CREATE 2116 shares at 282.0951026094057
# 2001-09-10, Current Portfolio Value : 72174.59677124023
# 2001-09-10, LIMIT SELL CREATE 2116 shares at 280.4120228999767
# 2001-09-17, Current Portfolio Value : 70058.59677124023
# 2001-09-17, LIMIT SELL CREATE 2116 shares at 276.0279019822156
# 2001-09-18, Current Portfolio Value : 66461.39919281006
# 2001-09-18, LIMIT SELL CREATE 2116 shares at 279.2126878941385
# 2001-09-19, Current Portfolio Value : 65509.20161437988
# 2001-09-19, LIMIT SELL CREATE 2116 shares at 276.1790722020877
# 2001-09-20, Current Portfolio Value : 60388.481452941895
# 2001-09-20, LIMIT SELL CREATE 2116 shares at 267.8643717830935
# 2001-09-21, Current Portfolio Value : 59372.79838562012
# 2001-09-21, LIMIT SELL CREATE 2116 shares at 263.68183166310286
# 2001-09-24, Current Portfolio Value : 65953.55967712402
# 2001-09-24, LIMIT SELL CREATE 2116 shares at 268.5295515074424
# 2001-09-25, Current Portfolio Value : 66249.79838562012
# 2001-09-25, LIMIT SELL CREATE 2116 shares at 266.7456813991281
# 2001-09-26, Current Portfolio Value : 71963.0
# 2001-09-26, LIMIT SELL CREATE 2116 shares at 274.8184787094155
# 2001-09-27, Current Portfolio Value : 74925.40322875977
# 2001-09-27, LIMIT SELL CREATE 2116 shares at 274.58669462458204
# 2001-09-28, Current Portfolio Value : 75708.32096862793
# 2001-09-28, LIMIT SELL CREATE 2116 shares at 275.221609548045
# 2001-10-01, Current Portfolio Value : 73211.44032287598
# 2001-10-01, LIMIT SELL CREATE 2116 shares at 270.9382790291692
# 2001-10-02, Current Portfolio Value : 72386.20161437988
# 2001-10-02, LIMIT SELL CREATE 2116 shares at 274.7680988884286
# 2001-10-03, Current Portfolio Value : 76216.15644836426
# 2001-10-03, LIMIT SELL CREATE 2116 shares at 271.88565341625
# 2001-10-04, Current Portfolio Value : 77253.0
# 2001-10-04, LIMIT SELL CREATE 2116 shares at 270.23280775079536
# 2001-10-05, Current Portfolio Value : 75877.59677124023
# 2001-10-05, LIMIT SELL CREATE 2116 shares at 270.86775343116983
# 2001-10-08, Current Portfolio Value : 75263.96290588379
# 2001-10-08, LIMIT SELL CREATE 2116 shares at 270.807285343221
# 2001-10-09, Current Portfolio Value : 76343.11935424805
# 2001-10-09, LIMIT SELL CREATE 2116 shares at 273.76025641339896
# 2001-10-10, Current Portfolio Value : 78099.40322875977
# 2001-10-10, LIMIT SELL CREATE 2116 shares at 272.8128820263182
# 2001-10-11, Current Portfolio Value : 79263.20161437988
# 2001-10-11, LIMIT SELL CREATE 2116 shares at 271.1600056039522
# 2001-10-12, Current Portfolio Value : 76745.15644836426
# 2001-10-12, LIMIT SELL CREATE 2116 shares at 275.1409956830837
# 2001-10-15, Current Portfolio Value : 77655.0370941162
# 2001-10-15, LIMIT SELL CREATE 2116 shares at 283.4254620581036
# 2001-10-16, Current Portfolio Value : 76195.0
# 2001-10-16, LIMIT SELL CREATE 2116 shares at 286.2474086854219
# 2001-10-17, Current Portfolio Value : 74883.08226013184
# 2001-10-17, LIMIT SELL CREATE 2116 shares at 284.725587462827
# 2001-10-18, Current Portfolio Value : 75200.47741699219
# 2001-10-18, LIMIT SELL CREATE 2116 shares at 286.3986096622055
# 2001-10-19, Current Portfolio Value : 74079.0
# 2001-10-19, LIMIT SELL CREATE 2116 shares at 286.9529107207072
# 2001-10-22, Current Portfolio Value : 72555.47741699219
# 2001-10-22, LIMIT SELL CREATE 2116 shares at 297.9686215911221
# 2001-10-23, Current Portfolio Value : 78734.20161437988
# 2001-10-23, LIMIT SELL CREATE 2116 shares at 304.60024230068734
# 2001-10-24, Current Portfolio Value : 77274.15644836426
# 2001-10-24, LIMIT SELL CREATE 2116 shares at 298.67412362640744
# 2001-10-25, Current Portfolio Value : 79369.0
# 2001-10-25, LIMIT SELL CREATE 2116 shares at 306.5151368518613
# 2001-10-26, Current Portfolio Value : 78184.0370941162
# 2001-10-26, LIMIT SELL CREATE 2116 shares at 309.54875254391214
# 2001-10-29, Current Portfolio Value : 77633.88064575195
# 2001-10-29, LIMIT SELL CREATE 2116 shares at 309.44796214502685
# 2001-10-30, Current Portfolio Value : 74671.47741699219
# 2001-10-30, LIMIT SELL CREATE 2116 shares at 310.3247801771968
# 2001-10-31, Current Portfolio Value : 75115.84355163574
# 2001-10-31, LIMIT SELL CREATE 2116 shares at 298.99664060007564
# 2001-11-01, Current Portfolio Value : 75348.59677124023
# 2001-11-01, LIMIT SELL CREATE 2116 shares at 301.99999149124056
# 2001-11-02, Current Portfolio Value : 75454.40322875977
# 2001-11-02, LIMIT SELL CREATE 2116 shares at 302.25195210999794
# 2001-11-05, Current Portfolio Value : 76533.55967712402
# 2001-11-05, LIMIT SELL CREATE 2116 shares at 301.153407503045
# 2001-11-06, Current Portfolio Value : 78840.0
# 2001-11-06, LIMIT SELL CREATE 2116 shares at 298.59347900453463
# 2001-11-07, Current Portfolio Value : 79157.40322875977
# 2001-11-07, LIMIT SELL CREATE 2116 shares at 303.5823115586958
# 2001-11-08, Current Portfolio Value : 80448.15644836426
# 2001-11-08, LIMIT SELL CREATE 2116 shares at 307.0291463563381
# 2001-11-09, Current Portfolio Value : 80638.59677124022
# 2001-11-09, LIMIT SELL CREATE 2116 shares at 308.9037185965757
# 2001-11-12, Current Portfolio Value : 80913.67903137207
# 2001-11-12, LIMIT SELL CREATE 2116 shares at 306.7368634266443
# 2001-11-13, Current Portfolio Value : 82627.64193725586
# 2001-11-13, LIMIT SELL CREATE 2116 shares at 306.6562188047715
# 2001-11-14, Current Portfolio Value : 80405.84355163574
# 2001-11-14, LIMIT SELL CREATE 2116 shares at 302.7961956584492
# 2001-11-15, Current Portfolio Value : 79855.67903137207
# 2001-11-15, LIMIT SELL CREATE 2116 shares at 304.4792753678782
# 2001-11-16, Current Portfolio Value : 78734.20161437988
# 2001-11-16, LIMIT SELL CREATE 2116 shares at 302.2217180660235
# 2001-11-19, Current Portfolio Value : 80215.40322875977
# 2001-11-19, LIMIT SELL CREATE 2116 shares at 304.0358529752237
# 2001-11-20, Current Portfolio Value : 78903.4774169922
# 2001-11-20, LIMIT SELL CREATE 2116 shares at 302.1007818901258
# 2001-11-21, Current Portfolio Value : 77951.28387451172
# 2001-11-21, LIMIT SELL CREATE 2116 shares at 310.8790812356985
# 2001-11-23, Current Portfolio Value : 79686.40322875977
# ...
# 2001-12-24, LIMIT SELL CREATE 9922 shares at 280.9495922961747
# 2001-12-26, Current Portfolio Value : 93916.57526397705
# 2001-12-26, LIMIT SELL CREATE 9922 shares at 272.9693311327358
# 2001-12-27, Current Portfolio Value : 93519.69564247131
# 2001-12-27, LIMIT SELL CREATE 9922 shares at 273.1516138319983
# 2001-12-28, Current Portfolio Value : 92527.49185752869
# 2001-12-28, LIMIT SELL CREATE 9922 shares at 281.16225544531426
# 2001-12-31, Current Portfolio Value : 92453.07988548279
# 2001-12-31, LIMIT SELL CREATE 9922 shares at 278.2759890835945
# 2002-01-02, Current Portfolio Value : 92155.42253494264
# 2002-01-02, LIMIT SELL CREATE 9922 shares at 276.22016289298057
# 2002-01-03, Current Portfolio Value : 95752.13996505736
# 2002-01-03, LIMIT SELL CREATE 9922 shares at 277.45568603106403
# 2002-01-04, Current Portfolio Value : 96000.19564247131
# 2002-01-04, LIMIT SELL CREATE 9922 shares at 284.7371659414807
# 2002-01-07, Current Portfolio Value : 97686.93639945984
# 2002-01-07, LIMIT SELL CREATE 9922 shares at 285.26377070796656
# 2002-01-08, Current Portfolio Value : 97686.93639945984
# 2002-01-08, LIMIT SELL CREATE 9922 shares at 291.1375818996128
# 2002-01-09, Current Portfolio Value : 99472.88996505736
# 2002-01-09, LIMIT SELL CREATE 9922 shares at 293.15289052177417
# 2002-01-10, Current Portfolio Value : 99720.94564247131
# 2002-01-10, LIMIT SELL CREATE 9922 shares at 296.2315767013319
# 2002-01-11, Current Portfolio Value : 97042.00110054016
# 2002-01-11, LIMIT SELL CREATE 9922 shares at 290.3172788470824
# 2002-01-14, Current Portfolio Value : 97984.59375
# 2002-01-14, LIMIT SELL CREATE 9922 shares at 289.4969448887026
# 2002-01-15, Current Portfolio Value : 99100.82064247131
# 2002-01-15, LIMIT SELL CREATE 9922 shares at 284.8789310722907
# 2002-01-16, Current Portfolio Value : 99249.64458656311
# 2002-01-16, LIMIT SELL CREATE 9922 shares at 283.2282187545036
# 2002-01-17, Current Portfolio Value : 99249.64458656311
# 2002-01-17, LIMIT SELL CREATE 9922 shares at 277.96204746624824
# 2002-01-18, Current Portfolio Value : 98604.71875
# 2002-01-18, LIMIT SELL CREATE 9922 shares at 288.40321778727844
# 2002-01-22, Current Portfolio Value : 97190.83450698851
# 2002-01-22, LIMIT SELL CREATE 9922 shares at 282.43829615185024
# 2002-01-23, Current Portfolio Value : 98034.20488548279
# 2002-01-23, LIMIT SELL CREATE 9922 shares at 282.20535876555977
# 2002-01-24, Current Portfolio Value : 99398.47799301149
# 2002-01-24, LIMIT SELL CREATE 9922 shares at 279.0051507864937
# 2002-01-25, Current Portfolio Value : 100390.68177795409
# 2002-01-25, LIMIT SELL CREATE 9922 shares at 281.0305965272305
# 2002-01-28, Current Portfolio Value : 103119.22799301149
# 2002-01-28, LIMIT SELL CREATE 9922 shares at 281.040733645806
# 2002-01-29, Current Portfolio Value : 101581.32064247131
# 2002-01-29, LIMIT SELL CREATE 9922 shares at 284.0890084696373
# 2002-01-30, Current Portfolio Value : 101705.34375
# 2002-01-30, LIMIT SELL CREATE 9922 shares at 280.28119149302967
# 2002-01-31, Current Portfolio Value : 101705.34375
# 2002-01-31, LIMIT SELL CREATE 9922 shares at 277.19236819489646
# 2002-02-01, Current Portfolio Value : 102201.44564247131
# 2002-02-01, LIMIT SELL CREATE 9922 shares at 279.85583428890124
# 2002-02-04, Current Portfolio Value : 99572.11223602295
# 2002-02-04, LIMIT SELL CREATE 9922 shares at 281.5167146311131
# 2002-02-05, Current Portfolio Value : 99844.96875
# 2002-02-05, LIMIT SELL CREATE 9922 shares at 286.8233725819717
# 2002-02-06, Current Portfolio Value : 101878.97799301149
# 2002-02-06, LIMIT SELL CREATE 9922 shares at 289.7096389436915
# 2002-02-07, Current Portfolio Value : 100341.07064247131
# 2002-02-07, LIMIT SELL CREATE 9922 shares at 287.2791102359772
# 2002-02-08, Current Portfolio Value : 103714.55215644836
# 2002-02-08, LIMIT SELL CREATE 9922 shares at 290.61094622727774
# 2002-02-11, Current Portfolio Value : 105773.36223602295
# 2002-02-11, LIMIT SELL CREATE 9922 shares at 292.4135917002995
# 2002-02-12, Current Portfolio Value : 105798.17253494264
# 2002-02-12, LIMIT SELL CREATE 9922 shares at 297.0923664164656
# 2002-02-13, Current Portfolio Value : 105946.99647903442
# 2002-02-13, LIMIT SELL CREATE 9922 shares at 301.5280975336151
# 2002-02-14, Current Portfolio Value : 105078.82526397705
# 2002-02-14, LIMIT SELL CREATE 9922 shares at 295.6137996793656
# 2002-02-15, Current Portfolio Value : 103838.57526397705
# 2002-02-15, LIMIT SELL CREATE 9922 shares at 297.43671938953827
# 2002-02-19, Current Portfolio Value : 100465.09375
# 2002-02-19, LIMIT SELL CREATE 9922 shares at 301.5280975336151
# 2002-02-20, Current Portfolio Value : 98951.98723602295
# 2002-02-20, LIMIT SELL CREATE 9922 shares at 299.3608866620684
# 2002-02-21, Current Portfolio Value : 95231.23723602295
# 2002-02-21, LIMIT SELL CREATE 9922 shares at 299.8773543099787
# 2002-02-22, Current Portfolio Value : 102424.69102096558
# 2002-02-22, LIMIT SELL CREATE 9922 shares at 298.2165048736162
# 2002-02-25, Current Portfolio Value : 106864.78829193115
# 2002-02-25, LIMIT SELL CREATE 9922 shares at 299.1380863943533
# 2002-02-26, Current Portfolio Value : 107708.14920806885
# 2002-02-26, LIMIT SELL CREATE 9922 shares at 295.6441801292426
# 2002-02-27, Current Portfolio Value : 111478.51034355164
# 2002-02-27, LIMIT SELL CREATE 9922 shares at 300.1913268331743
# 2002-02-28, Current Portfolio Value : 109568.52420806885
# 2002-02-28, LIMIT SELL CREATE 9922 shares at 300.879970967621
# 2002-03-01, Current Portfolio Value : 114976.01496505736
# 2002-03-01, LIMIT SELL CREATE 9922 shares at 298.5405836095379
# 2002-03-04, Current Portfolio Value : 115844.19564247131
# 2002-03-04, LIMIT SELL CREATE 9922 shares at 297.0619859665885
# 2002-03-05, Current Portfolio Value : 113611.74185752869
# 2002-03-05, LIMIT SELL CREATE 9922 shares at 290.96540541307644
# 2002-03-06, Current Portfolio Value : 107981.00572204591
# 2002-03-06, LIMIT SELL CREATE 9922 shares at 299.88749142855414
# 2002-03-07, Current Portfolio Value : 108129.83912849426
# 2002-03-07, LIMIT SELL CREATE 9922 shares at 305.61950658354124
# 2002-03-08, Current Portfolio Value : 109146.84375
# 2002-03-08, LIMIT SELL CREATE 9922 shares at 312.4351426272263
# 2002-03-11, Current Portfolio Value : 113462.91791343689
# 2002-03-11, LIMIT SELL CREATE 9922 shares at 316.62779923950984
# 2002-03-12, Current Portfolio Value : 112644.34837150574
# 2002-03-12, LIMIT SELL CREATE 9922 shares at 317.61014166000115
# 2002-03-13, Current Portfolio Value : 111131.24185752869
# 2002-03-13, LIMIT SELL CREATE 9922 shares at 312.1718247910587
# 2002-03-14, Current Portfolio Value : 110635.13996505736
# 2002-03-14, LIMIT SELL CREATE 9922 shares at 317.1139173433924
# 2002-03-15, Current Portfolio Value : 110709.56139945984
# 2002-03-15, LIMIT SELL CREATE 9922 shares at 324.5776799530716
# 2002-03-18, Current Portfolio Value : 114430.31139945984
# 2002-03-18, LIMIT SELL CREATE 9922 shares at 325.2157003063396
# 2002-03-19, Current Portfolio Value : 113537.32988548279
# 2002-03-19, LIMIT SELL CREATE 9922 shares at 326.1676622769538
# 2002-03-20, Current Portfolio Value : 113661.35299301149
# 2002-03-20, LIMIT SELL CREATE 9922 shares at 331.77812472658326
# 2002-03-21, Current Portfolio Value : 115521.72799301149
# 2002-03-21, LIMIT SELL CREATE 9922 shares at 333.27696570083424
# 2002-03-22, Current Portfolio Value : 115075.23723602295
# 2002-03-22, LIMIT SELL CREATE 9922 shares at 333.0035416519405
# 2002-03-25, Current Portfolio Value : 112793.18177795409
# 2002-03-25, LIMIT SELL CREATE 9922 shares at 337.0037784463861
# 2002-03-26, Current Portfolio Value : 112669.14920806885
# 2002-03-26, LIMIT SELL CREATE 9922 shares at 337.0037784463861
# 2002-03-27, Current Portfolio Value : 114281.47799301149
# 2002-03-27, LIMIT SELL CREATE 9922 shares at 335.4948312594089
# 2002-03-28, Current Portfolio Value : 115819.38534355164
# 2002-03-28, LIMIT SELL CREATE 9922 shares at 332.821258952678
# 2002-04-01, Current Portfolio Value : 115521.72799301149
# 2002-04-01, LIMIT SELL CREATE 9922 shares at 336.2746167434869
# 2002-04-02, Current Portfolio Value : 112545.12610054016
# 2002-04-02, LIMIT SELL CREATE 9922 shares at 337.0139155649616
# 2002-04-03, Current Portfolio Value : 107658.54753494264
# 2002-04-03, LIMIT SELL CREATE 9922 shares at 334.3808299208339
# 2002-04-04, Current Portfolio Value : 108129.83912849426
# 2002-04-04, LIMIT SELL CREATE 9922 shares at 328.8311283709586
# 2002-04-05, Current Portfolio Value : 106740.75572204591
# 2002-04-05, LIMIT SELL CREATE 9922 shares at 327.6360918954784
# 2002-04-08, Current Portfolio Value : 108055.42715644836
# 2002-04-08, LIMIT SELL CREATE 9922 shares at 334.55300640737016
# 2002-04-09, Current Portfolio Value : 104334.67715644836
# 2002-04-09, LIMIT SELL CREATE 9922 shares at 338.6342783387209
# 2002-04-10, Current Portfolio Value : 101730.14458656311
# 2002-04-10, LIMIT SELL CREATE 9922 shares at 341.0445637151336
# 2002-04-11, Current Portfolio Value : 96868.36685752869
# 2002-04-11, LIMIT SELL CREATE 9922 shares at 345.4093968139534
# 2002-04-12, Current Portfolio Value : 100316.26034355164
# 2002-04-12, LIMIT SELL CREATE 9922 shares at 346.6246457148859
# 2002-04-15, Current Portfolio Value : 103912.98723602295
# 2002-04-15, LIMIT SELL CREATE 9922 shares at 314.13650963204134
# 2002-04-16, Current Portfolio Value : 102077.42253494264
# 2002-04-16, LIMIT SELL CREATE 9922 shares at 319.65586163788885
# 2002-04-17, Current Portfolio Value : 94759.94564247131
# 2002-04-17, LIMIT SELL CREATE 9922 shares at 317.37723517956
# 2002-04-18, Current Portfolio Value : 94139.82064247131
# 2002-04-18, LIMIT SELL CREATE 9922 shares at 314.0352311638347
# 2002-04-19, Current Portfolio Value : 95900.97337150574
# 2002-04-19, LIMIT SELL CREATE 9922 shares at 307.0980733206413
# 2002-04-22, Current Portfolio Value : 90543.09375
# 2002-04-22, LIMIT SELL CREATE 9922 shares at 291.1274447810374
# 2002-04-23, Current Portfolio Value : 89005.18639945984
# 2002-04-23, LIMIT SELL CREATE 9922 shares at 292.42372881887496
# 2002-04-24, Current Portfolio Value : 88955.57526397705
# 2002-04-24, LIMIT SELL CREATE 9922 shares at 291.11730766246194
# 2002-04-25, Current Portfolio Value : 89898.16791343689
# 2002-04-25, LIMIT SELL CREATE 9922 shares at 293.2440318714053
# 2002-04-26, Current Portfolio Value : 90394.26034355164
# 2002-04-26, LIMIT SELL CREATE 9922 shares at 291.34010793017694
# 2002-04-29, Current Portfolio Value : 85978.97337150574
# 2002-04-29, LIMIT SELL CREATE 9922 shares at 288.0487586014797
# 2002-04-30, Current Portfolio Value : 91237.63072204591
# 2002-04-30, LIMIT SELL CREATE 9922 shares at 284.85868774098907
# 2002-05-01, Current Portfolio Value : 91336.85299301149
# 2002-05-01, LIMIT SELL CREATE 9922 shares at 282.90414001858187
# 2002-05-02, Current Portfolio Value : 91188.01958656311
# 2002-05-02, LIMIT SELL CREATE 9922 shares at 290.2666241600544
# 2002-05-03, Current Portfolio Value : 85879.75110054016
# 2002-05-03, LIMIT SELL CREATE 9922 shares at 294.37827654128216
# 2002-05-06, Current Portfolio Value : 69806.11223602295
# 2002-05-06, LIMIT SELL CREATE 9922 shares at 291.81608891548404
# 2002-05-07, Current Portfolio Value : 70699.09375
# 2002-05-07, LIMIT SELL CREATE 9922 shares at 287.2082122176476
# 2002-05-08, Current Portfolio Value : 75312.82526397705
# 2002-05-08, LIMIT SELL CREATE 9922 shares at 286.79299213209464
# 2002-05-09, Current Portfolio Value : 75908.14469623566
# 2002-05-09, LIMIT SELL CREATE 9922 shares at 290.0640981294903
# 2002-05-10, Current Portfolio Value : 73874.13545322418
# 2002-05-10, LIMIT SELL CREATE 9922 shares at 295.87711751553314
# 2002-05-13, Current Portfolio Value : 74965.55204677582
# 2002-05-13, LIMIT SELL CREATE 9922 shares at 298.4190618100296
# 2002-05-14, Current Portfolio Value : 77644.49185752869
# 2002-05-14, LIMIT SELL CREATE 9922 shares at 297.8012847880631
# 2002-05-15, Current Portfolio Value : 79380.84375
# 2002-05-15, LIMIT SELL CREATE 9922 shares at 291.51228441671327
# 2002-05-16, Current Portfolio Value : 77396.44564247131
# 2002-05-16, LIMIT SELL CREATE 9922 shares at 291.6540495475232
# 2002-05-17, Current Portfolio Value : 71344.0243177414
# 2002-05-17, LIMIT SELL CREATE 9922 shares at 288.7981945415298
# 2002-05-20, Current Portfolio Value : 68813.9131822586
# 2002-05-20, LIMIT SELL CREATE 9922 shares at 287.6740560843792
# 2002-05-21, Current Portfolio Value : 67474.44564247131
# 2002-05-21, LIMIT SELL CREATE 9922 shares at 276.40244559224305
# 2002-05-22, Current Portfolio Value : 65142.774317741394
# 2002-05-22, LIMIT SELL CREATE 9922 shares at 279.49126889037626
# 2002-05-23, Current Portfolio Value : 65986.14469623566
# 2002-05-23, LIMIT SELL CREATE 9922 shares at 280.9495922961747
# 2002-05-24, Current Portfolio Value : 65093.163182258606
# 2002-05-24, LIMIT SELL CREATE 9922 shares at 286.6208156455583
# 2002-05-28, Current Portfolio Value : 65390.82526397705
# 2002-05-28, LIMIT SELL CREATE 9922 shares at 282.4889199330289
# 2002-05-29, Current Portfolio Value : 65787.70488548279
# 2002-05-29, LIMIT SELL CREATE 9922 shares at 280.0583912253146
# 2002-05-30, Current Portfolio Value : 65886.92242527008
# 2002-05-30, LIMIT SELL CREATE 9922 shares at 279.42037087204665
# 2002-05-31, Current Portfolio Value : 66978.34375
# 2002-05-31, LIMIT SELL CREATE 9922 shares at 287.05630996826216
# 2002-06-03, Current Portfolio Value : 64497.84375
# 2002-06-03, LIMIT SELL CREATE 9922 shares at 292.8490860230034
# 2002-06-04, Current Portfolio Value : 66234.19564247131
# 2002-06-04, LIMIT SELL CREATE 9922 shares at 294.8947750950418
# 2002-06-05, Current Portfolio Value : 66482.24185752869
# 2002-06-05, LIMIT SELL CREATE 9922 shares at 296.3936160692928
# 2002-06-06, Current Portfolio Value : 65986.14469623566
# 2002-06-06, LIMIT SELL CREATE 9922 shares at 300.464750882068
# 2002-06-07, Current Portfolio Value : 68218.59375
# 2002-06-07, LIMIT SELL CREATE 9922 shares at 302.4395728416261
# 2002-06-10, Current Portfolio Value : 66134.97337150574
# 2002-06-10, LIMIT SELL CREATE 9922 shares at 309.5691195968081
# 2002-06-11, Current Portfolio Value : 67176.78356075287
# 2002-06-11, LIMIT SELL CREATE 9922 shares at 312.5060097397066
# 2002-06-12, Current Portfolio Value : 66829.51507472992
# 2002-06-12, LIMIT SELL CREATE 9922 shares at 315.75687240580066
# 2002-06-13, Current Portfolio Value : 65688.48261451721
# 2002-06-13, LIMIT SELL CREATE 9922 shares at 316.7797014888952
# 2002-06-14, Current Portfolio Value : 65886.92242527008
# 2002-06-14, LIMIT SELL CREATE 9922 shares at 312.4351426272263
# 2002-06-17, Current Portfolio Value : 67424.83450698853
# 2002-06-17, LIMIT SELL CREATE 9922 shares at 321.1344283749889
# 2002-06-18, Current Portfolio Value : 69458.84375
# 2002-06-18, LIMIT SELL CREATE 9922 shares at 321.65089602289925
# 2002-06-19, Current Portfolio Value : 67871.32526397705
# 2002-06-19, LIMIT SELL CREATE 9922 shares at 319.0178412846209
# 2002-06-20, Current Portfolio Value : 68268.20488548279
# 2002-06-20, LIMIT SELL CREATE 9922 shares at 318.92669993498964
# 2002-06-21, Current Portfolio Value : 65142.774317741394
# 2002-06-21, LIMIT SELL CREATE 9922 shares at 312.29334659056707
# 2002-06-24, Current Portfolio Value : 64547.45488548279
# 2002-06-24, LIMIT SELL CREATE 9922 shares at 323.02821519764194
# 2002-06-25, Current Portfolio Value : 64448.23261451721
# 2002-06-25, LIMIT SELL CREATE 9922 shares at 328.6488147658468
# 2002-06-26, Current Portfolio Value : 64398.621479034424
# 2002-06-26, LIMIT SELL CREATE 9922 shares at 333.2567223695326
# Final Portfolio Value: 64398.621479034424
#
# STRATEGY INFO:
# OrderedDict([('sharperatio', -0.01703751437514688)])
# AutoOrderedDict([('len', 80), ('drawdown', 44.40928082595766), ('moneydown', 51445.57416343689), ('max', AutoOrderedDict([('len', 411), ('drawdown', 51.59087725351083), ('moneydown', 52710.625)]))])
# OrderedDict([('rtot', -0.4400779587119422), ('ravg', -0.000814959182799893), ('rnorm', -0.185653814490349), ('rnorm100', -18.565381449034902)])
# For ADSK, return was -35.601378520965575% for buy and hold vs -35.601378520965575%  for strategy
# {'WAT': <backtrader.cerebro.Cerebro at 0x7f83d85286d0>,
#  'UNH': <backtrader.cerebro.Cerebro at 0x7f83e9bcf310>,
#  'HD': <backtrader.cerebro.Cerebro at 0x7f83e90ba5d0>,
#  'MSFT': <backtrader.cerebro.Cerebro at 0x7f83ea26cbd0>,
#  'XOM': <backtrader.cerebro.Cerebro at 0x7f83ea307690>,
#  'ADSK': <backtrader.cerebro.Cerebro at 0x7f84097ce910>}

# %% [markdown]
# ### Library additionally has plotting
# Not sure how to reformat this, it's pretty ugly

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 8]
plt.rcParams.update({'font.size': 12}) 
cerebro_dict['UNH'].plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-22-73966f5e4f6c> in <module>
#       3 plt.rcParams['figure.figsize'] = [10, 8]
#       4 plt.rcParams.update({'font.size': 12})
# ----> 5 cerebro_dict['UNH'].plot()
#
# /opt/anaconda3/lib/python3.7/site-packages/backtrader/cerebro.py in plot(self, plotter, numfigs, iplot, start, end, width, height, dpi, tight, use, **kwargs)
#     972
#     973         if not plotter:
# --> 974             from . import plot
#     975             if self.p.oldsync:
#     976                 plotter = plot.Plot_OldSync(**kwargs)
#
# /opt/anaconda3/lib/python3.7/site-packages/backtrader/plot/__init__.py in <module>
#      40
#      41
# ---> 42 from .plot import Plot, Plot_OldSync
#      43 from .scheme import PlotScheme
#
# /opt/anaconda3/lib/python3.7/site-packages/backtrader/plot/plot.py in <module>
#      42 from .finance import plot_candlestick, plot_ohlc, plot_volume, plot_lineonclose
#      43 from .formatters import (MyVolFormatter, MyDateFormatter, getlocator)
# ---> 44 from . import locator as loc
#      45 from .multicursor import MultiCursor
#      46 from .scheme import PlotScheme
#
# /opt/anaconda3/lib/python3.7/site-packages/backtrader/plot/locator.py in <module>
#      33 from matplotlib.dates import AutoDateFormatter as ADFormatter
#      34
# ---> 35 from matplotlib.dates import (HOURS_PER_DAY, MIN_PER_HOUR, SEC_PER_MIN,
#      36                               MONTHS_PER_YEAR, DAYS_PER_WEEK,
#      37                               SEC_PER_HOUR, SEC_PER_DAY,
#
# ImportError: cannot import name 'warnings' from 'matplotlib.dates' (/opt/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py)

# %% [markdown]
# ### Ways to Improve:

# %% [markdown]
# Increase strategy trading volume. There are certain periods where sell orders are not going through for multiple days in a row, meaning that the price is lower than anticipated by model for that period. For example, if the last sell order didn't go through, we can find a way to use that information to inform our next sell order and make the prediction lower or try a market sell. Maybe train a "bear" model, one that only knows pain and suffering of bear markets, and only produces pessimistic high price predictions.
#
# Smarter entry points. Currently, buy orders are being executed at market price at the open. Returns may increase if entry constraints are increased.
#
# Resizing orders. Orders for this strategy baseline are currently 100% in or 100% out of position. This has beneifits if you want less exposure to the long term movement of the stocks. Depending on the situation and strategy, we might want to reserve a cash position to expose ourselves less to short term movements.
